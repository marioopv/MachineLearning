# %% [markdown]
# # Optimización de hiper-parámetros - Avanzado - Solución
#
# En este notebook jugaremos con dos tipos de optimización de hiperparámetros más complicados:
# * Hyperopt
# * Algoritmos genéticos

# %% [markdown]
# ## Hyper-opt
#
# (Hyperopt: Distributed Asynchronous Hyper-parameter Optimization, https://github.com/hyperopt/hyperopt).
#
# Hyperopt es una librería escrita en Python que permite optimizar funciones de una forma rápida fijándose más en los valores que más probablemente van a dar una buena solución.
#
# Actualmente tiene dos algoritmos implementados para hacer esto:
#
# * Random Search
# * Tree of Parzen Estimators (TPE)
#
# Además, se pueden ejecutar en serie o en paralelo, haciendo uso de MongoDB.
#
# Vamos a ver un ejemplo de cómo utilizarlo.
#
# Vamos a encontrar el mínimo de $x^2$:
# (<a href="https://www.google.es/search?source=hp&ei=2ds5XO_jG6y_lwTvxp2QBQ&q=x**2&btnK=Google+Search&oq=x**2&gs_l=psy-ab.3...716.1584..1916...0.0..0.301.1084.1j0j3j1......0....1..gws-wiz.....0..0i131j0.cgRgMW95cQk">click aqui para ver la funcion</a>)

# %%
from hyperopt import fmin, tpe, hp
# con 10 iteraciones

best = fmin(fn=lambda x: x ** 2,
            space=hp.uniform('x', -10, 10),
            algo=tpe.suggest,
            max_evals=10)

print(best)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 655.52it/s, best loss: 1.0851313896933976]
# {'x': 1.0416963999618112}

# %%
# con 100 iteraciones
best = fmin(fn=lambda x: x ** 2,
            space=hp.uniform('x', -10, 10),
            algo=tpe.suggest,
            max_evals=100)

print(best)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 304.23it/s, best loss: 2.3360017308828754e-05]
# {'x': -0.0048332201800485725}

# %%
# con 1000 iteraciones
best = fmin(fn=lambda x: x ** 2,
            space=hp.uniform('x', -10, 10),
            algo=tpe.suggest,
            max_evals=1000)

print(best)
# Out:
# 100%|██████████| 1000/1000 [00:06<00:00, 159.94it/s, best loss: 2.3052055939773022e-05]
# {'x': 0.00480125566282124}

# %% [markdown]
# Y ahora uno más complejo con redes neuronales:

# %%
# instalamos los paquetes necesarios
# !pip install networkx==1.11 # para instala hyperopt correctamente, si no, da errores
# !pip install hyperopt
# Out:
# Collecting networkx==1.11
#   Downloading https://files.pythonhosted.org/packages/d3/2c/e473e54afc9fae58dfa97066ef6709a7e35a1dd1c28c5a3842989322be00/networkx-1.11-py2.py3-none-any.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 2.8MB/s
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.6/dist-packages (from networkx==1.11) (4.4.2)
# ERROR: scikit-image 0.16.2 has requirement networkx>=2.0, but you'll have networkx 1.11 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: networkx
#   Found existing installation: networkx 2.4
#     Uninstalling networkx-2.4:
#       Successfully uninstalled networkx-2.4
# Successfully installed networkx-1.11
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.6/dist-packages (0.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.18.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.11)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.6/dist-packages (from hyperopt) (3.10.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from hyperopt) (4.41.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from hyperopt) (0.16.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.12.0)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.6/dist-packages (from networkx->hyperopt) (4.4.2)

# %%
# imports necesarios
import sys
import time
import numpy as np
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.constraints import max_norm
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.datasets import cifar10

SEED = 42

(X_train, y_train), (X_test, y_test) = cifar10.load_data()
validation_split = 0.1
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=validation_split, random_state=SEED)

# normalizamos
X_train = X_train.astype('float32') / 255.
X_val = X_val.astype('float32') / 255.
X_test = X_test.astype('float32') / 255.

# convertimos las etiquetas a one-hot encoding
n_classes = 10
y_train = to_categorical(y_train, n_classes)
y_val = to_categorical(y_val, n_classes)
y_test = to_categorical(y_test, n_classes)

# definimos nuestro espacio de búsqueda
# vamos a variar:
# - el número de filtros en nuestras capas conv
# - el porcentaje de dropout
# - el número de neuronas en la capa dense
space = {
    'n_filters_conv': hp.choice('n_filters_conv', [32, 64, 128]),
    'dropout': hp.uniform('dropout', 0.0, 0.5),
    'neurons_dense': hp.choice('neurons_dense', [256, 512, 1024]), 
}

def	get_callbacks(pars):
  callbacks	= [EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=2, verbose=0, mode='auto')]
  return callbacks

def mi_cnn(pars):
  print ('Parameters: ', pars)
  model = Sequential()
  
  # Primer bloque convolucional
  model.add(Conv2D(pars['n_filters_conv'], kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(pars['dropout']))

  # Segundo bloque convolucional
  model.add(Conv2D(pars['n_filters_conv'], kernel_size=(3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(pars['dropout']))

  # Tercer bloque convolucional
  model.add(Conv2D(pars['n_filters_conv'], kernel_size=(3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(pars['dropout']))

  # Bloque clasificador
  model.add(Flatten())
  model.add(Dense(pars['neurons_dense'], activation='relu', kernel_constraint=max_norm(3.)))
  model.add(Dropout(pars['dropout']))
  model.add(Dense(10, activation='softmax'))

  # Compilamos el modelo
  model.compile(loss='categorical_crossentropy',
                optimizer=Adam(lr=0.0001, decay=1e-6),
                metrics=['accuracy'])

  # Entrenamos el modelo
  history = model.fit(X_train, 
                      y_train,
                      batch_size=128,
                      shuffle=True,
                      epochs=5,
                      validation_data=(X_val, y_val),
                      verbose = 0,
                      callbacks = get_callbacks(pars))

  best_epoch_loss = np.argmin(history.history['val_loss'])
  best_val_loss = np.min(history.history['val_loss'])
  best_val_acc = np.max(history.history['val_accuracy'])
  
  print('Epoch {} - val acc: {} - val loss: {}'.format(best_epoch_loss, best_val_acc, best_val_loss))
  sys.stdout.flush()
  
  return {'loss': best_val_loss, 'best_epoch': best_epoch_loss, 'eval_time': time.time(), 'status': STATUS_OK, 'model': model, 'history': history}


trials = Trials()
best = fmin(mi_cnn, space, algo=tpe.suggest, max_evals=10, trials=trials)
print(best)
# Out:
# Parameters:
# {'dropout': 0.2893968885773047, 'n_filters_conv': 32, 'neurons_dense': 256}
# Epoch 4 - val acc: 0.35260000824928284 - val loss: 1.7766779472351075
# Parameters:
# {'dropout': 0.24602421986549994, 'n_filters_conv': 32, 'neurons_dense': 256}
# Epoch 4 - val acc: 0.38100001215934753 - val loss: 1.6846457529067993
# Parameters:
# {'dropout': 0.3893173611359977, 'n_filters_conv': 32, 'neurons_dense': 256}
# Epoch 4 - val acc: 0.3386000096797943 - val loss: 1.7924710163116455
# Parameters:
# {'dropout': 0.021743729494355657, 'n_filters_conv': 128, 'neurons_dense': 512}
# Epoch 4 - val acc: 0.5428000092506409 - val loss: 1.281806408214569
# Parameters:
# {'dropout': 0.01841867440101863, 'n_filters_conv': 64, 'neurons_dense': 1024}
# Epoch 4 - val acc: 0.5153999924659729 - val loss: 1.3524145696640015
# Parameters:
# {'dropout': 0.34447763510219326, 'n_filters_conv': 128, 'neurons_dense': 256}
# Epoch 4 - val acc: 0.48980000615119934 - val loss: 1.4285307010650634
# Parameters:
# {'dropout': 0.14084614019549763, 'n_filters_conv': 128, 'neurons_dense': 1024}
# Epoch 4 - val acc: 0.548799991607666 - val loss: 1.268199026298523
# Parameters:
# {'dropout': 0.23636172256843885, 'n_filters_conv': 32, 'neurons_dense': 256}
# Epoch 4 - val acc: 0.375 - val loss: 1.6936490482330322
# Parameters:
# {'dropout': 0.24152388614709397, 'n_filters_conv': 128, 'neurons_dense': 256}
# Epoch 4 - val acc: 0.5040000081062317 - val loss: 1.3754857486724854
# Parameters:
# {'dropout': 0.0808290105926876, 'n_filters_conv': 64, 'neurons_dense': 1024}
# Epoch 4 - val acc: 0.5085999965667725 - val loss: 1.3765917095184326
# 100%|██████████| 10/10 [06:36<00:00, 39.69s/it, best loss: 1.268199026298523]
# {'dropout': 0.14084614019549763, 'n_filters_conv': 2, 'neurons_dense': 2}

# %%
trials.trials
# Out:
# [{'book_time': datetime.datetime(2020, 6, 10, 10, 3, 35, 853000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dropout': [0], 'n_filters_conv': [0], 'neurons_dense': [0]},
#    'tid': 0,
#    'vals': {'dropout': [0.2893968885773047],
#     'n_filters_conv': [0],
#     'neurons_dense': [0]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2020, 6, 10, 10, 4, 0, 508000),
#   'result': {'best_epoch': 4,
#    'eval_time': 1591783440.5087903,
#    'history': <keras.callbacks.callbacks.History at 0x7f1b56e0e828>,
#    'loss': 1.7766779472351075,
#    'model': <keras.engine.sequential.Sequential at 0x7f1b564d4f60>,
#    'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 0,
#   'version': 0},
#  {'book_time': datetime.datetime(2020, 6, 10, 10, 4, 0, 515000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dropout': [1], 'n_filters_conv': [1], 'neurons_dense': [1]},
#    'tid': 1,
#    'vals': {'dropout': [0.24602421986549994],
#     'n_filters_conv': [0],
#     'neurons_dense': [0]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2020, 6, 10, 10, 4, 25, 35000),
#   'result': {'best_epoch': 4,
#    'eval_time': 1591783465.035953,
#    'history': <keras.callbacks.callbacks.History at 0x7f1b561c8400>,
#    'loss': 1.6846457529067993,
#    'model': <keras.engine.sequential.Sequential at 0x7f1b564fa630>,
#    'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 1,
#   'version': 0},
#  {'book_time': datetime.datetime(2020, 6, 10, 10, 4, 25, 41000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dropout': [2], 'n_filters_conv': [2], 'neurons_dense': [2]},
#    'tid': 2,
#    'vals': {'dropout': [0.3893173611359977],
#     'n_filters_conv': [0],
#     'neurons_dense': [0]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2020, 6, 10, 10, 4, 49, 571000),
#   'result': {'best_epoch': 4,
#    'eval_time': 1591783489.5718048,
#    'history': <keras.callbacks.callbacks.History at 0x7f1b55f35d30>,
#    'loss': 1.7924710163116455,
#    'model': <keras.engine.sequential.Sequential at 0x7f1b5604a7f0>,
#    'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 2,
#   'version': 0},
#  {'book_time': datetime.datetime(2020, 6, 10, 10, 4, 49, 578000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dropout': [3], 'n_filters_conv': [3], 'neurons_dense': [3]},
#    'tid': 3,
#    'vals': {'dropout': [0.021743729494355657],
#     'n_filters_conv': [2],
#     'neurons_dense': [1]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2020, 6, 10, 10, 5, 46, 683000),
#   'result': {'best_epoch': 4,
#    'eval_time': 1591783546.683645,
#    'history': <keras.callbacks.callbacks.History at 0x7f1b55c277b8>,
#    'loss': 1.281806408214569,
#    'model': <keras.engine.sequential.Sequential at 0x7f1b55da2278>,
#    'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 3,
#   'version': 0},
#  {'book_time': datetime.datetime(2020, 6, 10, 10, 5, 46, 688000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dropout': [4], 'n_filters_conv': [4], 'neurons_dense': [4]},
#    'tid': 4,
#    'vals': {'dropout': [0.01841867440101863],
#     'n_filters_conv': [1],
#     'neurons_dense': [2]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2020, 6, 10, 10, 6, 22, 428000),
#   'result': {'best_epoch': 4,
#    'eval_time': 1591783582.428823,
#    'history': <keras.callbacks.callbacks.History at 0x7f1b55917320>,
#    'loss': 1.3524145696640015,
#    'model': <keras.engine.sequential.Sequential at 0x7f1b55af6588>,
#    'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 4,
#   'version': 0},
#  {'book_time': datetime.datetime(2020, 6, 10, 10, 6, 22, 435000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dropout': [5], 'n_filters_conv': [5], 'neurons_dense': [5]},
#    'tid': 5,
#    'vals': {'dropout': [0.34447763510219326],
#     'n_filters_conv': [2],
#     'neurons_dense': [0]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2020, 6, 10, 10, 7, 19, 17000),
#   'result': {'best_epoch': 4,
#    'eval_time': 1591783639.0169904,
#    'history': <keras.callbacks.callbacks.History at 0x7f1b55601c88>,
#    'loss': 1.4285307010650634,
#    'model': <keras.engine.sequential.Sequential at 0x7f1b556ac7f0>,
#    'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 5,
#   'version': 0},
#  {'book_time': datetime.datetime(2020, 6, 10, 10, 7, 19, 20000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dropout': [6], 'n_filters_conv': [6], 'neurons_dense': [6]},
#    'tid': 6,
#    'vals': {'dropout': [0.14084614019549763],
#     'n_filters_conv': [2],
#     'neurons_dense': [2]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2020, 6, 10, 10, 8, 17, 505000),
#   'result': {'best_epoch': 4,
#    'eval_time': 1591783697.5052671,
#    'history': <keras.callbacks.callbacks.History at 0x7f1b553768d0>,
#    'loss': 1.268199026298523,
#    'model': <keras.engine.sequential.Sequential at 0x7f1b554d8710>,
#    'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 6,
#   'version': 0},
#  {'book_time': datetime.datetime(2020, 6, 10, 10, 8, 17, 508000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dropout': [7], 'n_filters_conv': [7], 'neurons_dense': [7]},
#    'tid': 7,
#    'vals': {'dropout': [0.23636172256843885],
#     'n_filters_conv': [0],
#     'neurons_dense': [0]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2020, 6, 10, 10, 8, 40, 235000),
#   'result': {'best_epoch': 4,
#    'eval_time': 1591783720.235073,
#    'history': <keras.callbacks.callbacks.History at 0x7f1b551db5c0>,
#    'loss': 1.6936490482330322,
#    'model': <keras.engine.sequential.Sequential at 0x7f1b553a7da0>,
#    'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 7,
#   'version': 0},
#  {'book_time': datetime.datetime(2020, 6, 10, 10, 8, 40, 241000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dropout': [8], 'n_filters_conv': [8], 'neurons_dense': [8]},
#    'tid': 8,
#    'vals': {'dropout': [0.24152388614709397],
#     'n_filters_conv': [2],
#     'neurons_dense': [0]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2020, 6, 10, 10, 9, 36, 943000),
#   'result': {'best_epoch': 4,
#    'eval_time': 1591783776.943099,
#    'history': <keras.callbacks.callbacks.History at 0x7f1b54edd588>,
#    'loss': 1.3754857486724854,
#    'model': <keras.engine.sequential.Sequential at 0x7f1b5526d0f0>,
#    'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 8,
#   'version': 0},
#  {'book_time': datetime.datetime(2020, 6, 10, 10, 9, 36, 946000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dropout': [9], 'n_filters_conv': [9], 'neurons_dense': [9]},
#    'tid': 9,
#    'vals': {'dropout': [0.0808290105926876],
#     'n_filters_conv': [1],
#     'neurons_dense': [2]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2020, 6, 10, 10, 10, 12, 740000),
#   'result': {'best_epoch': 4,
#    'eval_time': 1591783812.7405298,
#    'history': <keras.callbacks.callbacks.History at 0x7f1b54bd0630>,
#    'loss': 1.3765917095184326,
#    'model': <keras.engine.sequential.Sequential at 0x7f1b54f08f98>,
#    'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 9,
#   'version': 0}]

# %% [markdown]
# ¿Por qué dice que best_epoch=4? Porque history está indexado en 0.

# %%
trials.trials[6]
# Out:
# {'book_time': datetime.datetime(2020, 6, 10, 10, 7, 19, 20000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#   'idxs': {'dropout': [6], 'n_filters_conv': [6], 'neurons_dense': [6]},
#   'tid': 6,
#   'vals': {'dropout': [0.14084614019549763],
#    'n_filters_conv': [2],
#    'neurons_dense': [2]},
#   'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2020, 6, 10, 10, 8, 17, 505000),
#  'result': {'best_epoch': 4,
#   'eval_time': 1591783697.5052671,
#   'history': <keras.callbacks.callbacks.History at 0x7f1b553768d0>,
#   'loss': 1.268199026298523,
#   'model': <keras.engine.sequential.Sequential at 0x7f1b554d8710>,
#   'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 6,
#  'version': 0}

# %%
trials.results
# Out:
# [{'best_epoch': 4,
#   'eval_time': 1591783440.5087903,
#   'history': <keras.callbacks.callbacks.History at 0x7f1b56e0e828>,
#   'loss': 1.7766779472351075,
#   'model': <keras.engine.sequential.Sequential at 0x7f1b564d4f60>,
#   'status': 'ok'},
#  {'best_epoch': 4,
#   'eval_time': 1591783465.035953,
#   'history': <keras.callbacks.callbacks.History at 0x7f1b561c8400>,
#   'loss': 1.6846457529067993,
#   'model': <keras.engine.sequential.Sequential at 0x7f1b564fa630>,
#   'status': 'ok'},
#  {'best_epoch': 4,
#   'eval_time': 1591783489.5718048,
#   'history': <keras.callbacks.callbacks.History at 0x7f1b55f35d30>,
#   'loss': 1.7924710163116455,
#   'model': <keras.engine.sequential.Sequential at 0x7f1b5604a7f0>,
#   'status': 'ok'},
#  {'best_epoch': 4,
#   'eval_time': 1591783546.683645,
#   'history': <keras.callbacks.callbacks.History at 0x7f1b55c277b8>,
#   'loss': 1.281806408214569,
#   'model': <keras.engine.sequential.Sequential at 0x7f1b55da2278>,
#   'status': 'ok'},
#  {'best_epoch': 4,
#   'eval_time': 1591783582.428823,
#   'history': <keras.callbacks.callbacks.History at 0x7f1b55917320>,
#   'loss': 1.3524145696640015,
#   'model': <keras.engine.sequential.Sequential at 0x7f1b55af6588>,
#   'status': 'ok'},
#  {'best_epoch': 4,
#   'eval_time': 1591783639.0169904,
#   'history': <keras.callbacks.callbacks.History at 0x7f1b55601c88>,
#   'loss': 1.4285307010650634,
#   'model': <keras.engine.sequential.Sequential at 0x7f1b556ac7f0>,
#   'status': 'ok'},
#  {'best_epoch': 4,
#   'eval_time': 1591783697.5052671,
#   'history': <keras.callbacks.callbacks.History at 0x7f1b553768d0>,
#   'loss': 1.268199026298523,
#   'model': <keras.engine.sequential.Sequential at 0x7f1b554d8710>,
#   'status': 'ok'},
#  {'best_epoch': 4,
#   'eval_time': 1591783720.235073,
#   'history': <keras.callbacks.callbacks.History at 0x7f1b551db5c0>,
#   'loss': 1.6936490482330322,
#   'model': <keras.engine.sequential.Sequential at 0x7f1b553a7da0>,
#   'status': 'ok'},
#  {'best_epoch': 4,
#   'eval_time': 1591783776.943099,
#   'history': <keras.callbacks.callbacks.History at 0x7f1b54edd588>,
#   'loss': 1.3754857486724854,
#   'model': <keras.engine.sequential.Sequential at 0x7f1b5526d0f0>,
#   'status': 'ok'},
#  {'best_epoch': 4,
#   'eval_time': 1591783812.7405298,
#   'history': <keras.callbacks.callbacks.History at 0x7f1b54bd0630>,
#   'loss': 1.3765917095184326,
#   'model': <keras.engine.sequential.Sequential at 0x7f1b54f08f98>,
#   'status': 'ok'}]

# %%
trials.losses()
# Out:
# [1.7766779472351075,
#  1.6846457529067993,
#  1.7924710163116455,
#  1.281806408214569,
#  1.3524145696640015,
#  1.4285307010650634,
#  1.268199026298523,
#  1.6936490482330322,
#  1.3754857486724854,
#  1.3765917095184326]

# %% [markdown]
# Qué os parece? mola eh? Así, podéis dejar vuestra configuración e iros a hacer algo más útil que andar variando parámetros hasta que encontréis la configuración adecuada.
#
# **Mejor que lo hagan por nosotros y que nos la encontremos automáticamente seleccionada!**
#
# Pero no tenemos por qué quedarnos aquí, podemos también variar el número de capas o si queremos conexiones residuales, por ejemplo! Sí, esto significa que podemos variar la **arquitectura** también!!
#
# Aquí tenéis un ejemplo muy completo: https://github.com/Vooban/Hyperopt-Keras-CNN-CIFAR-100
#
# Y aquí otro que quizá os parezca interesante:
#
# <img src="http://cdn.lizamayliza.com/storage/cache/images/003/636/Daffy-Duck-Money-eyes-feature,xlarge.1480369578.jpg" border="0" height="200">
#
# https://medium.com/machine-learning-world/neural-networks-for-algorithmic-trading-hyperparameters-optimization-cb2b4a29b8ee

# %% [markdown]
# ## 6.3 Algoritmos genéticos
#
# Quizás estéis pensando en que tras haber visto esto no necesitáis saber nada más, ya habéis encontrado algo que es la repera! Pues atentos porque lo que viene, pese a ser algo muy sencillo, es potentísimo, y os va encantar. Sí, estoy hablando de **los algoritmos genéticos**.
#
# En esencia, los algoritmos genéticos son un método de búsqueda meta-heurística inspirados en la evolución natural. Pertenecen a los algoritmos evolutivos, concretamente a los Algoritmos de búsqueda aleatoria guiada (Guided Random Search algorithms (Evolutionary Alg.)).
#
# Esto que os puede parecer chino, es muy sencillo. Vamos a entenderlos con un ejemplo:
#
# <img src="https://image.ibb.co/cJcQYJ/ga_problem.png" alt="ga_problem" border="0">
#
# Imaginad que tenemos un puzzle, y nos queda solo una pieza por encajar. Lo que pasa es que este puzzle es muy especial, porque nos permite fabricarnos nuestras propias piezas. Para ello, disponemos de varios mecanismos:
#
# * **combinar** partes de piezas (**crossover** o recombinación)
# * **modificar** determinadas partes de esas piezas (**mutación**)
# * **escoger** las mejores piezas de todas las que hemos hecho, para a partir de ellas, construir nuevas que sean mejores (**selección**)
#
# Entonces imaginaos que decidimos cortar 10 trozos de carton, que son nuestras 10 piezas iniciales con las que vamos a probar a ver si alguna encaja perfectamnte. Las probamos todas, y de esas 10, 5 encajan más o menos. Así que seleccionamos esas 5 y fabricamos nuevas a partir de ellas mediante los mecanismos explicados arriba:
#
# * de las 5 seleccionadas, sacamos 5 más combinando partes de dos de esas 5 originales escogiéndolas aleatoriamente
# * de las 5 originales, y las nuevas 5 que nos hemos creado, sacamos 5 más modificando ligeramente una de las puntas de la pieza
#
# Ahora resulta que tenemos 15 piezas, y nosotros queremos tener siempre 10, porque si no a la 5 vez que hiciéramos esto tendríamos una barbaridad de piezas!! Así que:
#
# * probamos nuestras 15 piezas y nos quedamos con la que mejor encaja, y luego 9 escogidas al azar
#
# Pues ya está, eso es lo que hace un algoritmo genético!! Ya sabéis cómo funcionan!! Sencillo, verdad? Pues no os hacéis una idea de lo potentes que son :-)
#
# Vamos a verlo un poco más concreto siguiendo con nuestro ejemplo:
#
# <img src="https://image.ibb.co/b7ySfy/geneticos_puzzle.png" alt="geneticos_puzzle" border="0">
#
# Como podéis ver:
#
# * cada pieza de nuestro conjunto de piezas (población) es un **cromosoma**
# * cada parte de nuestra pieza es un **gen**, por tanto, nuestro cromosoma tiene 4 genes
# * los posibles valores o configuraciones que puede tener cada gen se llama **alelo**
#
# Esto es exactamente igual que en biología! No os dije que estaban inspirados en la evolución natural? :-)
#
# Vale, pues vamos a ir relacionando estas palabrejas con nuestro ejemplo:
#
# * necesitamos encontrar la pieza correcta para nuestro hueco del puzzle
# * tenemos un conjunto inicial de piezas (**población**) que pueden encajar bien o no, no lo sabemos
# * comprobamos cómo de bien encajan estas piezas (usando la **función de fitness**)
# * si ninguna de las piezas encaja como nos gustaría, modificamos las piezas (con los operadores: **crossover** y **mutación**)
# * comprobamos como de bien encajan las piezas recien creadas (**función de fitness**)
# * seleccionamos las piezas que queremos aguantar para la próxima iteración (**selección**)
#
# * y volvemos a empezar! así, hasta que enocntremos una pieza que encaje con la precisión que nosotros queremos
#
# Venga, vamos a ponernos un poco más serios. Veamos el pseudo-algoritmo:
#
# **START**
#
# Generate the initial population
#
# Compute fitness
#
# **REPEAT**
#
#     Selection
#
#     Crossover
#
#     Mutation
#
#     Compute fitness
#
# **UNTIL** population has converged
#
# **STOP**
#
# Se entiende, no? Es exactamente lo mismo que los pasos que acabamos de hablar con el puzzle!!
#
# <img src="https://image.ibb.co/kQu7Ed/ga_workflow.png" alt="ga_workflow" border="0" width="600">
#
# Vale, y ahora llega lo interesante, cómo funcionan realmente?
#
# Tenemos que entender varios conceptos:
#
# * cómo se inicializa nuestra población
# * cómo funciona el crossover
# * cómo funciona la mutación
# * cómo funciona la seleccion
# * cómo podemos definir nuestra función de fitness
#
# Preparados? Vamos allá!

# %% [markdown]
# Lo primero es entender que cuando tenemos un problema en el mundo real y queremos solucionarlo en un ordenador, necesitamos **codificarlo** para que el ordenador lo entienda.
#
# Así, por ejemplo:
#
# * En el mundo real, el cromosoma es la pieza del puzzle. En el ordenador, el cromosoma es un vector con 4 valores (uno para indicar el tamaño de cada punta, donde positivo significa punta, negativo significa hueco hacia dentro de la pieza)
#
# Esto es a lo que se llama la codificación.
#
# Una vez sabido esto, vamos a ver cómo funcionan los operadores. Antes de nada, debéis saber que xisten muchos tipos de crossover, mutación y selección, pero aquí vamos a ver solo los más sencillos por temas de tiempo.
#
# Si estáis interesados en conocerlos más profundamente, en internet hay muchísimo material disponible. Podéis empezar aquí: https://www.tutorialspoint.com/genetic_algorithms/index.htm
#
# Vale, al turrón!
#
# <img src="https://image.ibb.co/hEwVHd/ga_operators.png" alt="ga_operators" border="0">
#
# **El crossover de un único punto (single-point crossover)**
#
# Nuestro cromosoma es la pieza de puzzle, que tiene los 4 genes que veis en la imagen. Pues el crossover simple sencillamente escoge un punto aleatoriamente de los 4 genes, y combina las partes en nuevos cromosomas, como veis en la imagen.
#
# Es importante que entendáis que el crossover **produce nuevos cromosomas**, puesto que tenemos los originales y los **recombinados**.
#
# **La mutación uniforme**
#
# La mutación uniforme consiste en que para cada cromosoma, lanzamos una moneda al aire. Si sale cara, modificamos un gen escogido aleatoriamente. ¿Qué valor le asignamos? Uno aleatorio dentro del rango que permite dicho gen.
#
# **La selección**
#
# Para la selección lo que se suele hacer es usar las fitness de los cromosomas (también llamados posibles **soluciones**). En este caso, vamos a ver la Stochastic Universal Sampling, que consiste en que construímos una gráfica de tipo tarta donde cada cromosoma ocupa un espacio que corresponde con su fitness. Después, establecemos N puntos fijos alrededor de la "tarta", donde N son el número de cromomsomas que queremos **seleccionar**. Después, se "gira la tarta", como si fuese la ruleta de la suerte, y los cromosomas a los que apuntan los puntos fijos son los seleccionados y pasan a la siguiente iteración.
#
# Si os fijáis, **los cromosomas no están ordenados de mayor a menor fitness**!!
#
# Esto es importante, puesto que si no, las probabilidades de seleccionar un cromosoma con una fitness alta y otro con una fitness baja serían más altas que de seleccionar dos con la fitness alta, ya que al estar los puntos de selección uno enfrente del otro, sería muy complicado seleccionar dos cromosomas con fitness parecidas.
#
# Este operador tiene varias formas de funcionar. Siguiendo con nuestro ejemplo de población de 10 cromosomas, las formas son:
#
# * Seleccionamos $N=10$ cromosomas, es decir, sustituimos la anterior población por una completamente nueva
# * Seleccionamos $N=n$ cromosomas, donde n<10. Es decir, sustituímos solo una parte de los crosomomas antiguos. El resto siguen jugando ;-D
#
# Vale, pues si seleccionamos los 10 está claro, pero si seleccionamos $n$, cómo elegimos cuales quitamos?
#
# Pues las dos formas más comunes son:
#
# * Quitamos los cromosomas más antiguos
# * Quitamos los cromosomas con peor fitness
#
# Ya por último, hay veces que seleccionamos al mejor cromosoma (o a los $k$ mejors) para que pase si o si a la siguiente iteración, es decir, hay *elitismo*. Hay que ir con cuidado con esto, puesto que aunque a priori parezca que el elitismo es lo mejor y que solo deberíamos quedarnos con los mejores, si lo hiciésemos nos estaríamos cargando una de las mayores virtudes de los genéticos: **que son capaces de escapar a mínimos locales!!!**
#
# Fijaos, aquí podéis ver en plena acción a un genético intentando decidir cual es la mejor configuración para un vehículo de 2 ruedas: http://rednuht.org/genetic_cars_2/
#
# Curioso, eh?
#
# Vale, pues ahora qué tal si implementamos un par de ejemplos nosotros?

# %%
# ejemplo simple de un GA donde tenemos que encontrar N números que sumen X
# https://lethain.com/genetic-algorithms-cool-name-damn-simple

from random import randint, random
from operator import add
from functools import reduce
import numpy as np

def individual(length, min, max):
    # creamos un individuo
    return [ randint(min,max) for x in range(length) ]

def population(count, length, min, max):   
    # creamos nuestra población
    # count: numero de invidiuos en la población
    # length: número de valores por individuo
    # min: minimo permitido para cada valor del individuo
    # max: maximo permitido para cada valor del individuo

    return [ individual(length, min, max) for x in range(count) ]

def fitness(individual, target):
    # calculamos la fitness de un individuo: más bajo es mejor
    
    sum = reduce(add, individual, 0)
    return abs(target-sum)

def grade(pop, target):
    # calculamos la media de la población entera
    summed = reduce(add, (fitness(x, target) for x in pop))
    return summed / (len(pop) * 1.0)
  
def find_best_solution(pop, target):
    # encuentra la mejor solución en la población actual y la imprime
    res = [fitness(x, target) for x in pop]
    res_min = np.min(res)
    res_min_idx = np.where(res == res_min)[0]
    for n in res_min_idx:
        print('Individual: ', n, 'Valores: ', *pop[n], ' Result: ', np.sum(pop[n]), 'Target; ', target)
    return res_min    

def evolve(pop, target, retain=0.2, random_select=0.05, mutate=0.01):
    graded = [ (fitness(x, target), x) for x in pop]
    graded = [ x[1] for x in sorted(graded)]
    retain_length = int(len(graded)*retain)
    parents = graded[:retain_length]
    
    # añadimos individuos aleatoriamente para promover la diversidad genética
    for individual in graded[retain_length:]:
        if random_select > random():
            parents.append(individual)
    
    # mutamos algunos
    for individual in parents:
        if mutate > random():
            pos_to_mutate = randint(0, len(individual)-1)
            individual[pos_to_mutate] = randint(i_min, i_max)
    
    # reproducimos (crossover) nuestros cromosomas (individuals, soluciones)
    parents_length = len(parents)
    desired_length = len(pop) - parents_length
    children = []
    while len(children) < desired_length:
        male = randint(0, parents_length-1)
        female = randint(0, parents_length-1)
        if male != female:
            male = parents[male]
            female = parents[female]
            half = round(len(male) / 2)
            child = male[:half] + female[half:]
            children.append(child)        
    parents.extend(children)
    return parents

# ejecutamos el GA
generations = 20
target = 108
p_count = 20
i_length = 5
i_min = 0
i_max = 100
error_accepted = 1
print('Inicializamos la población con 20 individuos.')
p = population(p_count, i_length, i_min, i_max)
print('Calculamos el fitness de esos 20 individuos.')
fitness_history = [grade(p, target),]
print('El mejor individuo de la población inicial es:')
find_best_solution(p, target)

print('Comienza la búsqueda:')
for i in range(generations):
    p = evolve(p, target, retain=0.2, random_select=0.2, mutate=0.4)
    res = grade(p, target)
    fitness_history.append(res)
    
    res_min = find_best_solution(p, target)
    print('Generación: ', i, ' Fitness medio de todos los individuos de la población:', res)
    
    if res_min < error_accepted:
      break
# Out:
# Inicializamos la población con 20 individuos.
# Calculamos el fitness de esos 20 individuos.
# El mejor individuo de la población inicial es:
# Individual:  16 Valores:  20 0 48 4 38  Result:  110 Target;  108
# Comienza la búsqueda:
# Individual:  0 Valores:  20 0 48 4 38  Result:  110 Target;  108
# Generación:  0  Fitness medio de todos los individuos de la población: 108.55
# Individual:  0 Valores:  20 0 71 4 38  Result:  133 Target;  108
# Generación:  1  Fitness medio de todos los individuos de la población: 114.1
# Individual:  8 Valores:  7 5 77 4 38  Result:  131 Target;  108
# Individual:  15 Valores:  7 5 77 4 38  Result:  131 Target;  108
# Generación:  2  Fitness medio de todos los individuos de la población: 58.9
# Individual:  2 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  5 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  6 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  17 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Generación:  3  Fitness medio de todos los individuos de la población: 31.7
# Individual:  0 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  1 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  2 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  7 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  10 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  12 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  13 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  18 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Generación:  4  Fitness medio de todos los individuos de la población: 24.1
# Individual:  0 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  3 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  4 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  11 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  13 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  15 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  18 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Generación:  5  Fitness medio de todos los individuos de la población: 38.65
# Individual:  1 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  2 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  3 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  4 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  6 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  8 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  9 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  10 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  12 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  13 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  14 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  15 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  16 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  18 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  19 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Generación:  6  Fitness medio de todos los individuos de la población: 19.35
# Individual:  0 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  7 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  9 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  11 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  12 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  13 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Generación:  7  Fitness medio de todos los individuos de la población: 28.9
# Individual:  0 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  1 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  2 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  3 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  9 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  13 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  14 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  15 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  16 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Generación:  8  Fitness medio de todos los individuos de la población: 14.75
# Individual:  1 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  4 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  6 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  8 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  9 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  10 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  11 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  13 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  15 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  16 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Individual:  17 Valores:  20 0 49 4 38  Result:  111 Target;  108
# Generación:  9  Fitness medio de todos los individuos de la población: 37.15
# Individual:  2 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  12 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Generación:  10  Fitness medio de todos los individuos de la población: 25.7
# Individual:  0 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  1 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  7 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  9 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Generación:  11  Fitness medio de todos los individuos de la población: 36.15
# Individual:  0 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  2 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  3 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  12 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  14 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  17 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  19 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Generación:  12  Fitness medio de todos los individuos de la población: 15.95
# Individual:  0 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  2 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  4 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  8 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  12 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  14 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Generación:  13  Fitness medio de todos los individuos de la población: 15.65
# Individual:  0 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  1 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  2 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  3 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  4 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  5 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  6 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  7 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  8 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  9 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  10 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  11 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  12 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  13 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  14 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  15 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  16 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  17 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  18 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  19 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Generación:  14  Fitness medio de todos los individuos de la población: 1.0
# Individual:  1 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  2 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  3 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  4 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  6 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  8 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  9 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  10 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  12 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  13 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  15 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  16 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  17 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  18 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Generación:  15  Fitness medio de todos los individuos de la población: 13.55
# Individual:  1 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  3 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  4 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  5 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  6 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  7 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  10 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  11 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  16 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  18 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  19 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Generación:  16  Fitness medio de todos los individuos de la población: 15.3
# Individual:  0 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  1 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  2 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  6 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  9 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  10 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  11 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  12 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  13 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  15 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  16 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  18 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Generación:  17  Fitness medio de todos los individuos de la población: 14.95
# Individual:  0 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  1 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  3 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  9 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  11 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  12 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  13 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  17 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  18 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  19 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Generación:  18  Fitness medio de todos los individuos de la población: 16.9
# Individual:  0 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  1 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  2 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  3 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  5 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  6 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  7 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  8 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  9 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  10 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  11 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  12 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  13 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  14 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  15 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  16 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  18 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Individual:  19 Valores:  20 0 49 4 34  Result:  107 Target;  108
# Generación:  19  Fitness medio de todos los individuos de la población: 4.7

# %%
# Ejemplo un poco más complejo de un GA que tiene que encontrar la cadena 'Hello Word!'
# http://www.obitko.com/tutorials/genetic-algorithms/ga-basic-description.php

import random

class GeneticAlgorithm(object):
    def __init__(self, genetics):
        self.genetics = genetics
        pass

    def run(self):
        population = self.genetics.initial()
        while True:
            fits_pops = [(self.genetics.fitness(ch),  ch) for ch in population]
            if self.genetics.check_stop(fits_pops): break
            population = self.next(fits_pops)
            pass
        return population

    def next(self, fits):
        parents_generator = self.genetics.parents(fits)
        size = len(fits)
        nexts = []
        while len(nexts) < size:
            parents = next(parents_generator)
            cross = random.random() < self.genetics.probability_crossover()
            children = self.genetics.crossover(parents) if cross else parents
            for ch in children:
                mutate = random.random() < self.genetics.probability_mutation()
                nexts.append(self.genetics.mutation(ch) if mutate else ch)
                pass
            pass
        return nexts[0:size]
    pass

class GeneticFunctions(object):
    def probability_crossover(self):
        # returns rate of occur crossover(0.0-1.0)
        return 1.0

    def probability_mutation(self):
        # returns rate of occur mutation(0.0-1.0)
        return 0.0

    def initial(self):
        # returns list of initial population        
        return []

    def fitness(self, chromosome):
        # returns domain fitness value of chromosome
        return len(chromosome)

    def check_stop(self, fits_populations):
        # stop run if returns True
        # - fits_populations: list of (fitness_value, chromosome)
        return False

    def parents(self, fits_populations):
        r"""generator of selected parents
        """
        gen = iter(sorted(fits_populations))
        while True:
            f1, ch1 = next(gen)
            f2, ch2 = next(gen)
            yield (ch1, ch2)
            pass
        return

    def crossover(self, parents):
        r"""breed children
        """
        return parents

    def mutation(self, chromosome):
        r"""mutate chromosome
        """
        return chromosome
    pass

if __name__ == "__main__":
    """
    example: Mapped guess prepared Text
    """
    class GuessText(GeneticFunctions):
        def __init__(self, target_text,
                     limit=200, size=400,
                     prob_crossover=0.9, prob_mutation=0.2):
            self.target = self.text2chromo(target_text)
            self.counter = 0

            self.limit = limit
            self.size = size
            self.prob_crossover = prob_crossover
            self.prob_mutation = prob_mutation
            pass

        # GeneticFunctions interface impls
        def probability_crossover(self):
            return self.prob_crossover

        def probability_mutation(self):
            return self.prob_mutation

        def initial(self):
            return [self.random_chromo() for j in range(self.size)]

        def fitness(self, chromo):
            # larger is better, matched == 0
            return -sum(abs(c - t) for c, t in zip(chromo, self.target))

        def check_stop(self, fits_populations):
            self.counter += 1
            if self.counter % 10 == 0:
                best_match = list(sorted(fits_populations))[-1][1]
                fits = [f for f, ch in fits_populations]
                best = max(fits)
                worst = min(fits)
                ave = sum(fits) / len(fits)
                print(
                    "[G %3d] score=(%4d, %4d, %4d): %r" %
                    (self.counter, best, ave, worst,
                     self.chromo2text(best_match)))
                pass
            return self.counter >= self.limit

        def parents(self, fits_populations):
            while True:
                father = self.tournament(fits_populations)
                mother = self.tournament(fits_populations)
                yield (father, mother)
                pass
            pass

        def crossover(self, parents):
            father, mother = parents
            index1 = random.randint(1, len(self.target) - 2)
            index2 = random.randint(1, len(self.target) - 2)
            if index1 > index2: index1, index2 = index2, index1
            child1 = father[:index1] + mother[index1:index2] + father[index2:]
            child2 = mother[:index1] + father[index1:index2] + mother[index2:]
            return (child1, child2)

        def mutation(self, chromosome):
            index = random.randint(0, len(self.target) - 1)
            vary = random.randint(-5, 5)
            mutated = list(chromosome)
            mutated[index] += vary
            return mutated

        # internals
        def tournament(self, fits_populations):
            alicef, alice = self.select_random(fits_populations)
            bobf, bob = self.select_random(fits_populations)
            return alice if alicef > bobf else bob

        def select_random(self, fits_populations):
            return fits_populations[random.randint(0, len(fits_populations)-1)]

        def text2chromo(self, text):
            return [ord(ch) for ch in text]
        def chromo2text(self, chromo):
            return "".join(chr(max(1, min(ch, 255))) for ch in chromo)

        def random_chromo(self):
            return [random.randint(1, 255) for i in range(len(self.target))]
        pass

    GeneticAlgorithm(GuessText("Hello World!")).run()
    pass
# Out:
# [G  10] score=(-175, -330, -541): '/x9hk"Tx\x88aS)'
# [G  20] score=( -74, -120, -175): '7imhk"T~rrt\x1f'
# [G  30] score=( -50,  -63,  -82): ':cmhk"Turnn\x1f'
# [G  40] score=( -28,  -42,  -59): '?cmlk"Wqrmi\x1f'
# [G  50] score=( -18,  -24,  -33): 'Dcmlo Wqrni\x1f'
# [G  60] score=(  -7,  -13,  -23): 'Demlo World\x1f'
# [G  70] score=(  -2,   -4,  -13): 'Hemlo Wormd!'
# [G  80] score=(   0,   -2,   -8): 'Hello World!'
# [G  90] score=(   0,    0,   -6): 'Hello World!'
# [G 100] score=(   0,    0,   -9): 'Hello World!'
# [G 110] score=(   0,    0,   -8): 'Hello World!'
# [G 120] score=(   0,    0,   -5): 'Hello World!'
# [G 130] score=(   0,    0,   -5): 'Hello World!'
# [G 140] score=(   0,    0,   -5): 'Hello World!'
# [G 150] score=(   0,    0,   -9): 'Hello World!'
# [G 160] score=(   0,    0,   -6): 'Hello World!'
# [G 170] score=(   0,    0,   -6): 'Hello World!'
# [G 180] score=(   0,    0,   -8): 'Hello World!'
# [G 190] score=(   0,    0,   -6): 'Hello World!'
# [G 200] score=(   0,    0,   -8): 'Hello World!'

# %% [markdown]
# Fijaos como es capaz de llegar a la cadena "Hello World!" tras unas pocas generaciones!
#
# Y ahora, vamos a verlo aplicado a una red neuronal. Para ello, vamos a hacer uso de una implementación disponible en Github: https://github.com/jliphard/DeepEvolve
#
# Para ello, vamos a clonar un repositorio con git que tiene implementado un GA para evolucionar los hiperparámetros y arquitectura de una red neuronal:

# %%
# !rm -rf DeepEvolve
# !git clone https://github.com/jliphard/DeepEvolve.git
# Out:
# Cloning into 'DeepEvolve'...
# remote: Enumerating objects: 160, done.
# remote: Total 160 (delta 0), reused 0 (delta 0), pack-reused 160
# Receiving objects: 100% (160/160), 1.52 MiB | 1.42 MiB/s, done.
# Resolving deltas: 100% (84/84), done.

# %%
# !ls
# Out:
# DeepEvolve  sample_data

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (4.41.1)

# %% [markdown]
# Quiero que veáis los parámetros entre los que va a buscar hasta encontrar la mejor combinación posible:

# %%
if dataset == 'mnist_cnn':
        generations = 8 # Number of times to evolve the population.
        all_possible_genes = {
            'nb_neurons': [16, 32, 64, 128],
            'nb_layers':  [1, 2, 3, 4 ,5],
            'activation': ['relu', 'elu', 'tanh', 'sigmoid', 'hard_sigmoid','softplus','linear'],
            'optimizer':  ['rmsprop', 'adam', 'sgd', 'adagrad','adadelta', 'adamax', 'nadam']
        }

# %% [markdown]
# Y ahora ejecutamos nuestro algoritmo genético:

# %%
# !python DeepEvolve/main.py
# Out:
# Using TensorFlow backend.
# 2020-06-10 10:24:27.300431: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ***Dataset: cifar10_cnn
# ***Evolving for 8 generations with population size = 30***
# 06/10/2020 10:24:29 AM - INFO - ***generate(generations, population, all_possible_genes, dataset)***
# 06/10/2020 10:24:29 AM - INFO - ***Now in generation 1 of 8***
# 06/10/2020 10:24:29 AM - INFO - --------------------------------------------------------------------------------
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 2, 'activation': 'softplus', 'optimizer': 'adagrad', 'nb_neurons': [64, 16, 16, 16, 16, 128]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 1
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: 8577f2cf268247b5ceb1582a76d0ddab
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 4, 'activation': 'tanh', 'optimizer': 'sgd', 'nb_neurons': [16, 64, 16, 16, 64, 32]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 2
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: b305fe2c628a4dc4a27dda51f132d38e
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 2, 'activation': 'sigmoid', 'optimizer': 'rmsprop', 'nb_neurons': [64, 32, 32, 64, 64, 32]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 3
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: b597780b7bf74005cae1b61fdb71a42f
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 5, 'activation': 'linear', 'optimizer': 'adamax', 'nb_neurons': [32, 32, 64, 16, 128, 64]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 4
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: 7f7ba89a998c8c116c6759d64d79a38a
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 3, 'activation': 'softplus', 'optimizer': 'adagrad', 'nb_neurons': [16, 128, 32, 16, 128, 32]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 5
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: 2285f9ee25ef8fea15c33d85ba2cc958
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 1, 'activation': 'linear', 'optimizer': 'adamax', 'nb_neurons': [32, 16, 16, 16, 128, 128]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 6
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: 3b193de51a573be511a08dd1a4b884c2
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 2, 'activation': 'linear', 'optimizer': 'rmsprop', 'nb_neurons': [16, 128, 16, 32, 16, 128]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 7
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: 425a591b8fe3f117d2794bda73c76354
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 5, 'activation': 'softplus', 'optimizer': 'nadam', 'nb_neurons': [32, 16, 128, 16, 32, 128]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 8
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: af710694dee89ead47a3be33ff745f10
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 3, 'activation': 'linear', 'optimizer': 'sgd', 'nb_neurons': [64, 16, 64, 32, 16, 32]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 9
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: c4e8eb4c32d6ea4917417c1ee601c957
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 1, 'activation': 'elu', 'optimizer': 'rmsprop', 'nb_neurons': [16, 32, 64, 32, 16, 16]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 10
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: 831880f9f622c6b1b39d84b7558bd7c7
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 4, 'activation': 'elu', 'optimizer': 'adadelta', 'nb_neurons': [16, 16, 128, 64, 64, 128]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 11
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: b884462d4d2302ffb776c3677e3d101b
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 2, 'activation': 'sigmoid', 'optimizer': 'sgd', 'nb_neurons': [64, 128, 32, 32, 64, 64]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 12
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: 2abf0c7115c9308dd3be7c286401ac1d
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 1, 'activation': 'linear', 'optimizer': 'adadelta', 'nb_neurons': [32, 32, 64, 64, 128, 64]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 13
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: adcb9a4fede7c469a1cf33e860a9121d
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 2, 'activation': 'softplus', 'optimizer': 'adam', 'nb_neurons': [64, 64, 128, 32, 64, 16]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 14
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: 57cce1f1033f4e3eb37975c3c1ad1df0
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 3, 'activation': 'linear', 'optimizer': 'adamax', 'nb_neurons': [128, 16, 128, 16, 32, 32]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 15
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: 791e08b060e22b1666a17366d886c076
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 5, 'activation': 'sigmoid', 'optimizer': 'adam', 'nb_neurons': [64, 64, 64, 32, 16, 64]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 16
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: 801a554c4f79b0c1231ac5228f87fa40
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 4, 'activation': 'linear', 'optimizer': 'adam', 'nb_neurons': [128, 64, 128, 16, 64, 32]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 17
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: 56e56c26a56cdcf88e0332af3bff4a82
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 5, 'activation': 'relu', 'optimizer': 'sgd', 'nb_neurons': [128, 128, 16, 16, 16, 128]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 18
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: 5290a383280917ba619a5bc8fefa8b16
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 5, 'activation': 'relu', 'optimizer': 'adam', 'nb_neurons': [64, 32, 32, 32, 16, 64]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 19
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: 2fc4e7858c008f374ac680fdd66d4550
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 1, 'activation': 'tanh', 'optimizer': 'adagrad', 'nb_neurons': [64, 128, 32, 32, 16, 16]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 20
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: b8d0d31583f585a99a8a04bbbfd74c64
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 4, 'activation': 'sigmoid', 'optimizer': 'adagrad', 'nb_neurons': [128, 16, 16, 128, 128, 16]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 21
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: 39365a8a76fb1372ec63da5fa748b968
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 3, 'activation': 'linear', 'optimizer': 'nadam', 'nb_neurons': [16, 32, 64, 128, 128, 32]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 22
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: 7182416123620dcc1a43bd0707999455
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 1, 'activation': 'relu', 'optimizer': 'adadelta', 'nb_neurons': [128, 32, 16, 32, 64, 32]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 23
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: 7b8aa5a68784c53d7ee8e478d6614c64
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 4, 'activation': 'elu', 'optimizer': 'rmsprop', 'nb_neurons': [16, 32, 32, 64, 32, 16]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 24
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: 1a3148376d47574806e15ffb5670a28a
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 5, 'activation': 'hard_sigmoid', 'optimizer': 'nadam', 'nb_neurons': [16, 32, 32, 64, 16, 32]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 25
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: be5090871577d240f7766ecd8e00d9a9
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 4, 'activation': 'sigmoid', 'optimizer': 'sgd', 'nb_neurons': [16, 16, 32, 128, 32, 32]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 26
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: 9cdf1f54b400c7797e84d49b9de783f7
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 5, 'activation': 'sigmoid', 'optimizer': 'sgd', 'nb_neurons': [16, 128, 32, 128, 32, 128]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 27
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: ec8878ca8fd730651d0a4bc8264bc9a3
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 2, 'activation': 'linear', 'optimizer': 'adamax', 'nb_neurons': [128, 16, 64, 128, 32, 16]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 28
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: 1fe7e76d55d5034ff613dace47bd47d2
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 3, 'activation': 'softplus', 'optimizer': 'adamax', 'nb_neurons': [128, 32, 16, 16, 64, 64]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 29
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: 762629e7ad98540122c35f85e788493d
# 06/10/2020 10:24:29 AM - INFO - {'nb_layers': 3, 'activation': 'tanh', 'optimizer': 'adamax', 'nb_neurons': [128, 128, 32, 128, 16, 16]}
# 06/10/2020 10:24:29 AM - INFO - Acc: 0.00%
# 06/10/2020 10:24:29 AM - INFO - UniID: 30
# 06/10/2020 10:24:29 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:24:29 AM - INFO - Gen: 1
# 06/10/2020 10:24:29 AM - INFO - Hash: e1bc46847c309b885d0b2874876d73ab
# 06/10/2020 10:24:29 AM - INFO - ***train_networks(networks, dataset)***
#   0% 0/30 [00:00<?, ?it/s]06/10/2020 10:24:29 AM - INFO - Getting Keras datasets
# 06/10/2020 10:24:29 AM - INFO - Compling Keras model
# 06/10/2020 10:24:29 AM - INFO - Architecture:[64, 16, 16, 16, 16, 128],softplus,adagrad,2
# 2020-06-10 10:24:29.686710: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-06-10 10:24:29.689811: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-10 10:24:29.690273: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2020-06-10 10:24:29.690316: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-10 10:24:29.692334: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-06-10 10:24:29.693998: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-06-10 10:24:29.694394: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-06-10 10:24:29.696206: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-06-10 10:24:29.697077: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-06-10 10:24:29.701116: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-06-10 10:24:29.701219: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-10 10:24:29.701669: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-10 10:24:29.702119: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-06-10 10:24:29.707103: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2200000000 Hz
# 2020-06-10 10:24:29.707510: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1444bc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-06-10 10:24:29.707549: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-06-10 10:24:29.754782: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-10 10:24:29.755337: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1444d80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-06-10 10:24:29.755374: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2020-06-10 10:24:29.755675: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-10 10:24:29.756071: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2020-06-10 10:24:29.756142: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-10 10:24:29.756207: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-06-10 10:24:29.756252: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-06-10 10:24:29.756291: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-06-10 10:24:29.756325: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-06-10 10:24:29.756359: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-06-10 10:24:29.756393: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-06-10 10:24:29.756513: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-10 10:24:29.756939: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-10 10:24:29.757303: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-06-10 10:24:29.757356: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-10 10:24:30.171304: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-06-10 10:24:30.171376: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2020-06-10 10:24:30.171398: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2020-06-10 10:24:30.171715: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-10 10:24:30.172252: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-10 10:24:30.172703: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-06-10 10:24:30.172770: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 2562 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 2020-06-10 10:24:31.008559: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-06-10 10:24:31.199564: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 50000/50000 [==============================] - 7s 150us/step - loss: 2.3646 - accuracy: 0.1143 - val_loss: 2.2135 - val_accuracy: 0.1770
# Epoch 2/4
# 50000/50000 [==============================] - 6s 122us/step - loss: 2.1750 - accuracy: 0.1918 - val_loss: 2.0519 - val_accuracy: 0.2702
# Epoch 3/4
# 50000/50000 [==============================] - 6s 121us/step - loss: 2.0905 - accuracy: 0.2374 - val_loss: 1.9915 - val_accuracy: 0.2882
# Epoch 4/4
# 50000/50000 [==============================] - 6s 122us/step - loss: 2.0459 - accuracy: 0.2553 - val_loss: 1.9522 - val_accuracy: 0.3115
# Test loss: 1.9521521991729736
# Test accuracy: 0.31150001287460327
#   3% 1/30 [00:28<13:47, 28.54s/it]06/10/2020 10:24:57 AM - INFO - Getting Keras datasets
# 06/10/2020 10:24:58 AM - INFO - Compling Keras model
# 06/10/2020 10:24:58 AM - INFO - Architecture:[16, 64, 16, 16, 64, 32],tanh,sgd,4
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 6s 111us/step - loss: 2.2118 - accuracy: 0.1711 - val_loss: 2.0347 - val_accuracy: 0.2795
# Epoch 2/4
# 50000/50000 [==============================] - 5s 100us/step - loss: 2.0422 - accuracy: 0.2346 - val_loss: 1.8834 - val_accuracy: 0.3227
# Epoch 3/4
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.9375 - accuracy: 0.2717 - val_loss: 1.8315 - val_accuracy: 0.3477
# Epoch 4/4
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.8771 - accuracy: 0.2980 - val_loss: 1.7831 - val_accuracy: 0.3529
# Test loss: 1.7830590976715088
# Test accuracy: 0.3528999984264374
#   7% 2/30 [00:51<12:30, 26.80s/it]06/10/2020 10:25:20 AM - INFO - Getting Keras datasets
# 06/10/2020 10:25:20 AM - INFO - Compling Keras model
# 06/10/2020 10:25:20 AM - INFO - Architecture:[64, 32, 32, 64, 64, 32],sigmoid,rmsprop,2
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 6s 129us/step - loss: 2.3068 - accuracy: 0.0972 - val_loss: 2.3051 - val_accuracy: 0.1000
# Epoch 2/4
# 50000/50000 [==============================] - 6s 123us/step - loss: 2.2451 - accuracy: 0.1483 - val_loss: 2.0439 - val_accuracy: 0.2625
# Epoch 3/4
# 50000/50000 [==============================] - 6s 122us/step - loss: 2.0551 - accuracy: 0.2535 - val_loss: 1.9222 - val_accuracy: 0.3320
# Epoch 4/4
# 50000/50000 [==============================] - 6s 123us/step - loss: 1.9598 - accuracy: 0.2853 - val_loss: 1.8425 - val_accuracy: 0.3456
# Test loss: 1.8424888214111328
# Test accuracy: 0.3456000089645386
#  10% 3/30 [01:18<12:06, 26.90s/it]06/10/2020 10:25:47 AM - INFO - Getting Keras datasets
# 06/10/2020 10:25:47 AM - INFO - Compling Keras model
# 06/10/2020 10:25:47 AM - INFO - Architecture:[32, 32, 64, 16, 128, 64],linear,adamax,5
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 6s 122us/step - loss: 1.8264 - accuracy: 0.3310 - val_loss: 1.5321 - val_accuracy: 0.4421
# Epoch 2/4
# 50000/50000 [==============================] - 5s 107us/step - loss: 1.5422 - accuracy: 0.4464 - val_loss: 1.3633 - val_accuracy: 0.5123
# Epoch 3/4
# 50000/50000 [==============================] - 5s 107us/step - loss: 1.4449 - accuracy: 0.4863 - val_loss: 1.3452 - val_accuracy: 0.5102
# Epoch 4/4
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.3931 - accuracy: 0.5109 - val_loss: 1.2358 - val_accuracy: 0.5661
# Test loss: 1.2358469451904297
# Test accuracy: 0.566100001335144
#  13% 4/30 [01:43<11:22, 26.26s/it]06/10/2020 10:26:12 AM - INFO - Getting Keras datasets
# 06/10/2020 10:26:12 AM - INFO - Compling Keras model
# 06/10/2020 10:26:12 AM - INFO - Architecture:[16, 128, 32, 16, 128, 32],softplus,adagrad,3
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 6s 130us/step - loss: 2.3477 - accuracy: 0.0994 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 2/4
# 50000/50000 [==============================] - 6s 124us/step - loss: 2.3027 - accuracy: 0.0982 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 3/4
# 50000/50000 [==============================] - 6s 122us/step - loss: 2.3027 - accuracy: 0.1000 - val_loss: 2.3026 - val_accuracy: 0.1000
# Test loss: 2.302593739318848
# Test accuracy: 0.10000000149011612
#  17% 5/30 [02:04<10:17, 24.71s/it]06/10/2020 10:26:33 AM - INFO - Getting Keras datasets
# 06/10/2020 10:26:33 AM - INFO - Compling Keras model
# 06/10/2020 10:26:33 AM - INFO - Architecture:[32, 16, 16, 16, 128, 128],linear,adamax,1
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 4s 86us/step - loss: 1.8115 - accuracy: 0.3923 - val_loss: 1.5137 - val_accuracy: 0.4738
# Epoch 2/4
# 50000/50000 [==============================] - 4s 83us/step - loss: 1.5197 - accuracy: 0.4705 - val_loss: 1.4097 - val_accuracy: 0.5139
# Epoch 3/4
# 50000/50000 [==============================] - 4s 85us/step - loss: 1.4314 - accuracy: 0.5029 - val_loss: 1.3474 - val_accuracy: 0.5330
# Epoch 4/4
# 50000/50000 [==============================] - 4s 85us/step - loss: 1.3592 - accuracy: 0.5305 - val_loss: 1.2958 - val_accuracy: 0.5505
# Test loss: 1.295801923942566
# Test accuracy: 0.5504999756813049
#  20% 6/30 [02:23<09:11, 22.98s/it]06/10/2020 10:26:52 AM - INFO - Getting Keras datasets
# 06/10/2020 10:26:52 AM - INFO - Compling Keras model
# 06/10/2020 10:26:52 AM - INFO - Architecture:[16, 128, 16, 32, 16, 128],linear,rmsprop,2
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 6s 112us/step - loss: 1.6012 - accuracy: 0.4450 - val_loss: 1.3336 - val_accuracy: 0.5405
# Epoch 2/4
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.2850 - accuracy: 0.5563 - val_loss: 1.1581 - val_accuracy: 0.6040
# Epoch 3/4
# 50000/50000 [==============================] - 5s 107us/step - loss: 1.2001 - accuracy: 0.5863 - val_loss: 1.1424 - val_accuracy: 0.6013
# Epoch 4/4
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.1528 - accuracy: 0.6017 - val_loss: 1.1209 - val_accuracy: 0.6159
# Test loss: 1.1208813467025758
# Test accuracy: 0.6158999800682068
#  23% 7/30 [02:47<08:55, 23.28s/it]06/10/2020 10:27:16 AM - INFO - Getting Keras datasets
# 06/10/2020 10:27:16 AM - INFO - Compling Keras model
# 06/10/2020 10:27:16 AM - INFO - Architecture:[32, 16, 128, 16, 32, 128],softplus,nadam,5
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 8s 151us/step - loss: 2.3489 - accuracy: 0.0991 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 2/4
# 50000/50000 [==============================] - 6s 130us/step - loss: 2.3032 - accuracy: 0.0963 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 3/4
# 50000/50000 [==============================] - 6s 129us/step - loss: 2.3030 - accuracy: 0.0977 - val_loss: 2.3026 - val_accuracy: 0.1000
# Test loss: 2.3026436836242676
# Test accuracy: 0.10000000149011612
#  27% 8/30 [03:10<08:35, 23.42s/it]06/10/2020 10:27:40 AM - INFO - Getting Keras datasets
# 06/10/2020 10:27:40 AM - INFO - Compling Keras model
# 06/10/2020 10:27:40 AM - INFO - Architecture:[64, 16, 64, 32, 16, 32],linear,sgd,3
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 6s 117us/step - loss: 2.2049 - accuracy: 0.1755 - val_loss: 2.0384 - val_accuracy: 0.2688
# Epoch 2/4
# 50000/50000 [==============================] - 6s 110us/step - loss: 2.0172 - accuracy: 0.2668 - val_loss: 1.8651 - val_accuracy: 0.3522
# Epoch 3/4
# 50000/50000 [==============================] - 5s 110us/step - loss: 1.9123 - accuracy: 0.3069 - val_loss: 1.7460 - val_accuracy: 0.3972
# Epoch 4/4
# 50000/50000 [==============================] - 5s 110us/step - loss: 1.8380 - accuracy: 0.3349 - val_loss: 1.6910 - val_accuracy: 0.4099
# Test loss: 1.6909524448394775
# Test accuracy: 0.4099000096321106
#  30% 9/30 [03:35<08:18, 23.75s/it]06/10/2020 10:28:04 AM - INFO - Getting Keras datasets
# 06/10/2020 10:28:04 AM - INFO - Compling Keras model
# 06/10/2020 10:28:04 AM - INFO - Architecture:[16, 32, 64, 32, 16, 16],elu,rmsprop,1
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 4s 71us/step - loss: 1.9180 - accuracy: 0.3092 - val_loss: 1.6523 - val_accuracy: 0.4044
# Epoch 2/4
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.7093 - accuracy: 0.3864 - val_loss: 1.5338 - val_accuracy: 0.4647
# Epoch 3/4
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.6450 - accuracy: 0.4080 - val_loss: 1.5308 - val_accuracy: 0.4783
# Epoch 4/4
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.5972 - accuracy: 0.4265 - val_loss: 1.4272 - val_accuracy: 0.5120
# Test loss: 1.4272474119186402
# Test accuracy: 0.5120000243186951
#  33% 10/30 [03:51<07:06, 21.31s/it]06/10/2020 10:28:20 AM - INFO - Getting Keras datasets
# 06/10/2020 10:28:20 AM - INFO - Compling Keras model
# 06/10/2020 10:28:20 AM - INFO - Architecture:[16, 16, 128, 64, 64, 128],elu,adadelta,4
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 6s 122us/step - loss: 1.8116 - accuracy: 0.3496 - val_loss: 1.5298 - val_accuracy: 0.4601
# Epoch 2/4
# 50000/50000 [==============================] - 6s 111us/step - loss: 1.5153 - accuracy: 0.4612 - val_loss: 1.3340 - val_accuracy: 0.5252
# Epoch 3/4
# 50000/50000 [==============================] - 6s 111us/step - loss: 1.4142 - accuracy: 0.5003 - val_loss: 1.2721 - val_accuracy: 0.5425
# Epoch 4/4
# 50000/50000 [==============================] - 6s 111us/step - loss: 1.3592 - accuracy: 0.5212 - val_loss: 1.2312 - val_accuracy: 0.5665
# Test loss: 1.2311996786117554
# Test accuracy: 0.5665000081062317
#  37% 11/30 [04:16<07:08, 22.54s/it]06/10/2020 10:28:45 AM - INFO - Getting Keras datasets
# 06/10/2020 10:28:46 AM - INFO - Compling Keras model
# 06/10/2020 10:28:46 AM - INFO - Architecture:[64, 128, 32, 32, 64, 64],sigmoid,sgd,2
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 8s 165us/step - loss: 2.3210 - accuracy: 0.0989 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 2/4
# 50000/50000 [==============================] - 8s 157us/step - loss: 2.3041 - accuracy: 0.0995 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 3/4
# 50000/50000 [==============================] - 8s 158us/step - loss: 2.3036 - accuracy: 0.1000 - val_loss: 2.3026 - val_accuracy: 0.1000
# Test loss: 2.3025844718933106
# Test accuracy: 0.10000000149011612
#  40% 12/30 [04:42<07:05, 23.65s/it]06/10/2020 10:29:11 AM - INFO - Getting Keras datasets
# 06/10/2020 10:29:12 AM - INFO - Compling Keras model
# 06/10/2020 10:29:12 AM - INFO - Architecture:[32, 32, 64, 64, 128, 64],linear,adadelta,1
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 4s 83us/step - loss: 1.7944 - accuracy: 0.3786 - val_loss: 1.5342 - val_accuracy: 0.4718
# Epoch 2/4
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.5434 - accuracy: 0.4639 - val_loss: 1.4012 - val_accuracy: 0.5129
# Epoch 3/4
# 50000/50000 [==============================] - 4s 79us/step - loss: 1.4507 - accuracy: 0.4996 - val_loss: 1.4126 - val_accuracy: 0.5080
# Epoch 4/4
# 50000/50000 [==============================] - 4s 79us/step - loss: 1.3887 - accuracy: 0.5221 - val_loss: 1.3634 - val_accuracy: 0.5252
# Test loss: 1.3633832569122315
# Test accuracy: 0.5252000093460083
#  43% 13/30 [05:00<06:13, 21.97s/it]06/10/2020 10:29:29 AM - INFO - Getting Keras datasets
# 06/10/2020 10:29:30 AM - INFO - Compling Keras model
# 06/10/2020 10:29:30 AM - INFO - Architecture:[64, 64, 128, 32, 64, 16],softplus,adam,2
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 8s 153us/step - loss: 2.3111 - accuracy: 0.0987 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 2/4
# 50000/50000 [==============================] - 7s 145us/step - loss: 2.3027 - accuracy: 0.1000 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 3/4
# 50000/50000 [==============================] - 7s 145us/step - loss: 2.3027 - accuracy: 0.0964 - val_loss: 2.3026 - val_accuracy: 0.1000
# Test loss: 2.302594362640381
# Test accuracy: 0.10000000149011612
#  47% 14/30 [05:25<06:04, 22.81s/it]06/10/2020 10:29:54 AM - INFO - Getting Keras datasets
# 06/10/2020 10:29:55 AM - INFO - Compling Keras model
# 06/10/2020 10:29:55 AM - INFO - Architecture:[128, 16, 128, 16, 32, 32],linear,adamax,3
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 9s 179us/step - loss: 1.7640 - accuracy: 0.3684 - val_loss: 1.4084 - val_accuracy: 0.5195
# Epoch 2/4
# 50000/50000 [==============================] - 8s 169us/step - loss: 1.5116 - accuracy: 0.4702 - val_loss: 1.3086 - val_accuracy: 0.5549
# Epoch 3/4
# 50000/50000 [==============================] - 8s 168us/step - loss: 1.4141 - accuracy: 0.5077 - val_loss: 1.1927 - val_accuracy: 0.5961
# Epoch 4/4
# 50000/50000 [==============================] - 8s 169us/step - loss: 1.3718 - accuracy: 0.5214 - val_loss: 1.2269 - val_accuracy: 0.5768
# Test loss: 1.2268737939834595
# Test accuracy: 0.5767999887466431
#  50% 15/30 [06:02<06:45, 27.00s/it]06/10/2020 10:30:31 AM - INFO - Getting Keras datasets
# 06/10/2020 10:30:31 AM - INFO - Compling Keras model
# 06/10/2020 10:30:31 AM - INFO - Architecture:[64, 64, 64, 32, 16, 64],sigmoid,adam,5
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 9s 184us/step - loss: 2.3792 - accuracy: 0.0997 - val_loss: 2.3030 - val_accuracy: 0.1000
# Epoch 2/4
# 50000/50000 [==============================] - 9s 171us/step - loss: 2.3144 - accuracy: 0.1010 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 3/4
# 50000/50000 [==============================] - 9s 171us/step - loss: 2.3088 - accuracy: 0.1012 - val_loss: 2.3028 - val_accuracy: 0.1000
# Test loss: 2.3028323265075685
# Test accuracy: 0.10000000149011612
#  53% 16/30 [06:31<06:27, 27.67s/it]06/10/2020 10:31:00 AM - INFO - Getting Keras datasets
# 06/10/2020 10:31:01 AM - INFO - Compling Keras model
# 06/10/2020 10:31:01 AM - INFO - Architecture:[128, 64, 128, 16, 64, 32],linear,adam,4
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 12s 236us/step - loss: 1.8237 - accuracy: 0.3382 - val_loss: 1.4166 - val_accuracy: 0.5106
# Epoch 2/4
# 50000/50000 [==============================] - 11s 224us/step - loss: 1.5179 - accuracy: 0.4626 - val_loss: 1.3051 - val_accuracy: 0.5618
# Epoch 3/4
# 50000/50000 [==============================] - 11s 226us/step - loss: 1.4209 - accuracy: 0.4993 - val_loss: 1.2609 - val_accuracy: 0.5527
# Epoch 4/4
# 50000/50000 [==============================] - 11s 224us/step - loss: 1.3641 - accuracy: 0.5215 - val_loss: 1.1413 - val_accuracy: 0.6077
# Test loss: 1.1413324125289916
# Test accuracy: 0.607699990272522
#  57% 17/30 [07:20<07:20, 33.92s/it]06/10/2020 10:31:49 AM - INFO - Getting Keras datasets
# 06/10/2020 10:31:49 AM - INFO - Compling Keras model
# 06/10/2020 10:31:49 AM - INFO - Architecture:[128, 128, 16, 16, 16, 128],relu,sgd,5
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 13s 260us/step - loss: 2.3016 - accuracy: 0.1064 - val_loss: 2.2985 - val_accuracy: 0.1262
# Epoch 2/4
# 50000/50000 [==============================] - 12s 245us/step - loss: 2.2962 - accuracy: 0.1182 - val_loss: 2.2855 - val_accuracy: 0.1810
# Epoch 3/4
# 50000/50000 [==============================] - 12s 246us/step - loss: 2.2620 - accuracy: 0.1521 - val_loss: 2.1984 - val_accuracy: 0.1901
# Epoch 4/4
# 50000/50000 [==============================] - 12s 248us/step - loss: 2.1904 - accuracy: 0.1734 - val_loss: 2.1253 - val_accuracy: 0.1964
# Test loss: 2.1253060249328612
# Test accuracy: 0.1964000016450882
#  60% 18/30 [08:13<07:55, 39.67s/it]06/10/2020 10:32:42 AM - INFO - Getting Keras datasets
# 06/10/2020 10:32:42 AM - INFO - Compling Keras model
# 06/10/2020 10:32:42 AM - INFO - Architecture:[64, 32, 32, 32, 16, 64],relu,adam,5
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 8s 156us/step - loss: 2.0778 - accuracy: 0.1896 - val_loss: 1.7961 - val_accuracy: 0.3172
# Epoch 2/4
# 50000/50000 [==============================] - 7s 145us/step - loss: 1.7594 - accuracy: 0.3245 - val_loss: 1.5147 - val_accuracy: 0.4387
# Epoch 3/4
# 50000/50000 [==============================] - 7s 145us/step - loss: 1.5895 - accuracy: 0.4053 - val_loss: 1.4554 - val_accuracy: 0.4601
# Epoch 4/4
# 50000/50000 [==============================] - 7s 145us/step - loss: 1.4944 - accuracy: 0.4516 - val_loss: 1.2786 - val_accuracy: 0.5282
# Test loss: 1.278615068244934
# Test accuracy: 0.5281999707221985
#  63% 19/30 [08:45<06:52, 37.50s/it]06/10/2020 10:33:14 AM - INFO - Getting Keras datasets
# 06/10/2020 10:33:15 AM - INFO - Compling Keras model
# 06/10/2020 10:33:15 AM - INFO - Architecture:[64, 128, 32, 32, 16, 16],tanh,adagrad,1
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 5s 107us/step - loss: 2.6535 - accuracy: 0.1021 - val_loss: 2.3032 - val_accuracy: 0.1001
# Epoch 2/4
# 50000/50000 [==============================] - 5s 104us/step - loss: 2.4203 - accuracy: 0.1042 - val_loss: 2.2566 - val_accuracy: 0.1723
# Epoch 3/4
# 50000/50000 [==============================] - 5s 103us/step - loss: 2.2682 - accuracy: 0.1448 - val_loss: 2.1349 - val_accuracy: 0.2301
# Epoch 4/4
# 50000/50000 [==============================] - 5s 104us/step - loss: 2.1276 - accuracy: 0.1955 - val_loss: 1.9932 - val_accuracy: 0.2966
# Test loss: 1.993176692199707
# Test accuracy: 0.29660001397132874
#  67% 20/30 [09:08<05:30, 33.10s/it]06/10/2020 10:33:37 AM - INFO - Getting Keras datasets
# 06/10/2020 10:33:37 AM - INFO - Compling Keras model
# 06/10/2020 10:33:37 AM - INFO - Architecture:[128, 16, 16, 128, 128, 16],sigmoid,adagrad,4
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 10s 198us/step - loss: 2.3045 - accuracy: 0.0973 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 2/4
# 50000/50000 [==============================] - 9s 189us/step - loss: 2.3026 - accuracy: 0.0970 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 3/4
# 50000/50000 [==============================] - 9s 189us/step - loss: 2.3026 - accuracy: 0.1000 - val_loss: 2.3026 - val_accuracy: 0.1000
# Test loss: 2.3025881019592287
# Test accuracy: 0.10000000149011612
#  70% 21/30 [09:39<04:53, 32.60s/it]06/10/2020 10:34:08 AM - INFO - Getting Keras datasets
# 06/10/2020 10:34:09 AM - INFO - Compling Keras model
# 06/10/2020 10:34:09 AM - INFO - Architecture:[16, 32, 64, 128, 128, 32],linear,nadam,3
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.8426 - accuracy: 0.3412 - val_loss: 1.4661 - val_accuracy: 0.4736
# Epoch 2/4
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.5334 - accuracy: 0.4589 - val_loss: 1.3627 - val_accuracy: 0.5332
# Epoch 3/4
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.4366 - accuracy: 0.4949 - val_loss: 1.2873 - val_accuracy: 0.5495
# Epoch 4/4
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.3854 - accuracy: 0.5160 - val_loss: 1.4030 - val_accuracy: 0.5189
# Test loss: 1.403003261756897
# Test accuracy: 0.5188999772071838
#  73% 22/30 [10:02<03:56, 29.62s/it]06/10/2020 10:34:31 AM - INFO - Getting Keras datasets
# 06/10/2020 10:34:32 AM - INFO - Compling Keras model
# 06/10/2020 10:34:32 AM - INFO - Architecture:[128, 32, 16, 32, 64, 32],relu,adadelta,1
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 9s 175us/step - loss: 2.1646 - accuracy: 0.1670 - val_loss: 1.8406 - val_accuracy: 0.3714
# Epoch 2/4
# 50000/50000 [==============================] - 9s 171us/step - loss: 1.9195 - accuracy: 0.2639 - val_loss: 1.6603 - val_accuracy: 0.4319
# Epoch 3/4
# 50000/50000 [==============================] - 9s 172us/step - loss: 1.8088 - accuracy: 0.3150 - val_loss: 1.5783 - val_accuracy: 0.4622
# Epoch 4/4
# 50000/50000 [==============================] - 9s 171us/step - loss: 1.7353 - accuracy: 0.3445 - val_loss: 1.5047 - val_accuracy: 0.5044
# Test loss: 1.504690295791626
# Test accuracy: 0.5044000148773193
#  77% 23/30 [10:39<03:42, 31.78s/it]06/10/2020 10:35:08 AM - INFO - Getting Keras datasets
# 06/10/2020 10:35:08 AM - INFO - Compling Keras model
# 06/10/2020 10:35:08 AM - INFO - Architecture:[16, 32, 32, 64, 32, 16],elu,rmsprop,4
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.9367 - accuracy: 0.2888 - val_loss: 1.5814 - val_accuracy: 0.4384
# Epoch 2/4
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.7020 - accuracy: 0.3760 - val_loss: 1.4787 - val_accuracy: 0.4920
# Epoch 3/4
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.6074 - accuracy: 0.4155 - val_loss: 1.3844 - val_accuracy: 0.5056
# Epoch 4/4
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.5585 - accuracy: 0.4302 - val_loss: 1.3338 - val_accuracy: 0.5313
# Test loss: 1.3338181737899781
# Test accuracy: 0.5313000082969666
#  80% 24/30 [11:01<02:53, 28.97s/it]06/10/2020 10:35:30 AM - INFO - Getting Keras datasets
# 06/10/2020 10:35:31 AM - INFO - Compling Keras model
# 06/10/2020 10:35:31 AM - INFO - Architecture:[16, 32, 32, 64, 16, 32],hard_sigmoid,nadam,5
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 8s 153us/step - loss: 2.3352 - accuracy: 0.1012 - val_loss: 2.3030 - val_accuracy: 0.1000
# Epoch 2/4
# 50000/50000 [==============================] - 7s 139us/step - loss: 2.3058 - accuracy: 0.1009 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 3/4
# 50000/50000 [==============================] - 7s 138us/step - loss: 2.3039 - accuracy: 0.0988 - val_loss: 2.3026 - val_accuracy: 0.1000
# Test loss: 2.302643031692505
# Test accuracy: 0.10000000149011612
#  83% 25/30 [11:26<02:18, 27.75s/it]06/10/2020 10:35:55 AM - INFO - Getting Keras datasets
# 06/10/2020 10:35:56 AM - INFO - Compling Keras model
# 06/10/2020 10:35:56 AM - INFO - Architecture:[16, 16, 32, 128, 32, 32],sigmoid,sgd,4
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 5s 98us/step - loss: 2.3480 - accuracy: 0.1010 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 2/4
# 50000/50000 [==============================] - 4s 90us/step - loss: 2.3086 - accuracy: 0.0979 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 3/4
# 50000/50000 [==============================] - 4s 89us/step - loss: 2.3057 - accuracy: 0.0989 - val_loss: 2.3026 - val_accuracy: 0.1000
# Test loss: 2.3026033111572266
# Test accuracy: 0.10000000149011612
#  87% 26/30 [11:42<01:36, 24.25s/it]06/10/2020 10:36:11 AM - INFO - Getting Keras datasets
# 06/10/2020 10:36:12 AM - INFO - Compling Keras model
# 06/10/2020 10:36:12 AM - INFO - Architecture:[16, 128, 32, 128, 32, 128],sigmoid,sgd,5
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 7s 139us/step - loss: 2.4967 - accuracy: 0.0987 - val_loss: 2.3029 - val_accuracy: 0.1000
# Epoch 2/4
# 50000/50000 [==============================] - 7s 130us/step - loss: 2.4426 - accuracy: 0.1011 - val_loss: 2.3029 - val_accuracy: 0.1000
# Epoch 3/4
# 50000/50000 [==============================] - 7s 131us/step - loss: 2.4129 - accuracy: 0.0999 - val_loss: 2.3033 - val_accuracy: 0.1000
# Test loss: 2.3033401596069334
# Test accuracy: 0.10000000149011612
#  90% 27/30 [12:05<01:11, 23.75s/it]06/10/2020 10:36:34 AM - INFO - Getting Keras datasets
# 06/10/2020 10:36:34 AM - INFO - Compling Keras model
# 06/10/2020 10:36:34 AM - INFO - Architecture:[128, 16, 64, 128, 32, 16],linear,adamax,2
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 8s 164us/step - loss: 1.9697 - accuracy: 0.2806 - val_loss: 1.6319 - val_accuracy: 0.4321
# Epoch 2/4
# 50000/50000 [==============================] - 8s 157us/step - loss: 1.7193 - accuracy: 0.3759 - val_loss: 1.4604 - val_accuracy: 0.4959
# Epoch 3/4
# 50000/50000 [==============================] - 8s 157us/step - loss: 1.6033 - accuracy: 0.4211 - val_loss: 1.3864 - val_accuracy: 0.5168
# Epoch 4/4
# 50000/50000 [==============================] - 8s 157us/step - loss: 1.5374 - accuracy: 0.4466 - val_loss: 1.3365 - val_accuracy: 0.5289
# Test loss: 1.336508295249939
# Test accuracy: 0.5289000272750854
#  93% 28/30 [12:39<00:53, 26.93s/it]06/10/2020 10:37:08 AM - INFO - Getting Keras datasets
# 06/10/2020 10:37:09 AM - INFO - Compling Keras model
# 06/10/2020 10:37:09 AM - INFO - Architecture:[128, 32, 16, 16, 64, 64],softplus,adamax,3
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 11s 214us/step - loss: 2.3241 - accuracy: 0.1019 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 2/4
# 50000/50000 [==============================] - 10s 205us/step - loss: 2.3028 - accuracy: 0.0992 - val_loss: 2.3026 - val_accuracy: 0.1281
# Epoch 3/4
# 50000/50000 [==============================] - 10s 207us/step - loss: 2.3027 - accuracy: 0.1002 - val_loss: 2.3025 - val_accuracy: 0.1145
# Test loss: 2.3024865463256834
# Test accuracy: 0.1145000010728836
#  97% 29/30 [13:13<00:29, 29.05s/it]06/10/2020 10:37:42 AM - INFO - Getting Keras datasets
# 06/10/2020 10:37:43 AM - INFO - Compling Keras model
# 06/10/2020 10:37:43 AM - INFO - Architecture:[128, 128, 32, 128, 16, 16],tanh,adamax,3
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 13s 252us/step - loss: 1.8756 - accuracy: 0.3158 - val_loss: 1.5224 - val_accuracy: 0.4868
# Epoch 2/4
# 50000/50000 [==============================] - 12s 245us/step - loss: 1.6057 - accuracy: 0.4205 - val_loss: 1.3268 - val_accuracy: 0.5503
# Epoch 3/4
# 50000/50000 [==============================] - 12s 244us/step - loss: 1.4982 - accuracy: 0.4588 - val_loss: 1.3246 - val_accuracy: 0.5523
# Epoch 4/4
# 50000/50000 [==============================] - 12s 245us/step - loss: 1.4456 - accuracy: 0.4820 - val_loss: 1.2043 - val_accuracy: 0.5880
# Test loss: 1.204308374786377
# Test accuracy: 0.5879999995231628
# 100% 30/30 [14:05<00:00, 28.19s/it]
# 06/10/2020 10:38:34 AM - INFO - Generation average: 35.49%
# 06/10/2020 10:38:34 AM - INFO - --------------------------------------------------------------------------------
# 06/10/2020 10:38:34 AM - INFO - ***Now in generation 2 of 8***
# 06/10/2020 10:38:34 AM - INFO - --------------------------------------------------------------------------------
# 06/10/2020 10:38:34 AM - INFO - {'nb_layers': 2, 'activation': 'linear', 'optimizer': 'rmsprop', 'nb_neurons': [16, 128, 16, 32, 16, 128]}
# 06/10/2020 10:38:34 AM - INFO - Acc: 61.59%
# 06/10/2020 10:38:34 AM - INFO - UniID: 7
# 06/10/2020 10:38:34 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:38:34 AM - INFO - Gen: 1
# 06/10/2020 10:38:34 AM - INFO - Hash: 425a591b8fe3f117d2794bda73c76354
# 06/10/2020 10:38:34 AM - INFO - {'nb_layers': 4, 'activation': 'linear', 'optimizer': 'adam', 'nb_neurons': [128, 64, 128, 16, 64, 32]}
# 06/10/2020 10:38:34 AM - INFO - Acc: 60.77%
# 06/10/2020 10:38:34 AM - INFO - UniID: 17
# 06/10/2020 10:38:34 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:38:34 AM - INFO - Gen: 1
# 06/10/2020 10:38:34 AM - INFO - Hash: 56e56c26a56cdcf88e0332af3bff4a82
# 06/10/2020 10:38:34 AM - INFO - {'nb_layers': 3, 'activation': 'tanh', 'optimizer': 'adamax', 'nb_neurons': [128, 128, 32, 128, 16, 16]}
# 06/10/2020 10:38:34 AM - INFO - Acc: 58.80%
# 06/10/2020 10:38:34 AM - INFO - UniID: 30
# 06/10/2020 10:38:34 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:38:34 AM - INFO - Gen: 1
# 06/10/2020 10:38:34 AM - INFO - Hash: e1bc46847c309b885d0b2874876d73ab
# 06/10/2020 10:38:34 AM - INFO - {'nb_layers': 3, 'activation': 'linear', 'optimizer': 'adamax', 'nb_neurons': [128, 16, 128, 16, 32, 32]}
# 06/10/2020 10:38:34 AM - INFO - Acc: 57.68%
# 06/10/2020 10:38:34 AM - INFO - UniID: 15
# 06/10/2020 10:38:34 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:38:34 AM - INFO - Gen: 1
# 06/10/2020 10:38:34 AM - INFO - Hash: 791e08b060e22b1666a17366d886c076
# 06/10/2020 10:38:34 AM - INFO - {'nb_layers': 5, 'activation': 'relu', 'optimizer': 'adamax', 'nb_neurons': [32, 32, 64, 16, 128, 64]}
# 06/10/2020 10:38:34 AM - INFO - Acc: 0.00%
# 06/10/2020 10:38:34 AM - INFO - UniID: 4
# 06/10/2020 10:38:34 AM - INFO - Mom and Dad: 0 0
# 06/10/2020 10:38:34 AM - INFO - Gen: 2
# 06/10/2020 10:38:34 AM - INFO - Hash: d875687b541ef37fb3aaab5dd348e0ff
# 06/10/2020 10:38:34 AM - INFO - {'nb_layers': 1, 'activation': 'elu', 'optimizer': 'rmsprop', 'nb_neurons': [16, 32, 32, 64, 32, 16]}
# 06/10/2020 10:38:34 AM - INFO - Acc: 0.00%
# 06/10/2020 10:38:34 AM - INFO - UniID: 24
# 06/10/2020 10:38:34 AM - INFO - Mom and Dad: 0 0
# ...
# Epoch 1/4
# 50000/50000 [==============================] - 13s 265us/step - loss: 1.8214 - accuracy: 0.3341 - val_loss: 1.6293 - val_accuracy: 0.4313
# Epoch 2/4
# 50000/50000 [==============================] - 13s 257us/step - loss: 1.5130 - accuracy: 0.4566 - val_loss: 1.3592 - val_accuracy: 0.5254
# Epoch 3/4
# 50000/50000 [==============================] - 13s 259us/step - loss: 1.3822 - accuracy: 0.5071 - val_loss: 1.2247 - val_accuracy: 0.5621
# Epoch 4/4
# 50000/50000 [==============================] - 13s 258us/step - loss: 1.2883 - accuracy: 0.5459 - val_loss: 1.1373 - val_accuracy: 0.5952
# Test loss: 1.1373411687850952
# Test accuracy: 0.5952000021934509
#  60% 21/35 [10:40<09:57, 42.66s/it]06/10/2020 12:31:54 PM - INFO - Getting Keras datasets
# 06/10/2020 12:31:54 PM - INFO - Compling Keras model
# 06/10/2020 12:31:54 PM - INFO - Architecture:[128, 64, 128, 16, 128, 128],elu,adam,3
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 13s 250us/step - loss: 1.5652 - accuracy: 0.4392 - val_loss: 1.3895 - val_accuracy: 0.5153
# Epoch 2/4
# 50000/50000 [==============================] - 12s 244us/step - loss: 1.2656 - accuracy: 0.5550 - val_loss: 1.1609 - val_accuracy: 0.5937
# Epoch 3/4
# 50000/50000 [==============================] - 12s 243us/step - loss: 1.1628 - accuracy: 0.5943 - val_loss: 1.0568 - val_accuracy: 0.6346
# Epoch 4/4
# 50000/50000 [==============================] - 12s 243us/step - loss: 1.1011 - accuracy: 0.6173 - val_loss: 0.9823 - val_accuracy: 0.6556
# Test loss: 0.982333696937561
# Test accuracy: 0.6556000113487244
#  63% 22/35 [11:32<09:50, 45.42s/it]06/10/2020 12:32:45 PM - INFO - Getting Keras datasets
# 06/10/2020 12:32:46 PM - INFO - Compling Keras model
# 06/10/2020 12:32:46 PM - INFO - Architecture:[16, 64, 32, 128, 64, 128],elu,adamax,3
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 6s 112us/step - loss: 1.6960 - accuracy: 0.3866 - val_loss: 1.5361 - val_accuracy: 0.4493
# Epoch 2/4
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.4041 - accuracy: 0.4998 - val_loss: 1.4091 - val_accuracy: 0.4901
# Epoch 3/4
# 50000/50000 [==============================] - 5s 103us/step - loss: 1.3034 - accuracy: 0.5379 - val_loss: 1.3734 - val_accuracy: 0.5081
# Epoch 4/4
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.2454 - accuracy: 0.5604 - val_loss: 1.2076 - val_accuracy: 0.5668
# Test loss: 1.2075962409973144
# Test accuracy: 0.5667999982833862
#  66% 23/35 [11:56<07:46, 38.85s/it]06/10/2020 12:33:09 PM - INFO - Getting Keras datasets
# 06/10/2020 12:33:09 PM - INFO - Compling Keras model
# 06/10/2020 12:33:09 PM - INFO - Architecture:[128, 64, 128, 16, 32, 128],elu,rmsprop,3
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 12s 245us/step - loss: 1.7408 - accuracy: 0.3970 - val_loss: 1.4268 - val_accuracy: 0.5055
# Epoch 2/4
# 50000/50000 [==============================] - 12s 240us/step - loss: 1.3872 - accuracy: 0.5183 - val_loss: 1.1828 - val_accuracy: 0.5803
# Epoch 3/4
# 50000/50000 [==============================] - 12s 242us/step - loss: 1.2679 - accuracy: 0.5573 - val_loss: 1.1794 - val_accuracy: 0.5882
# Epoch 4/4
# 50000/50000 [==============================] - 12s 241us/step - loss: 1.1820 - accuracy: 0.5908 - val_loss: 1.0652 - val_accuracy: 0.6312
# Test loss: 1.065200717830658
# Test accuracy: 0.6312000155448914
#  69% 24/35 [12:47<07:47, 42.53s/it]06/10/2020 12:34:00 PM - INFO - Getting Keras datasets
# 06/10/2020 12:34:01 PM - INFO - Compling Keras model
# 06/10/2020 12:34:01 PM - INFO - Architecture:[32, 128, 16, 128, 128, 128],elu,adam,5
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 9s 175us/step - loss: 1.6595 - accuracy: 0.3947 - val_loss: 1.3410 - val_accuracy: 0.5177
# Epoch 2/4
# 50000/50000 [==============================] - 8s 164us/step - loss: 1.3748 - accuracy: 0.5110 - val_loss: 1.1905 - val_accuracy: 0.5796
# Epoch 3/4
# 50000/50000 [==============================] - 8s 164us/step - loss: 1.2703 - accuracy: 0.5516 - val_loss: 1.1736 - val_accuracy: 0.5888
# Epoch 4/4
# 50000/50000 [==============================] - 8s 164us/step - loss: 1.2021 - accuracy: 0.5770 - val_loss: 1.0767 - val_accuracy: 0.6215
# Test loss: 1.0766941284179687
# Test accuracy: 0.6215000152587891
#  71% 25/35 [13:23<06:46, 40.66s/it]06/10/2020 12:34:36 PM - INFO - Getting Keras datasets
# 06/10/2020 12:34:37 PM - INFO - Compling Keras model
# 06/10/2020 12:34:37 PM - INFO - Architecture:[32, 128, 16, 16, 16, 128],elu,adamax,5
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 8s 156us/step - loss: 1.8176 - accuracy: 0.3194 - val_loss: 1.5576 - val_accuracy: 0.4236
# Epoch 2/4
# 50000/50000 [==============================] - 7s 148us/step - loss: 1.5354 - accuracy: 0.4344 - val_loss: 1.3476 - val_accuracy: 0.5099
# Epoch 3/4
# 50000/50000 [==============================] - 7s 148us/step - loss: 1.4431 - accuracy: 0.4742 - val_loss: 1.3126 - val_accuracy: 0.5180
# Epoch 4/4
# 50000/50000 [==============================] - 7s 148us/step - loss: 1.3808 - accuracy: 0.5031 - val_loss: 1.2021 - val_accuracy: 0.5735
# Test loss: 1.2020995182037353
# Test accuracy: 0.5734999775886536
#  74% 26/35 [13:56<05:44, 38.26s/it]06/10/2020 12:35:09 PM - INFO - Getting Keras datasets
# 06/10/2020 12:35:09 PM - INFO - Compling Keras model
# 06/10/2020 12:35:09 PM - INFO - Architecture:[128, 64, 128, 128, 32, 128],elu,rmsprop,3
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 12s 247us/step - loss: 1.7924 - accuracy: 0.3913 - val_loss: 1.6015 - val_accuracy: 0.4290
# Epoch 2/4
# 50000/50000 [==============================] - 12s 240us/step - loss: 1.3931 - accuracy: 0.5146 - val_loss: 1.2291 - val_accuracy: 0.5763
# Epoch 3/4
# 50000/50000 [==============================] - 12s 240us/step - loss: 1.2749 - accuracy: 0.5561 - val_loss: 1.1061 - val_accuracy: 0.6115
# Epoch 4/4
# 50000/50000 [==============================] - 12s 239us/step - loss: 1.1935 - accuracy: 0.5848 - val_loss: 1.0207 - val_accuracy: 0.6435
# Test loss: 1.0207407875061034
# Test accuracy: 0.6434999704360962
#  77% 27/35 [14:47<05:36, 42.08s/it]06/10/2020 12:36:00 PM - INFO - Getting Keras datasets
# 06/10/2020 12:36:00 PM - INFO - Compling Keras model
# 06/10/2020 12:36:00 PM - INFO - Architecture:[32, 64, 16, 128, 16, 128],linear,rmsprop,2
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.6292 - accuracy: 0.4292 - val_loss: 1.3321 - val_accuracy: 0.5445
# Epoch 2/4
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.3118 - accuracy: 0.5454 - val_loss: 1.1618 - val_accuracy: 0.5991
# Epoch 3/4
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.2304 - accuracy: 0.5771 - val_loss: 1.1200 - val_accuracy: 0.6156
# Epoch 4/4
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.1784 - accuracy: 0.5955 - val_loss: 1.1409 - val_accuracy: 0.6067
# Test loss: 1.140939314365387
# Test accuracy: 0.6067000031471252
#  80% 28/35 [15:10<04:14, 36.30s/it]06/10/2020 12:36:23 PM - INFO - Getting Keras datasets
# 06/10/2020 12:36:23 PM - INFO - Compling Keras model
# 06/10/2020 12:36:23 PM - INFO - Architecture:[128, 16, 128, 128, 16, 128],elu,adamax,3
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 10s 204us/step - loss: 1.6324 - accuracy: 0.4171 - val_loss: 1.3099 - val_accuracy: 0.5378
# Epoch 2/4
# 50000/50000 [==============================] - 10s 198us/step - loss: 1.3676 - accuracy: 0.5207 - val_loss: 1.2222 - val_accuracy: 0.5700
# Epoch 3/4
# 50000/50000 [==============================] - 10s 203us/step - loss: 1.2904 - accuracy: 0.5458 - val_loss: 1.1428 - val_accuracy: 0.6006
# Epoch 4/4
# 50000/50000 [==============================] - 10s 199us/step - loss: 1.2358 - accuracy: 0.5692 - val_loss: 1.1245 - val_accuracy: 0.6159
# Test loss: 1.1244620864868164
# Test accuracy: 0.6158999800682068
#  83% 29/35 [15:52<03:49, 38.26s/it]06/10/2020 12:37:06 PM - INFO - Getting Keras datasets
# 06/10/2020 12:37:06 PM - INFO - Compling Keras model
# 06/10/2020 12:37:06 PM - INFO - Architecture:[128, 64, 128, 32, 16, 128],elu,rmsprop,3
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 12s 248us/step - loss: 1.7699 - accuracy: 0.3910 - val_loss: 1.5625 - val_accuracy: 0.4432
# Epoch 2/4
# 50000/50000 [==============================] - 12s 241us/step - loss: 1.3926 - accuracy: 0.5175 - val_loss: 1.2311 - val_accuracy: 0.5742
# Epoch 3/4
# 50000/50000 [==============================] - 12s 242us/step - loss: 1.2636 - accuracy: 0.5599 - val_loss: 1.2896 - val_accuracy: 0.5493
# Epoch 4/4
# 50000/50000 [==============================] - 12s 242us/step - loss: 1.1802 - accuracy: 0.5877 - val_loss: 1.0626 - val_accuracy: 0.6213
# Test loss: 1.0625726676940919
# Test accuracy: 0.6212999820709229
#  86% 30/35 [16:44<03:30, 42.20s/it]06/10/2020 12:37:57 PM - INFO - Getting Keras datasets
# 06/10/2020 12:37:58 PM - INFO - Compling Keras model
# 06/10/2020 12:37:58 PM - INFO - Architecture:[128, 16, 128, 128, 32, 128],elu,adamax,4
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 11s 222us/step - loss: 1.6805 - accuracy: 0.3949 - val_loss: 1.4265 - val_accuracy: 0.4902
# Epoch 2/4
# 50000/50000 [==============================] - 11s 215us/step - loss: 1.4115 - accuracy: 0.4972 - val_loss: 1.2478 - val_accuracy: 0.5593
# Epoch 3/4
# 50000/50000 [==============================] - 11s 213us/step - loss: 1.3108 - accuracy: 0.5387 - val_loss: 1.1982 - val_accuracy: 0.5759
# Epoch 4/4
# 50000/50000 [==============================] - 11s 214us/step - loss: 1.2604 - accuracy: 0.5554 - val_loss: 1.1071 - val_accuracy: 0.6199
# Test loss: 1.1070616596221923
# Test accuracy: 0.6198999881744385
#  89% 31/35 [17:30<02:53, 43.35s/it]06/10/2020 12:38:43 PM - INFO - Getting Keras datasets
# 06/10/2020 12:38:44 PM - INFO - Compling Keras model
# 06/10/2020 12:38:44 PM - INFO - Architecture:[128, 64, 128, 64, 16, 128],elu,adamax,3
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 12s 248us/step - loss: 1.6039 - accuracy: 0.4276 - val_loss: 1.2985 - val_accuracy: 0.5379
# Epoch 2/4
# 50000/50000 [==============================] - 12s 239us/step - loss: 1.2948 - accuracy: 0.5448 - val_loss: 1.1297 - val_accuracy: 0.6059
# Epoch 3/4
# 50000/50000 [==============================] - 12s 238us/step - loss: 1.1888 - accuracy: 0.5870 - val_loss: 1.0814 - val_accuracy: 0.6131
# Epoch 4/4
# 50000/50000 [==============================] - 12s 239us/step - loss: 1.1356 - accuracy: 0.6026 - val_loss: 1.0411 - val_accuracy: 0.6428
# Test loss: 1.0411338333129883
# Test accuracy: 0.642799973487854
#  91% 32/35 [18:21<02:16, 45.64s/it]06/10/2020 12:39:34 PM - INFO - Getting Keras datasets
# 06/10/2020 12:39:35 PM - INFO - Compling Keras model
# 06/10/2020 12:39:35 PM - INFO - Architecture:[32, 32, 16, 128, 16, 128],linear,rmsprop,2
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.7129 - accuracy: 0.3973 - val_loss: 1.4325 - val_accuracy: 0.4900
# Epoch 2/4
# 50000/50000 [==============================] - 5s 93us/step - loss: 1.3869 - accuracy: 0.5168 - val_loss: 1.4833 - val_accuracy: 0.4653
# Epoch 3/4
# 50000/50000 [==============================] - 5s 92us/step - loss: 1.2967 - accuracy: 0.5511 - val_loss: 1.1992 - val_accuracy: 0.5881
# Epoch 4/4
# 50000/50000 [==============================] - 5s 92us/step - loss: 1.2502 - accuracy: 0.5711 - val_loss: 1.1486 - val_accuracy: 0.6026
# Test loss: 1.1485905952453612
# Test accuracy: 0.6025999784469604
#  94% 33/35 [18:42<01:16, 38.26s/it]06/10/2020 12:39:55 PM - INFO - Getting Keras datasets
# 06/10/2020 12:39:56 PM - INFO - Compling Keras model
# 06/10/2020 12:39:56 PM - INFO - Architecture:[128, 64, 128, 16, 16, 128],elu,adam,4
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 13s 260us/step - loss: 1.6908 - accuracy: 0.3846 - val_loss: 1.3306 - val_accuracy: 0.5324
# Epoch 2/4
# 50000/50000 [==============================] - 13s 252us/step - loss: 1.3770 - accuracy: 0.5073 - val_loss: 1.2423 - val_accuracy: 0.5529
# Epoch 3/4
# 50000/50000 [==============================] - 13s 252us/step - loss: 1.2620 - accuracy: 0.5551 - val_loss: 1.2090 - val_accuracy: 0.5743
# Epoch 4/4
# 50000/50000 [==============================] - 13s 252us/step - loss: 1.1907 - accuracy: 0.5783 - val_loss: 1.0634 - val_accuracy: 0.6232
# Test loss: 1.063384797859192
# Test accuracy: 0.623199999332428
#  97% 34/35 [19:36<00:42, 42.95s/it]06/10/2020 12:40:49 PM - INFO - Getting Keras datasets
# 06/10/2020 12:40:49 PM - INFO - Compling Keras model
# 06/10/2020 12:40:49 PM - INFO - Architecture:[128, 16, 128, 128, 16, 128],elu,rmsprop,3
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 50000/50000 [==============================] - 10s 205us/step - loss: 1.7362 - accuracy: 0.3839 - val_loss: 1.3621 - val_accuracy: 0.5196
# Epoch 2/4
# 50000/50000 [==============================] - 10s 198us/step - loss: 1.4365 - accuracy: 0.4965 - val_loss: 1.2444 - val_accuracy: 0.5648
# Epoch 3/4
# 50000/50000 [==============================] - 10s 198us/step - loss: 1.3425 - accuracy: 0.5291 - val_loss: 1.1617 - val_accuracy: 0.5957
# Epoch 4/4
# 50000/50000 [==============================] - 10s 198us/step - loss: 1.2730 - accuracy: 0.5515 - val_loss: 1.0905 - val_accuracy: 0.6236
# Test loss: 1.0904639432907104
# Test accuracy: 0.6236000061035156
# 100% 35/35 [20:18<00:00, 34.83s/it]
# 06/10/2020 12:41:32 PM - INFO - Generation average: 60.52%
# 06/10/2020 12:41:32 PM - INFO - --------------------------------------------------------------------------------
# 06/10/2020 12:41:32 PM - INFO - --------------------------------------------------------------------------------
# 06/10/2020 12:41:32 PM - INFO - {'activation': 'elu', 'nb_layers': 3, 'optimizer': 'adam', 'nb_neurons': [128, 64, 128, 16, 16, 128]}
# 06/10/2020 12:41:32 PM - INFO - Acc: 66.09%
# 06/10/2020 12:41:32 PM - INFO - UniID: 142
# 06/10/2020 12:41:32 PM - INFO - Mom and Dad: 104 122
# 06/10/2020 12:41:32 PM - INFO - Gen: 6
# 06/10/2020 12:41:32 PM - INFO - Hash: 3c2f14b3a7413cc682a99e8e96342155
# 06/10/2020 12:41:32 PM - INFO - {'activation': 'elu', 'nb_layers': 3, 'optimizer': 'adam', 'nb_neurons': [128, 64, 128, 16, 128, 128]}
# 06/10/2020 12:41:32 PM - INFO - Acc: 65.56%
# 06/10/2020 12:41:32 PM - INFO - UniID: 201
# 06/10/2020 12:41:32 PM - INFO - Mom and Dad: 165 142
# 06/10/2020 12:41:32 PM - INFO - Gen: 8
# 06/10/2020 12:41:32 PM - INFO - Hash: dfbb28707762ef224f0462052f7e9f44
# 06/10/2020 12:41:32 PM - INFO - {'activation': 'elu', 'nb_layers': 3, 'optimizer': 'adamax', 'nb_neurons': [128, 64, 128, 128, 16, 128]}
# 06/10/2020 12:41:32 PM - INFO - Acc: 65.09%
# 06/10/2020 12:41:32 PM - INFO - UniID: 145
# 06/10/2020 12:41:32 PM - INFO - Mom and Dad: 104 122
# 06/10/2020 12:41:32 PM - INFO - Gen: 6
# 06/10/2020 12:41:32 PM - INFO - Hash: 4fcdd5daaaac1ac6753ee10976c17649
# 06/10/2020 12:41:32 PM - INFO - {'activation': 'elu', 'nb_layers': 3, 'optimizer': 'adamax', 'nb_neurons': [128, 64, 128, 128, 64, 128]}
# 06/10/2020 12:41:32 PM - INFO - Acc: 64.84%
# 06/10/2020 12:41:32 PM - INFO - UniID: 165
# 06/10/2020 12:41:32 PM - INFO - Mom and Dad: 104 145
# 06/10/2020 12:41:32 PM - INFO - Gen: 7
# 06/10/2020 12:41:32 PM - INFO - Hash: d888146cada4b60d27cc936da3ee5da8
# 06/10/2020 12:41:32 PM - INFO - {'activation': 'elu', 'nb_layers': 3, 'optimizer': 'adamax', 'nb_neurons': [128, 64, 128, 16, 32, 128]}
# 06/10/2020 12:41:32 PM - INFO - Acc: 64.76%
# 06/10/2020 12:41:32 PM - INFO - UniID: 196
# 06/10/2020 12:41:32 PM - INFO - Mom and Dad: 145 142
# 06/10/2020 12:41:32 PM - INFO - Gen: 8
# 06/10/2020 12:41:32 PM - INFO - Hash: baf7a1afdde749fe740875b34fb4fcc2

# %% [markdown]
# Y os recomiendo que le echéis un ojo a estos dos enlaces en los que evolucionan una red neuronal con un GA. Aquí no nos da tiempo, pero son muy interesantes:
#
# ### Ejemplo GA para evolucionar NN:
#
# * https://blog.coast.ai/lets-evolve-a-neural-network-with-a-genetic-algorithm-code-included-8809bece164
# * https://github.com/harvitronix/neural-network-genetic-algorithm
