# %% [markdown]
# # Optimización de hiper-parámetros - Avanzado
#
# En este notebook jugaremos con dos tipos de optimización de hiperparámetros más complicados:
# * Hyperopt
# * Algoritmos genéticos

# %% [markdown]
# ## Hyper-opt
#
# (Hyperopt: Distributed Asynchronous Hyper-parameter Optimization, https://github.com/hyperopt/hyperopt).
#
# Hyperopt es una librería escrita en Python que permite optimizar funciones de una forma rápida fijándose más en los valores que más probablemente van a dar una buena solución.
#
# Actualmente tiene dos algoritmos implementados para hacer esto:
#
# * Random Search
# * Tree of Parzen Estimators (TPE)
#
# Además, se pueden ejecutar en serie o en paralelo, haciendo uso de MongoDB.
#
# Vamos a ver un ejemplo de cómo utilizarlo.
#
# Vamos a encontrar el mínimo de $x^2$:
# (<a href="https://www.google.es/search?source=hp&ei=2ds5XO_jG6y_lwTvxp2QBQ&q=x**2&btnK=Google+Search&oq=x**2&gs_l=psy-ab.3...716.1584..1916...0.0..0.301.1084.1j0j3j1......0....1..gws-wiz.....0..0i131j0.cgRgMW95cQk">click aqui para ver la funcion</a>)

# %%
from hyperopt import fmin, tpe, hp
# con 10 iteraciones

best = fmin(fn=lambda x: x ** 2,
            space=hp.uniform('x', -10, 10),
            algo=tpe.suggest,
            max_evals=10)

print(best)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 708.28it/s, best loss: 8.539499994235294]
# {'x': -2.9222422887630817}

# %%
# con 100 iteraciones
best = fmin(fn=lambda x: x ** 2,
            space=hp.uniform('x', -10, 10),
            algo=tpe.suggest,
            max_evals=100)

print(best)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 376.90it/s, best loss: 0.0014834168269518854]
# {'x': -0.03851515061572375}

# %%
# con 1000 iteraciones
best = fmin(fn=lambda x: x ** 2,
            space=hp.uniform('x', -10, 10),
            algo=tpe.suggest,
            max_evals=1000)

print(best)
# Out:
# 100%|██████████| 1000/1000 [00:04<00:00, 213.30it/s, best loss: 3.944167302318249e-07]
# {'x': 0.0006280260585611276}

# %% [markdown]
# Y ahora uno más complejo con redes neuronales:

# %%
# instalamos los paquetes necesarios
# !pip install networkx==1.11 # para instala hyperopt correctamente, si no, da errores
# !pip install hyperopt
# Out:
# Collecting networkx==1.11
#   Downloading networkx-1.11-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 14.5 MB/s
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from networkx==1.11) (4.4.2)
# Installing collected packages: networkx
#   Attempting uninstall: networkx
#     Found existing installation: networkx 2.6.3
#     Uninstalling networkx-2.6.3:
#       Successfully uninstalled networkx-2.6.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikit-image 0.16.2 requires networkx>=2.0, but you have networkx 1.11 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed networkx-1.11
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.7/dist-packages (0.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from hyperopt) (4.62.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.11)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.19.5)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from hyperopt) (0.16.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.15.0)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.7/dist-packages (from hyperopt) (3.12.0)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from networkx->hyperopt) (4.4.2)

# %%
# imports necesarios
import sys
import time
import numpy as np
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.constraints import max_norm
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.datasets import cifar10

SEED = 42

(X_train, y_train), (X_test, y_test) = cifar10.load_data()
validation_split = 0.1
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=validation_split, random_state=SEED)

# normalizamos
X_train = X_train.astype('float32') / 255.
X_val = X_val.astype('float32') / 255.
X_test = X_test.astype('float32') / 255.

# convertimos las etiquetas a one-hot encoding
n_classes = 10
y_train = to_categorical(y_train, n_classes)
y_val = to_categorical(y_val, n_classes)
y_test = to_categorical(y_test, n_classes)

# definimos nuestro espacio de búsqueda
# vamos a variar:
# - el número de filtros en nuestras capas conv
# - el porcentaje de dropout
# - el número de neuronas en la capa dense
space = {
    'n_filters_conv': hp.choice('n_filters_conv', [32, 64, 128]),
    'dropout': hp.uniform('dropout', 0.0, 0.5),
    'neurons_dense': hp.choice('neurons_dense', [256, 512, 1024]), 
}

def	get_callbacks(pars):
  callbacks	= [EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=2, verbose=0, mode='auto')]
  return callbacks

def mi_cnn(pars):
  print ('Parameters: ', pars)
  model = Sequential()
  
  # Primer bloque convolucional
  model.add(Conv2D(pars['n_filters_conv'], kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(pars['dropout']))

  # Segundo bloque convolucional
  model.add(Conv2D(pars['n_filters_conv'], kernel_size=(3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(pars['dropout']))

  # Tercer bloque convolucional
  model.add(Conv2D(pars['n_filters_conv'], kernel_size=(3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(pars['dropout']))

  # Bloque clasificador
  model.add(Flatten())
  model.add(Dense(pars['neurons_dense'], activation='relu', kernel_constraint=max_norm(3.)))
  model.add(Dropout(pars['dropout']))
  model.add(Dense(10, activation='softmax'))

  # Compilamos el modelo
  model.compile(loss='categorical_crossentropy',
                optimizer=Adam(lr=0.0001, decay=1e-6),
                metrics=['accuracy'])

  # Entrenamos el modelo
  history = model.fit(X_train, 
                      y_train,
                      batch_size=128,
                      shuffle=True,
                      epochs=5,
                      validation_data=(X_val, y_val),
                      verbose = 0,
                      callbacks = get_callbacks(pars))

  best_epoch_loss = np.argmin(history.history['val_loss'])
  best_val_loss = np.min(history.history['val_loss'])
  best_val_acc = np.max(history.history['val_accuracy'])
  
  print('Epoch {} - val acc: {} - val loss: {}'.format(best_epoch_loss, best_val_acc, best_val_loss))
  sys.stdout.flush()
  
  return {'loss': best_val_loss, 'best_epoch': best_epoch_loss, 'eval_time': time.time(), 'status': STATUS_OK, 'model': model, 'history': history}


trials = Trials()
best = fmin(mi_cnn, space, algo=tpe.suggest, max_evals=100, trials=trials)
print(best)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# 170508288/170498071 [==============================] - 6s 0us/step
# Parameters:
# {'dropout': 0.12881796928340788, 'n_filters_conv': 128, 'neurons_dense': 1024}
#   0%|          | 0/10 [00:00<?, ?it/s, best loss: ?]
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 4 - val acc: 0.5454000234603882 - val loss: 1.2698273658752441
# Parameters:
# {'dropout': 0.390102988243035, 'n_filters_conv': 64, 'neurons_dense': 256}
# Epoch 4 - val acc: 0.3970000147819519 - val loss: 1.6546269655227661
# Parameters:
# {'dropout': 0.4542023792720861, 'n_filters_conv': 128, 'neurons_dense': 1024}
# Epoch 4 - val acc: 0.4819999933242798 - val loss: 1.4638895988464355
# Parameters:
# {'dropout': 0.27957105898309437, 'n_filters_conv': 128, 'neurons_dense': 1024}
# Epoch 4 - val acc: 0.5296000242233276 - val loss: 1.3307889699935913
# Parameters:
# {'dropout': 0.3905158605390463, 'n_filters_conv': 64, 'neurons_dense': 256}
# Epoch 4 - val acc: 0.41679999232292175 - val loss: 1.6171038150787354
# Parameters:
# {'dropout': 0.06328826221784639, 'n_filters_conv': 32, 'neurons_dense': 1024}
# Epoch 4 - val acc: 0.43700000643730164 - val loss: 1.5200520753860474
# Parameters:
# {'dropout': 0.40071804425666835, 'n_filters_conv': 64, 'neurons_dense': 256}
# Epoch 4 - val acc: 0.39739999175071716 - val loss: 1.6719541549682617
# Parameters:
# {'dropout': 0.24485561494462055, 'n_filters_conv': 64, 'neurons_dense': 1024}
# Epoch 4 - val acc: 0.46459999680519104 - val loss: 1.4742319583892822
# Parameters:
# {'dropout': 0.2680128013718139, 'n_filters_conv': 64, 'neurons_dense': 512}
# Epoch 4 - val acc: 0.45339998602867126 - val loss: 1.5017356872558594
# Parameters:
# {'dropout': 0.43902857958301533, 'n_filters_conv': 32, 'neurons_dense': 512}
# Epoch 4 - val acc: 0.34700000286102295 - val loss: 1.7830910682678223
# 100%|██████████| 10/10 [02:18<00:00, 13.83s/it, best loss: 1.2698273658752441]
# {'dropout': 0.12881796928340788, 'n_filters_conv': 2, 'neurons_dense': 2}

# %%
trials.trials
# Out:
# [{'book_time': datetime.datetime(2021, 11, 8, 18, 54, 28, 601000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dropout': [0], 'n_filters_conv': [0], 'neurons_dense': [0]},
#    'tid': 0,
#    'vals': {'dropout': [0.12881796928340788],
#     'n_filters_conv': [2],
#     'neurons_dense': [2]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 11, 8, 18, 55, 1, 591000),
#   'result': {'best_epoch': 4,
#    'eval_time': 1636397701.5915682,
#    'history': <keras.callbacks.History at 0x7f1b6009b3d0>,
#    'loss': 1.2698273658752441,
#    'model': <keras.engine.sequential.Sequential at 0x7f1b718f9710>,
#    'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 0,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 11, 8, 18, 55, 1, 595000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dropout': [1], 'n_filters_conv': [1], 'neurons_dense': [1]},
#    'tid': 1,
#    'vals': {'dropout': [0.390102988243035],
#     'n_filters_conv': [1],
#     'neurons_dense': [0]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 11, 8, 18, 55, 13, 263000),
#   'result': {'best_epoch': 4,
#    'eval_time': 1636397713.2631986,
#    'history': <keras.callbacks.History at 0x7f1af4447210>,
#    'loss': 1.6546269655227661,
#    'model': <keras.engine.sequential.Sequential at 0x7f1af4472690>,
#    'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 1,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 11, 8, 18, 55, 13, 267000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dropout': [2], 'n_filters_conv': [2], 'neurons_dense': [2]},
#    'tid': 2,
#    'vals': {'dropout': [0.4542023792720861],
#     'n_filters_conv': [2],
#     'neurons_dense': [2]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 11, 8, 18, 55, 27, 648000),
#   'result': {'best_epoch': 4,
#    'eval_time': 1636397727.6489,
#    'history': <keras.callbacks.History at 0x7f1af4221d50>,
#    'loss': 1.4638895988464355,
#    'model': <keras.engine.sequential.Sequential at 0x7f1af427fad0>,
#    'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 2,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 11, 8, 18, 55, 27, 656000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dropout': [3], 'n_filters_conv': [3], 'neurons_dense': [3]},
#    'tid': 3,
#    'vals': {'dropout': [0.27957105898309437],
#     'n_filters_conv': [2],
#     'neurons_dense': [2]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 11, 8, 18, 55, 49, 669000),
#   'result': {'best_epoch': 4,
#    'eval_time': 1636397749.6697288,
#    'history': <keras.callbacks.History at 0x7f1ade79d150>,
#    'loss': 1.3307889699935913,
#    'model': <keras.engine.sequential.Sequential at 0x7f1af427f190>,
#    'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 3,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 11, 8, 18, 55, 49, 673000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dropout': [4], 'n_filters_conv': [4], 'neurons_dense': [4]},
#    'tid': 4,
#    'vals': {'dropout': [0.3905158605390463],
#     'n_filters_conv': [1],
#     'neurons_dense': [0]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 11, 8, 18, 55, 58, 638000),
#   'result': {'best_epoch': 4,
#    'eval_time': 1636397758.638672,
#    'history': <keras.callbacks.History at 0x7f1ade676110>,
#    'loss': 1.6171038150787354,
#    'model': <keras.engine.sequential.Sequential at 0x7f1ade64ab50>,
#    'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 4,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 11, 8, 18, 55, 58, 642000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dropout': [5], 'n_filters_conv': [5], 'neurons_dense': [5]},
#    'tid': 5,
#    'vals': {'dropout': [0.06328826221784639],
#     'n_filters_conv': [0],
#     'neurons_dense': [2]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 11, 8, 18, 56, 10, 50000),
#   'result': {'best_epoch': 4,
#    'eval_time': 1636397770.050746,
#    'history': <keras.callbacks.History at 0x7f1ade48c850>,
#    'loss': 1.5200520753860474,
#    'model': <keras.engine.sequential.Sequential at 0x7f1ade46a390>,
#    'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 5,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 11, 8, 18, 56, 10, 55000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dropout': [6], 'n_filters_conv': [6], 'neurons_dense': [6]},
#    'tid': 6,
#    'vals': {'dropout': [0.40071804425666835],
#     'n_filters_conv': [1],
#     'neurons_dense': [0]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 11, 8, 18, 56, 19, 180000),
#   'result': {'best_epoch': 4,
#    'eval_time': 1636397779.1801438,
#    'history': <keras.callbacks.History at 0x7f1ade1dd510>,
#    'loss': 1.6719541549682617,
#    'model': <keras.engine.sequential.Sequential at 0x7f1ade240a90>,
#    'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 6,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 11, 8, 18, 56, 19, 185000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dropout': [7], 'n_filters_conv': [7], 'neurons_dense': [7]},
#    'tid': 7,
#    'vals': {'dropout': [0.24485561494462055],
#     'n_filters_conv': [1],
#     'neurons_dense': [2]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 11, 8, 18, 56, 28, 537000),
#   'result': {'best_epoch': 4,
#    'eval_time': 1636397788.537588,
#    'history': <keras.callbacks.History at 0x7f1a261fae90>,
#    'loss': 1.4742319583892822,
#    'model': <keras.engine.sequential.Sequential at 0x7f1ade1cbb50>,
#    'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 7,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 11, 8, 18, 56, 28, 542000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dropout': [8], 'n_filters_conv': [8], 'neurons_dense': [8]},
#    'tid': 8,
#    'vals': {'dropout': [0.2680128013718139],
#     'n_filters_conv': [1],
#     'neurons_dense': [1]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 11, 8, 18, 56, 37, 909000),
#   'result': {'best_epoch': 4,
#    'eval_time': 1636397797.9094422,
#    'history': <keras.callbacks.History at 0x7f1963fd81d0>,
#    'loss': 1.5017356872558594,
#    'model': <keras.engine.sequential.Sequential at 0x7f1a26210b50>,
#    'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 8,
#   'version': 0},
#  {'book_time': datetime.datetime(2021, 11, 8, 18, 56, 37, 916000),
#   'exp_key': None,
#   'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'idxs': {'dropout': [9], 'n_filters_conv': [9], 'neurons_dense': [9]},
#    'tid': 9,
#    'vals': {'dropout': [0.43902857958301533],
#     'n_filters_conv': [0],
#     'neurons_dense': [1]},
#    'workdir': None},
#   'owner': None,
#   'refresh_time': datetime.datetime(2021, 11, 8, 18, 56, 46, 854000),
#   'result': {'best_epoch': 4,
#    'eval_time': 1636397806.8546188,
#    'history': <keras.callbacks.History at 0x7f1963df6a50>,
#    'loss': 1.7830910682678223,
#    'model': <keras.engine.sequential.Sequential at 0x7f1963e0a350>,
#    'status': 'ok'},
#   'spec': None,
#   'state': 2,
#   'tid': 9,
#   'version': 0}]

# %% [markdown]
# ¿Por qué dice que best_epoch=4? Porque history está indexado en 0.

# %%
trials.trials[6]
# Out:
# {'book_time': datetime.datetime(2021, 11, 8, 18, 56, 10, 55000),
#  'exp_key': None,
#  'misc': {'cmd': ('domain_attachment', 'FMinIter_Domain'),
#   'idxs': {'dropout': [6], 'n_filters_conv': [6], 'neurons_dense': [6]},
#   'tid': 6,
#   'vals': {'dropout': [0.40071804425666835],
#    'n_filters_conv': [1],
#    'neurons_dense': [0]},
#   'workdir': None},
#  'owner': None,
#  'refresh_time': datetime.datetime(2021, 11, 8, 18, 56, 19, 180000),
#  'result': {'best_epoch': 4,
#   'eval_time': 1636397779.1801438,
#   'history': <keras.callbacks.History at 0x7f1ade1dd510>,
#   'loss': 1.6719541549682617,
#   'model': <keras.engine.sequential.Sequential at 0x7f1ade240a90>,
#   'status': 'ok'},
#  'spec': None,
#  'state': 2,
#  'tid': 6,
#  'version': 0}

# %%
trials.results
# Out:
# [{'best_epoch': 4,
#   'eval_time': 1636397701.5915682,
#   'history': <keras.callbacks.History at 0x7f1b6009b3d0>,
#   'loss': 1.2698273658752441,
#   'model': <keras.engine.sequential.Sequential at 0x7f1b718f9710>,
#   'status': 'ok'},
#  {'best_epoch': 4,
#   'eval_time': 1636397713.2631986,
#   'history': <keras.callbacks.History at 0x7f1af4447210>,
#   'loss': 1.6546269655227661,
#   'model': <keras.engine.sequential.Sequential at 0x7f1af4472690>,
#   'status': 'ok'},
#  {'best_epoch': 4,
#   'eval_time': 1636397727.6489,
#   'history': <keras.callbacks.History at 0x7f1af4221d50>,
#   'loss': 1.4638895988464355,
#   'model': <keras.engine.sequential.Sequential at 0x7f1af427fad0>,
#   'status': 'ok'},
#  {'best_epoch': 4,
#   'eval_time': 1636397749.6697288,
#   'history': <keras.callbacks.History at 0x7f1ade79d150>,
#   'loss': 1.3307889699935913,
#   'model': <keras.engine.sequential.Sequential at 0x7f1af427f190>,
#   'status': 'ok'},
#  {'best_epoch': 4,
#   'eval_time': 1636397758.638672,
#   'history': <keras.callbacks.History at 0x7f1ade676110>,
#   'loss': 1.6171038150787354,
#   'model': <keras.engine.sequential.Sequential at 0x7f1ade64ab50>,
#   'status': 'ok'},
#  {'best_epoch': 4,
#   'eval_time': 1636397770.050746,
#   'history': <keras.callbacks.History at 0x7f1ade48c850>,
#   'loss': 1.5200520753860474,
#   'model': <keras.engine.sequential.Sequential at 0x7f1ade46a390>,
#   'status': 'ok'},
#  {'best_epoch': 4,
#   'eval_time': 1636397779.1801438,
#   'history': <keras.callbacks.History at 0x7f1ade1dd510>,
#   'loss': 1.6719541549682617,
#   'model': <keras.engine.sequential.Sequential at 0x7f1ade240a90>,
#   'status': 'ok'},
#  {'best_epoch': 4,
#   'eval_time': 1636397788.537588,
#   'history': <keras.callbacks.History at 0x7f1a261fae90>,
#   'loss': 1.4742319583892822,
#   'model': <keras.engine.sequential.Sequential at 0x7f1ade1cbb50>,
#   'status': 'ok'},
#  {'best_epoch': 4,
#   'eval_time': 1636397797.9094422,
#   'history': <keras.callbacks.History at 0x7f1963fd81d0>,
#   'loss': 1.5017356872558594,
#   'model': <keras.engine.sequential.Sequential at 0x7f1a26210b50>,
#   'status': 'ok'},
#  {'best_epoch': 4,
#   'eval_time': 1636397806.8546188,
#   'history': <keras.callbacks.History at 0x7f1963df6a50>,
#   'loss': 1.7830910682678223,
#   'model': <keras.engine.sequential.Sequential at 0x7f1963e0a350>,
#   'status': 'ok'}]

# %%
trials.losses()
# Out:
# [1.2698273658752441,
#  1.6546269655227661,
#  1.4638895988464355,
#  1.3307889699935913,
#  1.6171038150787354,
#  1.5200520753860474,
#  1.6719541549682617,
#  1.4742319583892822,
#  1.5017356872558594,
#  1.7830910682678223]

# %% [markdown]
# Qué os parece? mola eh? Así, podéis dejar vuestra configuración e iros a hacer algo más útil que andar variando parámetros hasta que encontréis la configuración adecuada.
#
# **Mejor que lo hagan por nosotros y que nos la encontremos automáticamente seleccionada!**
#
# Pero no tenemos por qué quedarnos aquí, podemos también variar el número de capas o si queremos conexiones residuales, por ejemplo! Sí, esto significa que podemos variar la **arquitectura** también!!
#
# Aquí tenéis un ejemplo muy completo: https://github.com/Vooban/Hyperopt-Keras-CNN-CIFAR-100
#
# Y aquí otro que quizá os parezca interesante:
#
# <img src="http://cdn.lizamayliza.com/storage/cache/images/003/636/Daffy-Duck-Money-eyes-feature,xlarge.1480369578.jpg" border="0" height="200">
#
# https://medium.com/machine-learning-world/neural-networks-for-algorithmic-trading-hyperparameters-optimization-cb2b4a29b8ee

# %% [markdown]
# ## 6.3 Algoritmos genéticos
#
# Quizás estéis pensando en que tras haber visto esto no necesitáis saber nada más, ya habéis encontrado algo que es la repera! Pues atentos porque lo que viene, pese a ser algo muy sencillo, es potentísimo, y os va encantar. Sí, estoy hablando de **los algoritmos genéticos**.
#
# En esencia, los algoritmos genéticos son un método de búsqueda meta-heurística inspirados en la evolución natural. Pertenecen a los algoritmos evolutivos, concretamente a los Algoritmos de búsqueda aleatoria guiada (Guided Random Search algorithms (Evolutionary Alg.)).
#
# Esto que os puede parecer chino, es muy sencillo. Vamos a entenderlos con un ejemplo:
#
# <img src="https://image.ibb.co/cJcQYJ/ga_problem.png" alt="ga_problem" border="0">
#
# Imaginad que tenemos un puzzle, y nos queda solo una pieza por encajar. Lo que pasa es que este puzzle es muy especial, porque nos permite fabricarnos nuestras propias piezas. Para ello, disponemos de varios mecanismos:
#
# * **combinar** partes de piezas (**crossover** o recombinación)
# * **modificar** determinadas partes de esas piezas (**mutación**)
# * **escoger** las mejores piezas de todas las que hemos hecho, para a partir de ellas, construir nuevas que sean mejores (**selección**)
#
# Entonces imaginaos que decidimos cortar 10 trozos de carton, que son nuestras 10 piezas iniciales con las que vamos a probar a ver si alguna encaja perfectamnte. Las probamos todas, y de esas 10, 5 encajan más o menos. Así que seleccionamos esas 5 y fabricamos nuevas a partir de ellas mediante los mecanismos explicados arriba:
#
# * de las 5 seleccionadas, sacamos 5 más combinando partes de dos de esas 5 originales escogiéndolas aleatoriamente
# * de las 5 originales, y las nuevas 5 que nos hemos creado, sacamos 5 más modificando ligeramente una de las puntas de la pieza
#
# Ahora resulta que tenemos 15 piezas, y nosotros queremos tener siempre 10, porque si no a la 5 vez que hiciéramos esto tendríamos una barbaridad de piezas!! Así que:
#
# * probamos nuestras 15 piezas y nos quedamos con la que mejor encaja, y luego 9 escogidas al azar
#
# Pues ya está, eso es lo que hace un algoritmo genético!! Ya sabéis cómo funcionan!! Sencillo, verdad? Pues no os hacéis una idea de lo potentes que son :-)
#
# Vamos a verlo un poco más concreto siguiendo con nuestro ejemplo:
#
# <img src="https://image.ibb.co/b7ySfy/geneticos_puzzle.png" alt="geneticos_puzzle" border="0">
#
# Como podéis ver:
#
# * cada pieza de nuestro conjunto de piezas (población) es un **cromosoma**
# * cada parte de nuestra pieza es un **gen**, por tanto, nuestro cromosoma tiene 4 genes
# * los posibles valores o configuraciones que puede tener cada gen se llama **alelo**
#
# Esto es exactamente igual que en biología! No os dije que estaban inspirados en la evolución natural? :-)
#
# Vale, pues vamos a ir relacionando estas palabrejas con nuestro ejemplo:
#
# * necesitamos encontrar la pieza correcta para nuestro hueco del puzzle
# * tenemos un conjunto inicial de piezas (**población**) que pueden encajar bien o no, no lo sabemos
# * comprobamos cómo de bien encajan estas piezas (usando la **función de fitness**)
# * si ninguna de las piezas encaja como nos gustaría, modificamos las piezas (con los operadores: **crossover** y **mutación**)
# * comprobamos como de bien encajan las piezas recien creadas (**función de fitness**)
# * seleccionamos las piezas que queremos aguantar para la próxima iteración (**selección**)
#
# * y volvemos a empezar! así, hasta que enocntremos una pieza que encaje con la precisión que nosotros queremos
#
# Venga, vamos a ponernos un poco más serios. Veamos el pseudo-algoritmo:
#
# **START**
#
# Generate the initial population
#
# Compute fitness
#
# **REPEAT**
#
#     Selection
#
#     Crossover
#
#     Mutation
#
#     Compute fitness
#
# **UNTIL** population has converged
#
# **STOP**
#
# Se entiende, no? Es exactamente lo mismo que los pasos que acabamos de hablar con el puzzle!!
#
# <img src="https://image.ibb.co/kQu7Ed/ga_workflow.png" alt="ga_workflow" border="0" width="600">
#
# Vale, y ahora llega lo interesante, cómo funcionan realmente?
#
# Tenemos que entender varios conceptos:
#
# * cómo se inicializa nuestra población
# * cómo funciona el crossover
# * cómo funciona la mutación
# * cómo funciona la seleccion
# * cómo podemos definir nuestra función de fitness
#
# Preparados? Vamos allá!

# %% [markdown]
# Lo primero es entender que cuando tenemos un problema en el mundo real y queremos solucionarlo en un ordenador, necesitamos **codificarlo** para que el ordenador lo entienda.
#
# Así, por ejemplo:
#
# * En el mundo real, el cromosoma es la pieza del puzzle. En el ordenador, el cromosoma es un vector con 4 valores (uno para indicar el tamaño de cada punta, donde positivo significa punta, negativo significa hueco hacia dentro de la pieza)
#
# Esto es a lo que se llama la codificación.
#
# Una vez sabido esto, vamos a ver cómo funcionan los operadores. Antes de nada, debéis saber que xisten muchos tipos de crossover, mutación y selección, pero aquí vamos a ver solo los más sencillos por temas de tiempo.
#
# Si estáis interesados en conocerlos más profundamente, en internet hay muchísimo material disponible. Podéis empezar aquí: https://www.tutorialspoint.com/genetic_algorithms/index.htm
#
# Vale, al turrón!
#
# <img src="https://image.ibb.co/hEwVHd/ga_operators.png" alt="ga_operators" border="0">
#
# **El crossover de un único punto (single-point crossover)**
#
# Nuestro cromosoma es la pieza de puzzle, que tiene los 4 genes que veis en la imagen. Pues el crossover simple sencillamente escoge un punto aleatoriamente de los 4 genes, y combina las partes en nuevos cromosomas, como veis en la imagen.
#
# Es importante que entendáis que el crossover **produce nuevos cromosomas**, puesto que tenemos los originales y los **recombinados**.
#
# **La mutación uniforme**
#
# La mutación uniforme consiste en que para cada cromosoma, lanzamos una moneda al aire. Si sale cara, modificamos un gen escogido aleatoriamente. ¿Qué valor le asignamos? Uno aleatorio dentro del rango que permite dicho gen.
#
# **La selección**
#
# Para la selección lo que se suele hacer es usar las fitness de los cromosomas (también llamados posibles **soluciones**). En este caso, vamos a ver la Stochastic Universal Sampling, que consiste en que construímos una gráfica de tipo tarta donde cada cromosoma ocupa un espacio que corresponde con su fitness. Después, establecemos N puntos fijos alrededor de la "tarta", donde N son el número de cromomsomas que queremos **seleccionar**. Después, se "gira la tarta", como si fuese la ruleta de la suerte, y los cromosomas a los que apuntan los puntos fijos son los seleccionados y pasan a la siguiente iteración.
#
# Si os fijáis, **los cromosomas no están ordenados de mayor a menor fitness**!!
#
# Esto es importante, puesto que si no, las probabilidades de seleccionar un cromosoma con una fitness alta y otro con una fitness baja serían más altas que de seleccionar dos con la fitness alta, ya que al estar los puntos de selección uno enfrente del otro, sería muy complicado seleccionar dos cromosomas con fitness parecidas.
#
# Este operador tiene varias formas de funcionar. Siguiendo con nuestro ejemplo de población de 10 cromosomas, las formas son:
#
# * Seleccionamos $N=10$ cromosomas, es decir, sustituimos la anterior población por una completamente nueva
# * Seleccionamos $N=n$ cromosomas, donde n<10. Es decir, sustituímos solo una parte de los crosomomas antiguos. El resto siguen jugando ;-D
#
# Vale, pues si seleccionamos los 10 está claro, pero si seleccionamos $n$, cómo elegimos cuales quitamos?
#
# Pues las dos formas más comunes son:
#
# * Quitamos los cromosomas más antiguos
# * Quitamos los cromosomas con peor fitness
#
# Ya por último, hay veces que seleccionamos al mejor cromosoma (o a los $k$ mejors) para que pase si o si a la siguiente iteración, es decir, hay *elitismo*. Hay que ir con cuidado con esto, puesto que aunque a priori parezca que el elitismo es lo mejor y que solo deberíamos quedarnos con los mejores, si lo hiciésemos nos estaríamos cargando una de las mayores virtudes de los genéticos: **que son capaces de escapar a mínimos locales!!!**
#
# Fijaos, aquí podéis ver en plena acción a un genético intentando decidir cual es la mejor configuración para un vehículo de 2 ruedas: http://rednuht.org/genetic_cars_2/
#
# Curioso, eh?
#
# Vale, pues ahora qué tal si implementamos un par de ejemplos nosotros?

# %%
# ejemplo simple de un GA donde tenemos que encontrar N números que sumen X
# https://lethain.com/genetic-algorithms-cool-name-damn-simple

from random import randint, random
from operator import add
from functools import reduce
import numpy as np

def individual(length, min, max):
    # creamos un individuo
    return [ randint(min,max) for x in range(length) ]

def population(count, length, min, max):   
    # creamos nuestra población
    # count: numero de invidiuos en la población
    # length: número de valores por individuo
    # min: minimo permitido para cada valor del individuo
    # max: maximo permitido para cada valor del individuo

    return [ individual(length, min, max) for x in range(count) ]

def fitness(individual, target):
    # calculamos la fitness de un individuo: más bajo es mejor
    
    sum = reduce(add, individual, 0)
    return abs(target-sum)

def grade(pop, target):
    # calculamos la media de la población entera
    summed = reduce(add, (fitness(x, target) for x in pop))
    return summed / (len(pop) * 1.0)
  
def find_best_solution(pop, target):
    # encuentra la mejor solución en la población actual y la imprime
    res = [fitness(x, target) for x in pop]
    res_min = np.min(res)
    res_min_idx = np.where(res == res_min)[0]
    for n in res_min_idx:
        print('Individual: ', n, 'Valores: ', *pop[n], ' Result: ', np.sum(pop[n]), 'Target; ', target)
    return res_min    

def evolve(pop, target, retain=0.2, random_select=0.05, mutate=0.01):
    graded = [ (fitness(x, target), x) for x in pop]
    graded = [ x[1] for x in sorted(graded)]
    retain_length = int(len(graded)*retain)
    parents = graded[:retain_length]
    
    # añadimos individuos aleatoriamente para promover la diversidad genética
    for individual in graded[retain_length:]:
        if random_select > random():
            parents.append(individual)
    
    # mutamos algunos
    for individual in parents:
        if mutate > random():
            pos_to_mutate = randint(0, len(individual)-1)
            individual[pos_to_mutate] = randint(i_min, i_max)
    
    # reproducimos (crossover) nuestros cromosomas (individuals, soluciones)
    parents_length = len(parents)
    desired_length = len(pop) - parents_length
    children = []
    while len(children) < desired_length:
        male = randint(0, parents_length-1)
        female = randint(0, parents_length-1)
        if male != female:
            male = parents[male]
            female = parents[female]
            half = round(len(male) / 2)
            child = male[:half] + female[half:]
            children.append(child)        
    parents.extend(children)
    return parents

# ejecutamos el GA
generations = 200
target = 108
p_count = 20
i_length = 10
i_min = 0
i_max = 100
error_accepted = 1
print('Inicializamos la población con 20 individuos.')
p = population(p_count, i_length, i_min, i_max)
print('Calculamos el fitness de esos 20 individuos.')
fitness_history = [grade(p, target),]
print('El mejor individuo de la población inicial es:')
find_best_solution(p, target)

print('Comienza la búsqueda:')
for i in range(generations):
    p = evolve(p, target, retain=0.2, random_select=0.2, mutate=0.4)
    res = grade(p, target)
    fitness_history.append(res)
    
    res_min = find_best_solution(p, target)
    print('Generación: ', i, ' Fitness medio de todos los individuos de la población:', res)
    
    if res_min < error_accepted:
      break
# Out:
# Inicializamos la población con 20 individuos.
# Calculamos el fitness de esos 20 individuos.
# El mejor individuo de la población inicial es:
# Individual:  5 Valores:  11 1 58 40 12 85 69 15 61 5  Result:  357 Target;  108
# Comienza la búsqueda:
# Individual:  12 Valores:  11 1 58 40 12 75 18 6 90 41  Result:  352 Target;  108
# Generación:  0  Fitness medio de todos los individuos de la población: 361.85
# Individual:  15 Valores:  11 1 9 40 12 85 24 15 61 5  Result:  263 Target;  108
# Generación:  1  Fitness medio de todos los individuos de la población: 285.15
# Individual:  0 Valores:  11 1 9 40 12 85 24 15 61 5  Result:  263 Target;  108
# Generación:  2  Fitness medio de todos los individuos de la población: 294.1
# Individual:  0 Valores:  11 1 9 40 12 23 24 15 61 5  Result:  201 Target;  108
# Generación:  3  Fitness medio de todos los individuos de la población: 259.75
# Individual:  0 Valores:  11 1 9 40 12 23 24 15 61 5  Result:  201 Target;  108
# Generación:  4  Fitness medio de todos los individuos de la población: 294.25
# Individual:  0 Valores:  11 1 9 40 12 23 24 15 61 5  Result:  201 Target;  108
# Individual:  12 Valores:  11 1 9 40 12 23 24 15 61 5  Result:  201 Target;  108
# Generación:  5  Fitness medio de todos los individuos de la población: 209.05
# Individual:  1 Valores:  11 1 9 40 12 23 5 15 61 5  Result:  182 Target;  108
# Generación:  6  Fitness medio de todos los individuos de la población: 188.3
# Individual:  0 Valores:  11 1 9 40 12 23 5 15 61 5  Result:  182 Target;  108
# Individual:  11 Valores:  11 1 9 40 12 23 5 15 61 5  Result:  182 Target;  108
# Individual:  15 Valores:  11 1 9 40 12 23 5 15 61 5  Result:  182 Target;  108
# Generación:  7  Fitness medio de todos los individuos de la población: 134.25
# Individual:  0 Valores:  11 1 9 40 12 23 5 15 61 5  Result:  182 Target;  108
# Individual:  9 Valores:  11 1 9 40 12 23 5 15 61 5  Result:  182 Target;  108
# Individual:  12 Valores:  11 1 9 40 12 23 5 15 61 5  Result:  182 Target;  108
# Generación:  8  Fitness medio de todos los individuos de la población: 101.5
# Individual:  0 Valores:  11 1 9 40 12 23 5 15 61 5  Result:  182 Target;  108
# Individual:  11 Valores:  11 1 9 40 12 23 5 15 61 5  Result:  182 Target;  108
# Generación:  9  Fitness medio de todos los individuos de la población: 123.75
# Individual:  1 Valores:  11 1 9 40 12 23 5 15 61 5  Result:  182 Target;  108
# Individual:  10 Valores:  11 1 9 40 12 23 5 15 61 5  Result:  182 Target;  108
# Individual:  13 Valores:  11 1 9 40 12 23 5 15 61 5  Result:  182 Target;  108
# Individual:  14 Valores:  11 1 9 40 12 23 5 15 61 5  Result:  182 Target;  108
# Generación:  10  Fitness medio de todos los individuos de la población: 123.9
# Individual:  2 Valores:  11 1 9 40 12 23 5 15 33 5  Result:  154 Target;  108
# Generación:  11  Fitness medio de todos los individuos de la población: 104.0
# Individual:  1 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Generación:  12  Fitness medio de todos los individuos de la población: 102.95
# Individual:  0 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Generación:  13  Fitness medio de todos los individuos de la población: 119.75
# Individual:  0 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  11 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  13 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  16 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Generación:  14  Fitness medio de todos los individuos de la población: 96.35
# Individual:  0 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  1 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  3 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  5 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  7 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  10 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  14 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  15 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  16 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  17 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  18 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  19 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Generación:  15  Fitness medio de todos los individuos de la población: 78.35
# Individual:  0 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  2 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  3 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  4 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  7 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  9 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  10 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  12 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  13 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  14 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  17 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  18 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Individual:  19 Valores:  11 1 9 40 12 23 24 15 30 5  Result:  170 Target;  108
# Generación:  16  Fitness medio de todos los individuos de la población: 82.85
# Individual:  16 Valores:  11 1 9 38 12 23 19 15 30 5  Result:  163 Target;  108
# Generación:  17  Fitness medio de todos los individuos de la población: 77.55
# Individual:  5 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Generación:  18  Fitness medio de todos los individuos de la población: 86.85
# Individual:  8 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Generación:  19  Fitness medio de todos los individuos de la población: 83.75
# Individual:  0 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  14 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Generación:  20  Fitness medio de todos los individuos de la población: 78.5
# Individual:  1 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  9 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  12 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Generación:  21  Fitness medio de todos los individuos de la población: 90.15
# Individual:  0 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  2 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  12 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  13 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  14 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  15 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  18 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Generación:  22  Fitness medio de todos los individuos de la población: 67.15
# Individual:  0 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  1 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  2 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  3 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  4 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  8 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  10 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  11 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  14 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  16 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  17 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  19 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Generación:  23  Fitness medio de todos los individuos de la población: 52.1
# Individual:  1 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  3 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  4 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  5 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  10 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  12 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  16 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  17 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  18 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Individual:  19 Valores:  11 1 9 40 12 23 9 15 30 5  Result:  155 Target;  108
# Generación:  24  Fitness medio de todos los individuos de la población: 61.25
# Individual:  2 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Individual:  9 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Individual:  13 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Individual:  16 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Generación:  25  Fitness medio de todos los individuos de la población: 63.6
# Individual:  1 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Individual:  2 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Individual:  9 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Individual:  11 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Individual:  12 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Individual:  19 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Generación:  26  Fitness medio de todos los individuos de la población: 71.6
# Individual:  0 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Individual:  1 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Individual:  2 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Individual:  3 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Individual:  10 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Individual:  12 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Individual:  14 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Individual:  16 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Individual:  18 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Individual:  19 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Generación:  27  Fitness medio de todos los individuos de la población: 70.55
# Individual:  0 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Individual:  2 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Individual:  3 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Individual:  11 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Individual:  13 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Individual:  15 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Individual:  19 Valores:  11 1 9 40 12 23 9 15 27 5  Result:  152 Target;  108
# Generación:  28  Fitness medio de todos los individuos de la población: 65.2
# Individual:  3 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  7 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  14 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  16 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Generación:  29  Fitness medio de todos los individuos de la población: 45.8
# Individual:  0 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  1 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  2 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  3 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  12 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  14 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  15 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  16 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  18 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  19 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Generación:  30  Fitness medio de todos los individuos de la población: 50.7
# Individual:  1 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  2 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  3 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  10 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  13 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  18 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Generación:  31  Fitness medio de todos los individuos de la población: 84.0
# Individual:  0 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  1 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  2 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  3 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  11 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  12 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  13 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  14 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  15 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  18 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Generación:  32  Fitness medio de todos los individuos de la población: 99.25
# Individual:  0 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  1 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  3 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  7 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  8 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  11 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  14 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  18 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Generación:  33  Fitness medio de todos los individuos de la población: 99.65
# Individual:  0 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  1 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  2 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  3 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  5 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  6 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  8 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  9 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  10 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  11 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  12 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  13 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  15 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  16 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  17 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  18 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Individual:  19 Valores:  11 1 9 40 12 14 9 15 27 5  Result:  143 Target;  108
# Generación:  34  Fitness medio de todos los individuos de la población: 41.75
# Individual:  6 Valores:  11 1 9 29 12 14 9 15 27 5  Result:  132 Target;  108
# Generación:  35  Fitness medio de todos los individuos de la población: 61.7
# Individual:  0 Valores:  11 1 9 29 12 14 9 15 27 5  Result:  132 Target;  108
# Generación:  36  Fitness medio de todos los individuos de la población: 76.1
# Individual:  0 Valores:  11 1 9 29 12 14 9 15 27 5  Result:  132 Target;  108
# Generación:  37  Fitness medio de todos los individuos de la población: 85.8
# Individual:  0 Valores:  11 1 9 29 12 14 9 15 27 5  Result:  132 Target;  108
# Individual:  5 Valores:  11 1 9 29 12 14 9 15 27 5  Result:  132 Target;  108
# Individual:  13 Valores:  11 1 9 29 12 14 9 15 27 5  Result:  132 Target;  108
# Individual:  15 Valores:  11 1 9 29 12 14 9 15 27 5  Result:  132 Target;  108
# Generación:  38  Fitness medio de todos los individuos de la población: 31.7
# Individual:  2 Valores:  11 1 9 29 12 14 9 15 27 5  Result:  132 Target;  108
# Individual:  3 Valores:  11 1 9 29 12 14 9 15 27 5  Result:  132 Target;  108
# Individual:  11 Valores:  11 1 9 29 12 14 9 15 27 5  Result:  132 Target;  108
# Individual:  15 Valores:  11 1 9 29 12 14 9 15 27 5  Result:  132 Target;  108
# Generación:  39  Fitness medio de todos los individuos de la población: 59.75
# Individual:  2 Valores:  11 1 9 28 12 14 9 15 27 5  Result:  131 Target;  108
# Individual:  7 Valores:  11 1 9 28 12 14 9 15 27 5  Result:  131 Target;  108
# Individual:  12 Valores:  11 1 9 28 12 14 9 15 27 5  Result:  131 Target;  108
# Generación:  40  Fitness medio de todos los individuos de la población: 43.05
# Individual:  19 Valores:  11 1 9 28 12 6 9 15 27 5  Result:  123 Target;  108
# Generación:  41  Fitness medio de todos los individuos de la población: 56.15
# Individual:  5 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Individual:  10 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Individual:  14 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Generación:  42  Fitness medio de todos los individuos de la población: 26.6
# Individual:  1 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Individual:  9 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Individual:  17 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Generación:  43  Fitness medio de todos los individuos de la población: 55.95
# Individual:  14 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Individual:  18 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Individual:  19 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Generación:  44  Fitness medio de todos los individuos de la población: 55.9
# Individual:  1 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Individual:  12 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Individual:  13 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Individual:  17 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Generación:  45  Fitness medio de todos los individuos de la población: 26.45
# Individual:  0 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Individual:  1 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Individual:  16 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Generación:  46  Fitness medio de todos los individuos de la población: 55.8
# Individual:  0 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Individual:  1 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Individual:  2 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Individual:  9 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Individual:  11 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Individual:  12 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Individual:  13 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Individual:  15 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Individual:  18 Valores:  11 1 4 29 12 6 9 15 27 5  Result:  119 Target;  108
# Generación:  47  Fitness medio de todos los individuos de la población: 42.05
# Individual:  0 Valores:  11 1 4 29 12 6 9 15 27 3  Result:  117 Target;  108
# Individual:  5 Valores:  11 1 4 29 12 6 9 15 27 3  Result:  117 Target;  108
# Individual:  11 Valores:  11 1 4 29 12 6 9 15 27 3  Result:  117 Target;  108
# Individual:  13 Valores:  11 1 4 29 12 6 9 15 27 3  Result:  117 Target;  108
# Individual:  18 Valores:  11 1 4 29 12 6 9 15 27 3  Result:  117 Target;  108
# Generación:  48  Fitness medio de todos los individuos de la población: 30.8
# Individual:  2 Valores:  11 1 4 29 12 6 9 15 27 3  Result:  117 Target;  108
# Individual:  3 Valores:  11 1 4 29 12 6 9 15 27 3  Result:  117 Target;  108
# Individual:  12 Valores:  11 1 4 29 12 6 9 15 27 3  Result:  117 Target;  108
# Individual:  16 Valores:  11 1 4 29 12 6 9 15 27 3  Result:  117 Target;  108
# Generación:  49  Fitness medio de todos los individuos de la población: 68.35
# Individual:  0 Valores:  11 1 4 29 12 6 9 15 27 3  Result:  117 Target;  108
# Individual:  2 Valores:  11 1 4 29 12 6 9 15 27 3  Result:  117 Target;  108
# Generación:  50  Fitness medio de todos los individuos de la población: 79.15
# Individual:  3 Valores:  11 13 4 29 12 6 9 15 11 3  Result:  113 Target;  108
# Generación:  51  Fitness medio de todos los individuos de la población: 79.25
# Individual:  1 Valores:  11 1 4 29 12 6 9 15 11 3  Result:  101 Target;  108
# Generación:  52  Fitness medio de todos los individuos de la población: 95.6
# Individual:  0 Valores:  11 1 4 29 12 6 9 15 11 3  Result:  101 Target;  108
# Individual:  9 Valores:  11 1 4 29 12 6 9 15 11 3  Result:  101 Target;  108
# Individual:  10 Valores:  11 1 4 29 12 6 9 15 11 3  Result:  101 Target;  108
# Individual:  13 Valores:  11 1 4 29 12 6 9 15 11 3  Result:  101 Target;  108
# Generación:  53  Fitness medio de todos los individuos de la población: 59.45
# Individual:  0 Valores:  11 1 4 29 12 6 9 15 11 3  Result:  101 Target;  108
# Individual:  1 Valores:  11 1 4 29 12 6 9 15 11 3  Result:  101 Target;  108
# Individual:  2 Valores:  11 1 4 29 12 6 9 15 11 3  Result:  101 Target;  108
# Individual:  3 Valores:  11 1 4 29 12 6 9 15 11 3  Result:  101 Target;  108
# Individual:  9 Valores:  11 1 4 29 12 6 9 15 11 3  Result:  101 Target;  108
# Individual:  11 Valores:  11 1 4 29 12 6 9 15 11 3  Result:  101 Target;  108
# Individual:  18 Valores:  11 1 4 29 12 6 9 15 11 3  Result:  101 Target;  108
# Generación:  54  Fitness medio de todos los individuos de la población: 34.7
# Individual:  0 Valores:  11 1 4 29 12 6 9 15 11 3  Result:  101 Target;  108
# Individual:  1 Valores:  11 1 4 29 12 6 9 15 11 3  Result:  101 Target;  108
# Individual:  3 Valores:  11 1 4 29 12 6 9 15 11 3  Result:  101 Target;  108
# Individual:  5 Valores:  11 1 4 29 12 6 9 15 11 3  Result:  101 Target;  108
# Individual:  6 Valores:  11 1 4 29 12 6 9 15 11 3  Result:  101 Target;  108
# Individual:  11 Valores:  11 1 4 29 12 6 9 15 11 3  Result:  101 Target;  108
# Individual:  16 Valores:  11 1 4 29 12 6 9 15 11 3  Result:  101 Target;  108
# Individual:  19 Valores:  11 1 4 29 12 6 9 15 11 3  Result:  101 Target;  108
# Generación:  55  Fitness medio de todos los individuos de la población: 29.6
# Individual:  4 Valores:  11 1 4 29 12 8 9 15 11 3  Result:  103 Target;  108
# Individual:  16 Valores:  11 1 4 29 12 8 9 15 11 3  Result:  103 Target;  108
# Generación:  56  Fitness medio de todos los individuos de la población: 24.15
# Individual:  0 Valores:  11 1 4 29 12 8 9 15 11 3  Result:  103 Target;  108
# Individual:  1 Valores:  11 1 4 29 12 8 9 15 11 3  Result:  103 Target;  108
# Individual:  7 Valores:  11 1 4 29 12 8 9 15 11 3  Result:  103 Target;  108
# Individual:  9 Valores:  11 1 4 29 12 8 9 15 11 3  Result:  103 Target;  108
# Individual:  12 Valores:  11 1 4 29 12 8 9 15 11 3  Result:  103 Target;  108
# Individual:  13 Valores:  11 1 4 29 12 8 9 15 11 3  Result:  103 Target;  108
# Individual:  15 Valores:  11 1 4 29 12 8 9 15 11 3  Result:  103 Target;  108
# Individual:  18 Valores:  11 1 4 29 12 8 9 15 11 3  Result:  103 Target;  108
# Generación:  57  Fitness medio de todos los individuos de la población: 16.5
# Individual:  0 Valores:  11 1 4 29 12 8 9 15 11 3  Result:  103 Target;  108
# Individual:  1 Valores:  11 1 4 29 12 8 9 15 11 3  Result:  103 Target;  108
# Individual:  3 Valores:  11 1 4 29 12 8 9 15 11 3  Result:  103 Target;  108
# Individual:  12 Valores:  11 1 4 29 12 8 9 15 11 3  Result:  103 Target;  108
# Individual:  13 Valores:  11 1 4 29 12 8 9 15 11 3  Result:  103 Target;  108
# Individual:  15 Valores:  11 1 4 29 12 8 9 15 11 3  Result:  103 Target;  108
# Individual:  16 Valores:  11 1 4 29 12 8 9 15 11 3  Result:  103 Target;  108
# Individual:  17 Valores:  11 1 4 29 12 8 9 15 11 3  Result:  103 Target;  108
# Individual:  19 Valores:  11 1 4 29 12 8 9 15 11 3  Result:  103 Target;  108
# Generación:  58  Fitness medio de todos los individuos de la población: 20.4
# Individual:  2 Valores:  11 1 4 29 12 8 9 15 11 3  Result:  103 Target;  108
# Individual:  3 Valores:  11 1 4 29 12 8 9 15 11 3  Result:  103 Target;  108
# Individual:  5 Valores:  11 1 4 29 12 8 9 15 11 3  Result:  103 Target;  108
# Generación:  59  Fitness medio de todos los individuos de la población: 42.75
# Individual:  0 Valores:  11 1 4 29 12 8 9 15 15 3  Result:  107 Target;  108
# Individual:  8 Valores:  11 1 4 29 12 8 9 15 15 3  Result:  107 Target;  108
# Individual:  15 Valores:  11 1 4 29 12 8 9 15 15 3  Result:  107 Target;  108
# Individual:  19 Valores:  11 1 4 29 12 8 9 15 15 3  Result:  107 Target;  108
# Generación:  60  Fitness medio de todos los individuos de la población: 24.8
# Individual:  2 Valores:  11 1 4 29 12 8 9 15 15 3  Result:  107 Target;  108
# Individual:  11 Valores:  11 1 4 29 12 8 9 15 15 3  Result:  107 Target;  108
# Individual:  12 Valores:  11 1 4 29 12 8 9 15 15 3  Result:  107 Target;  108
# Individual:  13 Valores:  11 1 4 29 12 8 9 15 15 3  Result:  107 Target;  108
# Individual:  18 Valores:  11 1 4 29 12 8 9 15 15 3  Result:  107 Target;  108
# Generación:  61  Fitness medio de todos los individuos de la población: 35.4
# Individual:  5 Valores:  11 1 4 29 6 8 16 15 15 3  Result:  108 Target;  108
# Generación:  62  Fitness medio de todos los individuos de la población: 19.6

# %%
# Ejemplo un poco más complejo de un GA que tiene que encontrar la cadena 'Hello Word!'
# http://www.obitko.com/tutorials/genetic-algorithms/ga-basic-description.php

import random

class GeneticAlgorithm(object):
    def __init__(self, genetics):
        self.genetics = genetics
        pass

    def run(self):
        population = self.genetics.initial()
        while True:
            fits_pops = [(self.genetics.fitness(ch),  ch) for ch in population]
            if self.genetics.check_stop(fits_pops): break
            population = self.next(fits_pops)
            pass
        return population

    def next(self, fits):
        parents_generator = self.genetics.parents(fits)
        size = len(fits)
        nexts = []
        while len(nexts) < size:
            parents = next(parents_generator)
            cross = random.random() < self.genetics.probability_crossover()
            children = self.genetics.crossover(parents) if cross else parents
            for ch in children:
                mutate = random.random() < self.genetics.probability_mutation()
                nexts.append(self.genetics.mutation(ch) if mutate else ch)
                pass
            pass
        return nexts[0:size]
    pass

class GeneticFunctions(object):
    def probability_crossover(self):
        # returns rate of occur crossover(0.0-1.0)
        return 1.0

    def probability_mutation(self):
        # returns rate of occur mutation(0.0-1.0)
        return 0.0

    def initial(self):
        # returns list of initial population        
        return []

    def fitness(self, chromosome):
        # returns domain fitness value of chromosome
        return len(chromosome)

    def check_stop(self, fits_populations):
        # stop run if returns True
        # - fits_populations: list of (fitness_value, chromosome)
        return False

    def parents(self, fits_populations):
        r"""generator of selected parents
        """
        gen = iter(sorted(fits_populations))
        while True:
            f1, ch1 = next(gen)
            f2, ch2 = next(gen)
            yield (ch1, ch2)
            pass
        return

    def crossover(self, parents):
        r"""breed children
        """
        return parents

    def mutation(self, chromosome):
        r"""mutate chromosome
        """
        return chromosome
    pass

if __name__ == "__main__":
    """
    example: Mapped guess prepared Text
    """
    class GuessText(GeneticFunctions):
        def __init__(self, target_text,
                     limit=200, size=400,
                     prob_crossover=0.9, prob_mutation=0.2):
            self.target = self.text2chromo(target_text)
            self.counter = 0

            self.limit = limit
            self.size = size
            self.prob_crossover = prob_crossover
            self.prob_mutation = prob_mutation
            pass

        # GeneticFunctions interface impls
        def probability_crossover(self):
            return self.prob_crossover

        def probability_mutation(self):
            return self.prob_mutation

        def initial(self):
            return [self.random_chromo() for j in range(self.size)]

        def fitness(self, chromo):
            # larger is better, matched == 0
            return -sum(abs(c - t) for c, t in zip(chromo, self.target))

        def check_stop(self, fits_populations):
            self.counter += 1
            if self.counter % 10 == 0:
                best_match = list(sorted(fits_populations))[-1][1]
                fits = [f for f, ch in fits_populations]
                best = max(fits)
                worst = min(fits)
                ave = sum(fits) / len(fits)
                print(
                    "[G %3d] score=(%4d, %4d, %4d): %r" %
                    (self.counter, best, ave, worst,
                     self.chromo2text(best_match)))
                pass
            return self.counter >= self.limit

        def parents(self, fits_populations):
            while True:
                father = self.tournament(fits_populations)
                mother = self.tournament(fits_populations)
                yield (father, mother)
                pass
            pass

        def crossover(self, parents):
            father, mother = parents
            index1 = random.randint(1, len(self.target) - 2)
            index2 = random.randint(1, len(self.target) - 2)
            if index1 > index2: index1, index2 = index2, index1
            child1 = father[:index1] + mother[index1:index2] + father[index2:]
            child2 = mother[:index1] + father[index1:index2] + mother[index2:]
            return (child1, child2)

        def mutation(self, chromosome):
            index = random.randint(0, len(self.target) - 1)
            vary = random.randint(-5, 5)
            mutated = list(chromosome)
            mutated[index] += vary
            return mutated

        # internals
        def tournament(self, fits_populations):
            alicef, alice = self.select_random(fits_populations)
            bobf, bob = self.select_random(fits_populations)
            return alice if alicef > bobf else bob

        def select_random(self, fits_populations):
            return fits_populations[random.randint(0, len(fits_populations)-1)]

        def text2chromo(self, text):
            return [ord(ch) for ch in text]
        def chromo2text(self, chromo):
            return "".join(chr(max(1, min(ch, 255))) for ch in chromo)

        def random_chromo(self):
            return [random.randint(1, 255) for i in range(len(self.target))]
        pass

    GeneticAlgorithm(GuessText("Hello World!")).run()
    pass
# Out:
# [G  10] score=(-149, -321, -473): '+MVpf YjxljK'
# [G  20] score=( -67, -108, -166): 'Wpkmv ^osfe2'
# [G  30] score=( -47,  -59,  -77): 'Rolmj Yotld2'
# [G  40] score=( -27,  -39,  -51): 'Sflmo Wotld-'
# [G  50] score=( -11,  -21,  -34): 'Iflmm Yosld$'
# [G  60] score=(  -5,  -10,  -20): 'Ifllo World$'
# [G  70] score=(  -2,   -5,  -11): 'Ifllo World!'
# [G  80] score=(   0,   -2,   -7): 'Hello World!'
# [G  90] score=(   0,    0,   -7): 'Hello World!'
# [G 100] score=(   0,    0,   -7): 'Hello World!'
# [G 110] score=(   0,    0,   -8): 'Hello World!'
# [G 120] score=(   0,    0,   -8): 'Hello World!'
# [G 130] score=(   0,    0,   -5): 'Hello World!'
# [G 140] score=(   0,    0,   -5): 'Hello World!'
# [G 150] score=(   0,    0,   -8): 'Hello World!'
# [G 160] score=(   0,    0,   -6): 'Hello World!'
# [G 170] score=(   0,    0,   -6): 'Hello World!'
# [G 180] score=(   0,    0,   -9): 'Hello World!'
# [G 190] score=(   0,    0,   -5): 'Hello World!'
# [G 200] score=(   0,    0,   -7): 'Hello World!'

# %% [markdown]
# Fijaos como es capaz de llegar a la cadena "Hello World!" tras unas pocas generaciones!
#
# Y ahora, vamos a verlo aplicado a una red neuronal. Para ello, vamos a hacer uso de una implementación disponible en Github: https://github.com/jliphard/DeepEvolve
#
# Para ello, vamos a clonar un repositorio con git que tiene implementado un GA para evolucionar los hiperparámetros y arquitectura de una red neuronal:

# %%
# !rm -rf DeepEvolve
# !git clone https://github.com/jliphard/DeepEvolve.git
# Out:
# Cloning into 'DeepEvolve'...
# remote: Enumerating objects: 163, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 163 (delta 0), reused 0 (delta 0), pack-reused 160
# Receiving objects: 100% (163/163), 1.52 MiB | 34.60 MiB/s, done.
# Resolving deltas: 100% (84/84), done.

# %%
# !ls
# Out:
# DeepEvolve  sample_data

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.41.1)

# %% [markdown]
# Quiero que veáis los parámetros entre los que va a buscar hasta encontrar la mejor combinación posible:

# %%
if dataset == 'mnist_cnn':
        generations = 8 # Number of times to evolve the population.
        all_possible_genes = {
            'nb_neurons': [16, 32, 64, 128],
            'nb_layers':  [1, 2, 3, 4 ,5],
            'activation': ['relu', 'elu', 'tanh', 'sigmoid', 'hard_sigmoid','softplus','linear'],
            'optimizer':  ['rmsprop', 'adam', 'sgd', 'adagrad','adadelta', 'adamax', 'nadam']
        }

# %%
# !cat DeepEvolve/main.py
# Out:
# """Entry point to evolving the neural network. Start here."""
# from __future__ import print_function
#
# from evolver import Evolver
#
# from tqdm import tqdm
#
# import logging
#
# import sys
#
# # Setup logging.
# logging.basicConfig(
#     format='%(asctime)s - %(levelname)s - %(message)s',
#     datefmt='%m/%d/%Y %I:%M:%S %p',
#     level=logging.INFO#,
#     #filename='log.txt'
# )
#
# def train_genomes(genomes, dataset):
#     """Train each genome.
#
#     Args:
#         networks (list): Current population of genomes
#         dataset (str): Dataset to use for training/evaluating
#
#     """
#     logging.info("***train_networks(networks, dataset)***")
#
#     pbar = tqdm(total=len(genomes))
#
#     for genome in genomes:
#         genome.train(dataset)
#         pbar.update(1)
#
#     pbar.close()
#
# def get_average_accuracy(genomes):
#     """Get the average accuracy for a group of networks/genomes.
#
#     Args:
#         networks (list): List of networks/genomes
#
#     Returns:
#         float: The average accuracy of a population of networks/genomes.
#
#     """
#     total_accuracy = 0
#
#     for genome in genomes:
#         total_accuracy += genome.accuracy
#
#     return total_accuracy / len(genomes)
#
# def generate(generations, population, all_possible_genes, dataset):
#     """Generate a network with the genetic algorithm.
#
#     Args:
#         generations (int): Number of times to evolve the population
#         population (int): Number of networks in each generation
#         all_possible_genes (dict): Parameter choices for networks
#         dataset (str): Dataset to use for training/evaluating
#
#     """
#     logging.info("***generate(generations, population, all_possible_genes, dataset)***")
#
#     evolver = Evolver(all_possible_genes)
#
#     genomes = evolver.create_population(population)
#
#     # Evolve the generation.
#     for i in range( generations ):
#
#         logging.info("***Now in generation %d of %d***" % (i + 1, generations))
#
#         print_genomes(genomes)
#
#         # Train and get accuracy for networks/genomes.
#         train_genomes(genomes, dataset)
#
#         # Get the average accuracy for this generation.
#         average_accuracy = get_average_accuracy(genomes)
#
#         # Print out the average accuracy each generation.
#         logging.info("Generation average: %.2f%%" % (average_accuracy * 100))
#         logging.info('-'*80) #-----------
#
#         # Evolve, except on the last iteration.
#         if i != generations - 1:
#             # Evolve!
#             genomes = evolver.evolve(genomes)
#
#     # Sort our final population according to performance.
#     genomes = sorted(genomes, key=lambda x: x.accuracy, reverse=True)
#
#     # Print out the top 5 networks/genomes.
#     print_genomes(genomes[:5])
#
#     #save_path = saver.save(sess, '/output/model.ckpt')
#     #print("Model saved in file: %s" % save_path)
#
# def print_genomes(genomes):
#     """Print a list of genomes.
#
#     Args:
#         genomes (list): The population of networks/genomes
#
#     """
#     logging.info('-'*80)
#
#     for genome in genomes:
#         genome.print_genome()
#
# def main():
#     """Evolve a genome."""
#     population = 30 # Number of networks/genomes in each generation.
#     #we only need to train the new ones....
#
#     ds = 4
#
#     if(   ds == 1):
#         dataset = 'mnist_mlp'
#     elif (ds == 2):
#         dataset = 'mnist_cnn'
#     elif (ds == 3):
#         dataset = 'cifar10_mlp'
#     elif (ds == 4):
#         dataset = 'cifar10_cnn'
#     else:
#         dataset = 'mnist_mlp'
#
#     print("***Dataset:", dataset)
#
#     if dataset == 'mnist_cnn':
#         generations = 8 # Number of times to evolve the population.
#         all_possible_genes = {
#             'nb_neurons': [16, 32, 64, 128],
#             'nb_layers':  [1, 2, 3, 4 ,5],
#             'activation': ['relu', 'elu', 'tanh', 'sigmoid', 'hard_sigmoid','softplus','linear'],
#             'optimizer':  ['rmsprop', 'adam', 'sgd', 'adagrad','adadelta', 'adamax', 'nadam']
#         }
#     elif dataset == 'mnist_mlp':
#         generations = 8 # Number of times to evolve the population.
#         all_possible_genes = {
#             'nb_neurons': [64, 128], #, 256, 512, 768, 1024],
#             'nb_layers':  [1, 2, 3, 4, 5],
#             'activation': ['relu', 'elu', 'tanh', 'sigmoid', 'hard_sigmoid','softplus','linear'],
#             'optimizer':  ['rmsprop', 'adam', 'sgd', 'adagrad','adadelta', 'adamax', 'nadam']
#         }
#     elif dataset == 'cifar10_mlp':
#         generations = 8 # Number of times to evolve the population.
#         all_possible_genes = {
#             'nb_neurons': [64, 128, 256, 512, 768, 1024],
#             'nb_layers':  [1, 2, 3, 4, 5],
#             'activation': ['relu', 'elu', 'tanh', 'sigmoid', 'hard_sigmoid','softplus','linear'],
#             'optimizer':  ['rmsprop', 'adam', 'sgd', 'adagrad','adadelta', 'adamax', 'nadam']
#         }
#     elif dataset == 'cifar10_cnn':
#         generations = 8 # Number of times to evolve the population.
#         all_possible_genes = {
#             'nb_neurons': [16, 32, 64, 128],
#             'nb_layers':  [1, 2, 3, 4, 5],
#             'activation': ['relu', 'elu', 'tanh', 'sigmoid', 'hard_sigmoid','softplus','linear'],
#             'optimizer':  ['rmsprop', 'adam', 'sgd', 'adagrad','adadelta', 'adamax', 'nadam']
#         }
#     else:
#         generations = 8 # Number of times to evolve the population.
#         all_possible_genes = {
#             'nb_neurons': [64, 128, 256, 512, 768, 1024],
#             'nb_layers':  [1, 2, 3, 4, 5],
#             'activation': ['relu', 'elu', 'tanh', 'sigmoid', 'hard_sigmoid','softplus','linear'],
#             'optimizer':  ['rmsprop', 'adam', 'sgd', 'adagrad','adadelta', 'adamax', 'nadam']
#         }
#
#     # replace nb_neurons with 1 unique value for each layer
#     # 6th value reserved for dense layer
#     nb_neurons = all_possible_genes['nb_neurons']
#     for i in range(1,7):
#       all_possible_genes['nb_neurons_' + str(i)] = nb_neurons
#     # remove old value from dict
#     all_possible_genes.pop('nb_neurons')
#
#     print("***Evolving for %d generations with population size = %d***" % (generations, population))
#
#     generate(generations, population, all_possible_genes, dataset)
#
# if __name__ == '__main__':
#     main()

# %% [markdown]
# Y ahora ejecutamos nuestro algoritmo genético:

# %%
# !python DeepEvolve/main.py
# Out:
# 2021-04-16 18:35:21.673517: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# ***Dataset: cifar10_cnn
# ***Evolving for 8 generations with population size = 30***
# 04/16/2021 06:35:23 PM - INFO - ***generate(generations, population, all_possible_genes, dataset)***
# 04/16/2021 06:35:23 PM - INFO - ***Now in generation 1 of 8***
# 04/16/2021 06:35:23 PM - INFO - --------------------------------------------------------------------------------
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 5, 'activation': 'softplus', 'optimizer': 'adagrad', 'nb_neurons': [128, 128, 32, 16, 32, 32]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 1
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: 251218aa3a46a5d2d3d8d3aa2fd006f0
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 4, 'activation': 'hard_sigmoid', 'optimizer': 'rmsprop', 'nb_neurons': [128, 128, 16, 32, 32, 64]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 2
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: 39e0133356a98da86566e8f5ea627908
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 4, 'activation': 'sigmoid', 'optimizer': 'adadelta', 'nb_neurons': [16, 32, 128, 128, 32, 128]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 3
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: 847a36b5a4a31f3cfab3145e88c3639f
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 2, 'activation': 'sigmoid', 'optimizer': 'adadelta', 'nb_neurons': [128, 64, 32, 16, 64, 64]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 4
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: 56beda3b44c79ef15907fe2fdebe43e4
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 1, 'activation': 'relu', 'optimizer': 'adadelta', 'nb_neurons': [16, 16, 16, 32, 32, 32]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 5
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: f43308e5558ebe64ef1df16b8665b95d
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 4, 'activation': 'hard_sigmoid', 'optimizer': 'adamax', 'nb_neurons': [16, 128, 128, 16, 32, 64]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 6
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: a866ea5e118b5c1f34167babbcc4dca4
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 3, 'activation': 'hard_sigmoid', 'optimizer': 'sgd', 'nb_neurons': [32, 32, 64, 64, 128, 32]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 7
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: b912e0cc62931250e67fcb1498ba8982
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 5, 'activation': 'linear', 'optimizer': 'adagrad', 'nb_neurons': [16, 64, 64, 64, 128, 64]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 8
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: ff48b314627cabb8787893ca6c709894
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 3, 'activation': 'relu', 'optimizer': 'rmsprop', 'nb_neurons': [64, 128, 16, 128, 32, 64]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 9
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: 3c17cd81fec3159c505030c35a4100c7
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 4, 'activation': 'sigmoid', 'optimizer': 'adadelta', 'nb_neurons': [64, 128, 64, 128, 128, 64]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 10
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: ae9ff71a70142472e9e514db30ee911c
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 2, 'activation': 'softplus', 'optimizer': 'nadam', 'nb_neurons': [64, 16, 32, 16, 32, 16]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 11
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: e6848b49a954e1a5f8279c85f8e7f8e4
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 2, 'activation': 'linear', 'optimizer': 'adam', 'nb_neurons': [64, 64, 32, 32, 32, 64]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 12
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: 0f25f3e5e2ef5472784df5a4f36fbb84
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 2, 'activation': 'tanh', 'optimizer': 'adadelta', 'nb_neurons': [32, 32, 128, 128, 128, 32]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 13
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: 5036d544e4c69ed3f58ebf6c01333ab5
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 3, 'activation': 'linear', 'optimizer': 'adagrad', 'nb_neurons': [32, 16, 128, 32, 16, 64]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 14
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: c98518acd383ebcb0d0aa1c09a592cb9
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 4, 'activation': 'sigmoid', 'optimizer': 'adagrad', 'nb_neurons': [16, 16, 128, 16, 16, 128]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 15
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: d51ca18f2d62776718cc18a6b4088788
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 2, 'activation': 'linear', 'optimizer': 'adagrad', 'nb_neurons': [64, 32, 16, 16, 128, 16]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 16
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: 9225a40b74e99fcbce9cd32421944a9f
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 5, 'activation': 'elu', 'optimizer': 'sgd', 'nb_neurons': [128, 64, 128, 64, 32, 32]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 17
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: 32895b50aff6d7d38df7fb0f23e145f1
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 5, 'activation': 'hard_sigmoid', 'optimizer': 'nadam', 'nb_neurons': [128, 16, 32, 32, 128, 32]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 18
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: 65a3dae14fbb42fd7f2f0319dd7c3017
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 1, 'activation': 'tanh', 'optimizer': 'nadam', 'nb_neurons': [64, 128, 128, 16, 16, 128]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 19
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: dd2f72ae9763c148ddcaef9a64e16fb5
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 4, 'activation': 'sigmoid', 'optimizer': 'adamax', 'nb_neurons': [32, 32, 128, 16, 32, 64]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 20
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: 973cf918a8db0a3f9a5886ffc73fb6c2
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 3, 'activation': 'tanh', 'optimizer': 'nadam', 'nb_neurons': [16, 16, 32, 32, 32, 128]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 21
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: 341a49fcff73decad82df4c98e9b49df
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 1, 'activation': 'relu', 'optimizer': 'rmsprop', 'nb_neurons': [128, 16, 128, 16, 64, 64]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 22
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: 97fd8fb44e272a79f1308ea3bb535267
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 4, 'activation': 'softplus', 'optimizer': 'adagrad', 'nb_neurons': [64, 64, 128, 64, 32, 16]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 23
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: 27a1876bd623dcccfd85787450caff24
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 3, 'activation': 'relu', 'optimizer': 'adagrad', 'nb_neurons': [128, 16, 16, 128, 16, 128]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 24
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: 4f9cdb3097c14a3681e422cf85a8bd28
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 5, 'activation': 'sigmoid', 'optimizer': 'adamax', 'nb_neurons': [128, 64, 64, 16, 32, 128]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 25
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: d8e1352c286a1dbd540e5f79ed395383
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 3, 'activation': 'linear', 'optimizer': 'sgd', 'nb_neurons': [32, 64, 16, 16, 64, 32]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 26
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: 38ff7d5c6bcebbbf6120b68172d156f5
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 1, 'activation': 'hard_sigmoid', 'optimizer': 'rmsprop', 'nb_neurons': [128, 16, 16, 128, 16, 16]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 27
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: 421974381cc4c40966d6a878638c030e
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 1, 'activation': 'elu', 'optimizer': 'nadam', 'nb_neurons': [64, 16, 16, 16, 16, 128]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 28
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: b482d28007fa6d20770decdd218886aa
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 4, 'activation': 'linear', 'optimizer': 'adamax', 'nb_neurons': [128, 32, 128, 128, 32, 32]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 29
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: dd71fafdbfd2560ca3b4c0e2ebd8afc5
# 04/16/2021 06:35:23 PM - INFO - {'nb_layers': 1, 'activation': 'hard_sigmoid', 'optimizer': 'adamax', 'nb_neurons': [64, 32, 16, 32, 64, 64]}
# 04/16/2021 06:35:23 PM - INFO - Acc: 0.00%
# 04/16/2021 06:35:23 PM - INFO - UniID: 30
# 04/16/2021 06:35:23 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:35:23 PM - INFO - Gen: 1
# 04/16/2021 06:35:23 PM - INFO - Hash: a1e782a30d0ff87b3532aadbcdbd134a
# 04/16/2021 06:35:23 PM - INFO - ***train_networks(networks, dataset)***
#   0% 0/30 [00:00<?, ?it/s]04/16/2021 06:35:23 PM - INFO - Getting Keras datasets
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 04/16/2021 06:35:27 PM - INFO - Compling Keras model
# 04/16/2021 06:35:27 PM - INFO - Architecture:[128, 128, 32, 16, 32, 32],softplus,adagrad,5
# 2021-04-16 18:35:27.500465: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-16 18:35:27.501501: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-16 18:35:27.555815: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-16 18:35:27.556469: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-04-16 18:35:27.556508: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-16 18:35:27.613788: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-04-16 18:35:27.613868: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-04-16 18:35:27.792560: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-04-16 18:35:27.807842: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-04-16 18:35:28.092473: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-04-16 18:35:28.104800: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-04-16 18:35:28.108373: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-04-16 18:35:28.108542: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-16 18:35:28.109275: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-16 18:35:28.112524: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-04-16 18:35:28.113005: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-16 18:35:28.113116: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-16 18:35:28.113745: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-04-16 18:35:28.113776: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-16 18:35:28.113809: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-04-16 18:35:28.113829: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-04-16 18:35:28.113847: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-04-16 18:35:28.113866: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-04-16 18:35:28.113885: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-04-16 18:35:28.113904: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-04-16 18:35:28.113922: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-04-16 18:35:28.113985: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-16 18:35:28.114576: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-16 18:35:28.115113: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-04-16 18:35:28.116696: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-16 18:35:32.511524: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-04-16 18:35:32.511576: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-04-16 18:35:32.511593: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-04-16 18:35:32.516187: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-16 18:35:32.516857: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-16 18:35:32.517446: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-16 18:35:32.518024: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-04-16 18:35:32.518079: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13994 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2021-04-16 18:35:33.169214: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-04-16 18:35:33.174433: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2199995000 Hz
# Epoch 1/4
# 2021-04-16 18:35:33.822768: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-04-16 18:35:36.348536: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-04-16 18:35:36.421925: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 391/391 [==============================] - 40s 19ms/step - loss: 2.8926 - accuracy: 0.1007 - val_loss: 2.3421 - val_accuracy: 0.1000
# Epoch 2/4
# 391/391 [==============================] - 7s 18ms/step - loss: 2.5568 - accuracy: 0.0966 - val_loss: 2.3198 - val_accuracy: 0.1000
# Epoch 3/4
# 391/391 [==============================] - 7s 18ms/step - loss: 2.4843 - accuracy: 0.0991 - val_loss: 2.3106 - val_accuracy: 0.1000
# Test loss: 2.310558557510376
# Test accuracy: 0.10000000149011612
#   3% 1/30 [01:05<31:26, 65.06s/it]04/16/2021 06:36:28 PM - INFO - Getting Keras datasets
# 04/16/2021 06:36:29 PM - INFO - Compling Keras model
# 04/16/2021 06:36:29 PM - INFO - Architecture:[128, 128, 16, 32, 32, 64],hard_sigmoid,rmsprop,4
# Epoch 1/4
# 391/391 [==============================] - 10s 23ms/step - loss: 2.3402 - accuracy: 0.0998 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 2/4
# 391/391 [==============================] - 9s 23ms/step - loss: 2.3031 - accuracy: 0.0937 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 3/4
# 391/391 [==============================] - 9s 23ms/step - loss: 2.3028 - accuracy: 0.0992 - val_loss: 2.3026 - val_accuracy: 0.1000
# Test loss: 2.3025970458984375
# Test accuracy: 0.10000000149011612
#   7% 2/30 [01:35<25:28, 54.58s/it]04/16/2021 06:36:58 PM - INFO - Getting Keras datasets
# 04/16/2021 06:36:59 PM - INFO - Compling Keras model
# 04/16/2021 06:36:59 PM - INFO - Architecture:[16, 32, 128, 128, 32, 128],sigmoid,adadelta,4
# Epoch 1/4
# 391/391 [==============================] - 4s 8ms/step - loss: 2.7383 - accuracy: 0.0991 - val_loss: 2.4394 - val_accuracy: 0.1000
# Epoch 2/4
# 391/391 [==============================] - 3s 7ms/step - loss: 2.6053 - accuracy: 0.0981 - val_loss: 2.3671 - val_accuracy: 0.1000
# Epoch 3/4
# 391/391 [==============================] - 3s 7ms/step - loss: 2.5361 - accuracy: 0.1008 - val_loss: 2.3310 - val_accuracy: 0.1000
# Epoch 4/4
# 391/391 [==============================] - 3s 7ms/step - loss: 2.5007 - accuracy: 0.1007 - val_loss: 2.3143 - val_accuracy: 0.1000
# Test loss: 2.3143277168273926
# Test accuracy: 0.10000000149011612
#  10% 3/30 [01:48<19:00, 42.26s/it]04/16/2021 06:37:11 PM - INFO - Getting Keras datasets
# 04/16/2021 06:37:12 PM - INFO - Compling Keras model
# 04/16/2021 06:37:12 PM - INFO - Architecture:[128, 64, 32, 16, 64, 64],sigmoid,adadelta,2
# Epoch 1/4
# 391/391 [==============================] - 6s 15ms/step - loss: 2.6645 - accuracy: 0.1004 - val_loss: 2.3603 - val_accuracy: 0.1000
# Epoch 2/4
# 391/391 [==============================] - 6s 14ms/step - loss: 2.4947 - accuracy: 0.1004 - val_loss: 2.3186 - val_accuracy: 0.1000
# Epoch 3/4
# 391/391 [==============================] - 6s 14ms/step - loss: 2.4212 - accuracy: 0.1001 - val_loss: 2.3086 - val_accuracy: 0.1000
# Test loss: 2.3085973262786865
# Test accuracy: 0.10000000149011612
#  13% 4/30 [02:08<15:20, 35.39s/it]04/16/2021 06:37:31 PM - INFO - Getting Keras datasets
# 04/16/2021 06:37:32 PM - INFO - Compling Keras model
# 04/16/2021 06:37:32 PM - INFO - Architecture:[16, 16, 16, 32, 32, 32],relu,adadelta,1
# Epoch 1/4
# 391/391 [==============================] - 2s 5ms/step - loss: 2.3515 - accuracy: 0.0985 - val_loss: 2.2966 - val_accuracy: 0.1090
# Epoch 2/4
# 391/391 [==============================] - 2s 5ms/step - loss: 2.3232 - accuracy: 0.1049 - val_loss: 2.2898 - val_accuracy: 0.1388
# Epoch 3/4
# 391/391 [==============================] - 2s 5ms/step - loss: 2.3141 - accuracy: 0.1068 - val_loss: 2.2858 - val_accuracy: 0.1534
# Test loss: 2.285827159881592
# Test accuracy: 0.1534000039100647
#  17% 5/30 [02:16<11:19, 27.19s/it]04/16/2021 06:37:39 PM - INFO - Getting Keras datasets
# 04/16/2021 06:37:40 PM - INFO - Compling Keras model
# 04/16/2021 06:37:40 PM - INFO - Architecture:[16, 128, 128, 16, 32, 64],hard_sigmoid,adamax,4
# Epoch 1/4
# 391/391 [==============================] - 5s 11ms/step - loss: 2.4196 - accuracy: 0.0962 - val_loss: 2.3032 - val_accuracy: 0.1000
# Epoch 2/4
# 391/391 [==============================] - 4s 10ms/step - loss: 2.3060 - accuracy: 0.1039 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 3/4
# 391/391 [==============================] - 4s 10ms/step - loss: 2.3042 - accuracy: 0.1005 - val_loss: 2.3026 - val_accuracy: 0.1000
# Test loss: 2.302625894546509
# Test accuracy: 0.10000000149011612
#  20% 6/30 [02:31<09:24, 23.53s/it]04/16/2021 06:37:54 PM - INFO - Getting Keras datasets
# 04/16/2021 06:37:55 PM - INFO - Compling Keras model
# 04/16/2021 06:37:55 PM - INFO - Architecture:[32, 32, 64, 64, 128, 32],hard_sigmoid,sgd,3
# Epoch 1/4
# 391/391 [==============================] - 4s 9ms/step - loss: 2.3851 - accuracy: 0.0991 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 2/4
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3043 - accuracy: 0.1022 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 3/4
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3034 - accuracy: 0.0994 - val_loss: 2.3027 - val_accuracy: 0.1000
# Test loss: 2.3026864528656006
# Test accuracy: 0.10000000149011612
#  23% 7/30 [02:43<07:46, 20.28s/it]04/16/2021 06:38:07 PM - INFO - Getting Keras datasets
# 04/16/2021 06:38:07 PM - INFO - Compling Keras model
# 04/16/2021 06:38:07 PM - INFO - Architecture:[16, 64, 64, 64, 128, 64],linear,adagrad,5
# Epoch 1/4
# 391/391 [==============================] - 4s 8ms/step - loss: 2.3391 - accuracy: 0.1157 - val_loss: 2.2359 - val_accuracy: 0.2006
# Epoch 2/4
# 391/391 [==============================] - 3s 7ms/step - loss: 2.2298 - accuracy: 0.1670 - val_loss: 2.1062 - val_accuracy: 0.2524
# Epoch 3/4
# 391/391 [==============================] - 3s 7ms/step - loss: 2.1263 - accuracy: 0.2082 - val_loss: 2.0299 - val_accuracy: 0.2801
# Epoch 4/4
# 391/391 [==============================] - 3s 7ms/step - loss: 2.0700 - accuracy: 0.2347 - val_loss: 1.9756 - val_accuracy: 0.2957
# Test loss: 1.9755736589431763
# Test accuracy: 0.2957000136375427
#  27% 8/30 [02:57<06:42, 18.29s/it]04/16/2021 06:38:20 PM - INFO - Getting Keras datasets
# 04/16/2021 06:38:21 PM - INFO - Compling Keras model
# 04/16/2021 06:38:21 PM - INFO - Architecture:[64, 128, 16, 128, 32, 64],relu,rmsprop,3
# Epoch 1/4
# 391/391 [==============================] - 5s 11ms/step - loss: 2.1373 - accuracy: 0.1979 - val_loss: 1.6116 - val_accuracy: 0.4315
# Epoch 2/4
# 391/391 [==============================] - 4s 10ms/step - loss: 1.6568 - accuracy: 0.3988 - val_loss: 1.3366 - val_accuracy: 0.5201
# Epoch 3/4
# 391/391 [==============================] - 4s 10ms/step - loss: 1.4826 - accuracy: 0.4650 - val_loss: 1.2813 - val_accuracy: 0.5312
# Epoch 4/4
# 391/391 [==============================] - 4s 10ms/step - loss: 1.3803 - accuracy: 0.5049 - val_loss: 1.2790 - val_accuracy: 0.5403
# Test loss: 1.2789994478225708
# Test accuracy: 0.5403000116348267
#  30% 9/30 [03:16<06:28, 18.49s/it]04/16/2021 06:38:39 PM - INFO - Getting Keras datasets
# 04/16/2021 06:38:40 PM - INFO - Compling Keras model
# 04/16/2021 06:38:40 PM - INFO - Architecture:[64, 128, 64, 128, 128, 64],sigmoid,adadelta,4
# Epoch 1/4
# 391/391 [==============================] - 6s 13ms/step - loss: 2.6491 - accuracy: 0.0961 - val_loss: 2.3914 - val_accuracy: 0.1000
# Epoch 2/4
# 391/391 [==============================] - 5s 12ms/step - loss: 2.5521 - accuracy: 0.1003 - val_loss: 2.3436 - val_accuracy: 0.1000
# Epoch 3/4
# 391/391 [==============================] - 5s 12ms/step - loss: 2.4992 - accuracy: 0.0984 - val_loss: 2.3212 - val_accuracy: 0.1000
# Test loss: 2.321216583251953
# Test accuracy: 0.10000000149011612
#  33% 10/30 [03:33<05:58, 17.94s/it]04/16/2021 06:38:56 PM - INFO - Getting Keras datasets
# 04/16/2021 06:38:57 PM - INFO - Compling Keras model
# 04/16/2021 06:38:57 PM - INFO - Architecture:[64, 16, 32, 16, 32, 16],softplus,nadam,2
# Epoch 1/4
# 391/391 [==============================] - 4s 10ms/step - loss: 2.3463 - accuracy: 0.1000 - val_loss: 2.3023 - val_accuracy: 0.0975
# Epoch 2/4
# 391/391 [==============================] - 3s 9ms/step - loss: 2.3028 - accuracy: 0.1017 - val_loss: 2.3024 - val_accuracy: 0.1446
# Epoch 3/4
# 391/391 [==============================] - 3s 9ms/step - loss: 2.3001 - accuracy: 0.1071 - val_loss: 2.1348 - val_accuracy: 0.2216
# Epoch 4/4
# 391/391 [==============================] - 3s 9ms/step - loss: 2.1568 - accuracy: 0.2041 - val_loss: 1.9837 - val_accuracy: 0.2972
# Test loss: 1.9837009906768799
# Test accuracy: 0.2971999943256378
#  37% 11/30 [03:49<05:33, 17.57s/it]04/16/2021 06:39:13 PM - INFO - Getting Keras datasets
# 04/16/2021 06:39:13 PM - INFO - Compling Keras model
# 04/16/2021 06:39:13 PM - INFO - Architecture:[64, 64, 32, 32, 32, 64],linear,adam,2
# Epoch 1/4
# 391/391 [==============================] - 4s 9ms/step - loss: 1.8325 - accuracy: 0.3464 - val_loss: 1.3917 - val_accuracy: 0.4983
# Epoch 2/4
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3457 - accuracy: 0.5316 - val_loss: 1.2523 - val_accuracy: 0.5691
# Epoch 3/4
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2434 - accuracy: 0.5672 - val_loss: 1.1189 - val_accuracy: 0.6208
# Epoch 4/4
# 391/391 [==============================] - 3s 8ms/step - loss: 1.1851 - accuracy: 0.5907 - val_loss: 1.1035 - val_accuracy: 0.6099
# Test loss: 1.1034936904907227
# Test accuracy: 0.6098999977111816
#  40% 12/30 [04:05<05:05, 16.99s/it]04/16/2021 06:39:28 PM - INFO - Getting Keras datasets
# 04/16/2021 06:39:29 PM - INFO - Compling Keras model
# 04/16/2021 06:39:29 PM - INFO - Architecture:[32, 32, 128, 128, 128, 32],tanh,adadelta,2
# Epoch 1/4
# 391/391 [==============================] - 3s 7ms/step - loss: 2.3909 - accuracy: 0.0974 - val_loss: 2.3110 - val_accuracy: 0.1193
# Epoch 2/4
# 391/391 [==============================] - 2s 6ms/step - loss: 2.3628 - accuracy: 0.1044 - val_loss: 2.3010 - val_accuracy: 0.1338
# Epoch 3/4
# 391/391 [==============================] - 2s 6ms/step - loss: 2.3453 - accuracy: 0.1064 - val_loss: 2.2931 - val_accuracy: 0.1431
# Test loss: 2.293132781982422
# Test accuracy: 0.14309999346733093
#  43% 13/30 [04:14<04:10, 14.76s/it]04/16/2021 06:39:38 PM - INFO - Getting Keras datasets
# 04/16/2021 06:39:38 PM - INFO - Compling Keras model
# 04/16/2021 06:39:38 PM - INFO - Architecture:[32, 16, 128, 32, 16, 64],linear,adagrad,3
# Epoch 1/4
# 391/391 [==============================] - 3s 7ms/step - loss: 2.3343 - accuracy: 0.1156 - val_loss: 2.2387 - val_accuracy: 0.1815
# Epoch 2/4
# 391/391 [==============================] - 2s 6ms/step - loss: 2.2271 - accuracy: 0.1804 - val_loss: 2.1186 - val_accuracy: 0.2362
# Epoch 3/4
# 391/391 [==============================] - 2s 6ms/step - loss: 2.1016 - accuracy: 0.2382 - val_loss: 2.0193 - val_accuracy: 0.2713
# Epoch 4/4
# 391/391 [==============================] - 2s 6ms/step - loss: 2.0133 - accuracy: 0.2726 - val_loss: 1.9687 - val_accuracy: 0.3008
# Test loss: 1.968726396560669
# Test accuracy: 0.30079999566078186
#  47% 14/30 [04:26<03:42, 13.92s/it]04/16/2021 06:39:50 PM - INFO - Getting Keras datasets
# 04/16/2021 06:39:50 PM - INFO - Compling Keras model
# 04/16/2021 06:39:50 PM - INFO - Architecture:[16, 16, 128, 16, 16, 128],sigmoid,adagrad,4
# Epoch 1/4
# 391/391 [==============================] - 3s 7ms/step - loss: 2.5547 - accuracy: 0.1010 - val_loss: 2.3032 - val_accuracy: 0.1000
# Epoch 2/4
# 391/391 [==============================] - 3s 7ms/step - loss: 2.4861 - accuracy: 0.0986 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 3/4
# 391/391 [==============================] - 3s 6ms/step - loss: 2.4578 - accuracy: 0.1005 - val_loss: 2.3027 - val_accuracy: 0.1000
# Test loss: 2.3027255535125732
# Test accuracy: 0.10000000149011612
#  50% 15/30 [04:37<03:12, 12.81s/it]04/16/2021 06:40:00 PM - INFO - Getting Keras datasets
# 04/16/2021 06:40:01 PM - INFO - Compling Keras model
# 04/16/2021 06:40:01 PM - INFO - Architecture:[64, 32, 16, 16, 128, 16],linear,adagrad,2
# Epoch 1/4
# 391/391 [==============================] - 4s 8ms/step - loss: 2.3220 - accuracy: 0.1128 - val_loss: 2.2445 - val_accuracy: 0.1888
# Epoch 2/4
# 391/391 [==============================] - 3s 7ms/step - loss: 2.2428 - accuracy: 0.1636 - val_loss: 2.1686 - val_accuracy: 0.2443
# Epoch 3/4
# 391/391 [==============================] - 3s 7ms/step - loss: 2.1778 - accuracy: 0.1950 - val_loss: 2.0999 - val_accuracy: 0.2604
# Epoch 4/4
# 391/391 [==============================] - 3s 7ms/step - loss: 2.1373 - accuracy: 0.2104 - val_loss: 2.0545 - val_accuracy: 0.2907
# Test loss: 2.054462432861328
# Test accuracy: 0.2906999886035919
#  53% 16/30 [04:51<03:04, 13.19s/it]04/16/2021 06:40:14 PM - INFO - Getting Keras datasets
# 04/16/2021 06:40:15 PM - INFO - Compling Keras model
# 04/16/2021 06:40:15 PM - INFO - Architecture:[128, 64, 128, 64, 32, 32],elu,sgd,5
# Epoch 1/4
# 391/391 [==============================] - 7s 17ms/step - loss: 2.2886 - accuracy: 0.1300 - val_loss: 2.0900 - val_accuracy: 0.2177
# Epoch 2/4
# 391/391 [==============================] - 6s 16ms/step - loss: 2.0930 - accuracy: 0.2175 - val_loss: 1.8987 - val_accuracy: 0.3208
# Epoch 3/4
# 391/391 [==============================] - 6s 16ms/step - loss: 1.9777 - accuracy: 0.2607 - val_loss: 1.8543 - val_accuracy: 0.3394
# Epoch 4/4
# 391/391 [==============================] - 6s 16ms/step - loss: 1.8927 - accuracy: 0.2920 - val_loss: 1.7096 - val_accuracy: 0.4021
# Test loss: 1.709604263305664
# Test accuracy: 0.40209999680519104
#  57% 17/30 [05:19<03:49, 17.67s/it]04/16/2021 06:40:42 PM - INFO - Getting Keras datasets
# 04/16/2021 06:40:43 PM - INFO - Compling Keras model
# 04/16/2021 06:40:43 PM - INFO - Architecture:[128, 16, 32, 32, 128, 32],hard_sigmoid,nadam,5
# Epoch 1/4
# 391/391 [==============================] - 10s 21ms/step - loss: 2.3352 - accuracy: 0.1007 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 2/4
# 391/391 [==============================] - 8s 20ms/step - loss: 2.3031 - accuracy: 0.1017 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 3/4
# 391/391 [==============================] - 8s 20ms/step - loss: 2.3027 - accuracy: 0.0992 - val_loss: 2.3026 - val_accuracy: 0.1000
# Test loss: 2.30259370803833
# Test accuracy: 0.10000000149011612
#  60% 18/30 [05:47<04:08, 20.68s/it]04/16/2021 06:41:10 PM - INFO - Getting Keras datasets
# 04/16/2021 06:41:11 PM - INFO - Compling Keras model
# 04/16/2021 06:41:11 PM - INFO - Architecture:[64, 128, 128, 16, 16, 128],tanh,nadam,1
# Epoch 1/4
# 391/391 [==============================] - 4s 10ms/step - loss: 1.8643 - accuracy: 0.3645 - val_loss: 1.4197 - val_accuracy: 0.5085
# Epoch 2/4
# 391/391 [==============================] - 4s 9ms/step - loss: 1.4176 - accuracy: 0.5099 - val_loss: 1.3018 - val_accuracy: 0.5472
# Epoch 3/4
# 391/391 [==============================] - 4s 9ms/step - loss: 1.2981 - accuracy: 0.5495 - val_loss: 1.2511 - val_accuracy: 0.5608
# Epoch 4/4
# 391/391 [==============================] - 4s 9ms/step - loss: 1.2248 - accuracy: 0.5759 - val_loss: 1.1747 - val_accuracy: 0.5944
# Test loss: 1.1747146844863892
# Test accuracy: 0.5943999886512756
#  63% 19/30 [06:04<03:36, 19.66s/it]04/16/2021 06:41:27 PM - INFO - Getting Keras datasets
# 04/16/2021 06:41:28 PM - INFO - Compling Keras model
# 04/16/2021 06:41:28 PM - INFO - Architecture:[32, 32, 128, 16, 32, 64],sigmoid,adamax,4
# Epoch 1/4
# 391/391 [==============================] - 4s 8ms/step - loss: 2.4050 - accuracy: 0.1031 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 2/4
# 391/391 [==============================] - 3s 7ms/step - loss: 2.3085 - accuracy: 0.0992 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 3/4
# 391/391 [==============================] - 3s 7ms/step - loss: 2.3047 - accuracy: 0.0977 - val_loss: 2.3026 - val_accuracy: 0.1000
# Test loss: 2.3026037216186523
# Test accuracy: 0.10000000149011612
#  67% 20/30 [06:15<02:50, 17.04s/it]04/16/2021 06:41:38 PM - INFO - Getting Keras datasets
# 04/16/2021 06:41:39 PM - INFO - Compling Keras model
# 04/16/2021 06:41:39 PM - INFO - Architecture:[16, 16, 32, 32, 32, 128],tanh,nadam,3
# Epoch 1/4
# 391/391 [==============================] - 4s 7ms/step - loss: 1.8947 - accuracy: 0.3071 - val_loss: 1.5579 - val_accuracy: 0.4279
# Epoch 2/4
# 391/391 [==============================] - 3s 7ms/step - loss: 1.5101 - accuracy: 0.4574 - val_loss: 1.4275 - val_accuracy: 0.4944
# Epoch 3/4
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4177 - accuracy: 0.4966 - val_loss: 1.3381 - val_accuracy: 0.5243
# Epoch 4/4
# 391/391 [==============================] - 3s 7ms/step - loss: 1.3634 - accuracy: 0.5233 - val_loss: 1.2703 - val_accuracy: 0.5436
# Test loss: 1.2703146934509277
# Test accuracy: 0.5436000227928162
#  70% 21/30 [06:28<02:23, 15.90s/it]04/16/2021 06:41:51 PM - INFO - Getting Keras datasets
# 04/16/2021 06:41:52 PM - INFO - Compling Keras model
# 04/16/2021 06:41:52 PM - INFO - Architecture:[128, 16, 128, 16, 64, 64],relu,rmsprop,1
# Epoch 1/4
# 391/391 [==============================] - 5s 12ms/step - loss: 2.1665 - accuracy: 0.2054 - val_loss: 1.5731 - val_accuracy: 0.4709
# Epoch 2/4
# 391/391 [==============================] - 5s 12ms/step - loss: 1.7280 - accuracy: 0.3611 - val_loss: 1.5588 - val_accuracy: 0.3979
# Epoch 3/4
# 391/391 [==============================] - 5s 12ms/step - loss: 1.6016 - accuracy: 0.4078 - val_loss: 1.3218 - val_accuracy: 0.5427
# Epoch 4/4
# 391/391 [==============================] - 5s 12ms/step - loss: 1.5207 - accuracy: 0.4367 - val_loss: 1.2678 - val_accuracy: 0.5585
# Test loss: 1.2678077220916748
# Test accuracy: 0.5584999918937683
#  73% 22/30 [06:49<02:20, 17.50s/it]04/16/2021 06:42:13 PM - INFO - Getting Keras datasets
# 04/16/2021 06:42:13 PM - INFO - Compling Keras model
# 04/16/2021 06:42:13 PM - INFO - Architecture:[64, 64, 128, 64, 32, 16],softplus,adagrad,4
# Epoch 1/4
# 391/391 [==============================] - 5s 12ms/step - loss: 2.4131 - accuracy: 0.0982 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 2/4
# 391/391 [==============================] - 4s 11ms/step - loss: 2.3046 - accuracy: 0.1001 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 3/4
# 391/391 [==============================] - 4s 11ms/step - loss: 2.3041 - accuracy: 0.0995 - val_loss: 2.3026 - val_accuracy: 0.0999
# Test loss: 2.3025684356689453
# Test accuracy: 0.09989999979734421
#  77% 23/30 [07:05<01:59, 17.08s/it]04/16/2021 06:42:29 PM - INFO - Getting Keras datasets
# 04/16/2021 06:42:29 PM - INFO - Compling Keras model
# 04/16/2021 06:42:29 PM - INFO - Architecture:[128, 16, 16, 128, 16, 128],relu,adagrad,3
# Epoch 1/4
# 391/391 [==============================] - 5s 13ms/step - loss: 2.3075 - accuracy: 0.0991 - val_loss: 2.3027 - val_accuracy: 0.1001
# Epoch 2/4
# 391/391 [==============================] - 5s 12ms/step - loss: 2.3031 - accuracy: 0.1033 - val_loss: 2.3024 - val_accuracy: 0.1061
# Epoch 3/4
# 391/391 [==============================] - 5s 12ms/step - loss: 2.3017 - accuracy: 0.1091 - val_loss: 2.3012 - val_accuracy: 0.1386
# Test loss: 2.3012280464172363
# Test accuracy: 0.13860000669956207
#  80% 24/30 [07:22<01:41, 16.92s/it]04/16/2021 06:42:45 PM - INFO - Getting Keras datasets
# 04/16/2021 06:42:46 PM - INFO - Compling Keras model
# 04/16/2021 06:42:46 PM - INFO - Architecture:[128, 64, 64, 16, 32, 128],sigmoid,adamax,5
# Epoch 1/4
# 391/391 [==============================] - 7s 17ms/step - loss: 2.4996 - accuracy: 0.0987 - val_loss: 2.3029 - val_accuracy: 0.1000
# Epoch 2/4
# 391/391 [==============================] - 6s 16ms/step - loss: 2.3455 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.1000
# Epoch 3/4
# 391/391 [==============================] - 6s 16ms/step - loss: 2.3190 - accuracy: 0.0988 - val_loss: 2.3029 - val_accuracy: 0.1000
# Test loss: 2.3029141426086426
# Test accuracy: 0.10000000149011612
#  83% 25/30 [07:43<01:31, 18.27s/it]04/16/2021 06:43:07 PM - INFO - Getting Keras datasets
# 04/16/2021 06:43:07 PM - INFO - Compling Keras model
# 04/16/2021 06:43:07 PM - INFO - Architecture:[32, 64, 16, 16, 64, 32],linear,sgd,3
# Epoch 1/4
# 391/391 [==============================] - 3s 7ms/step - loss: 2.2820 - accuracy: 0.1470 - val_loss: 2.0481 - val_accuracy: 0.2705
# Epoch 2/4
# 391/391 [==============================] - 3s 7ms/step - loss: 2.0885 - accuracy: 0.2292 - val_loss: 1.9430 - val_accuracy: 0.3291
# Epoch 3/4
# 391/391 [==============================] - 3s 7ms/step - loss: 1.9843 - accuracy: 0.2754 - val_loss: 1.8052 - val_accuracy: 0.3845
# Epoch 4/4
# 391/391 [==============================] - 3s 7ms/step - loss: 1.8967 - accuracy: 0.3106 - val_loss: 1.7219 - val_accuracy: 0.3962
# Test loss: 1.7218583822250366
# Test accuracy: 0.3962000012397766
#  87% 26/30 [07:56<01:06, 16.68s/it]04/16/2021 06:43:20 PM - INFO - Getting Keras datasets
# 04/16/2021 06:43:20 PM - INFO - Compling Keras model
# 04/16/2021 06:43:20 PM - INFO - Architecture:[128, 16, 16, 128, 16, 16],hard_sigmoid,rmsprop,1
# Epoch 1/4
# 391/391 [==============================] - 8s 18ms/step - loss: 2.4138 - accuracy: 0.1002 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 2/4
# 391/391 [==============================] - 7s 18ms/step - loss: 2.3135 - accuracy: 0.0970 - val_loss: 2.3029 - val_accuracy: 0.1000
# Epoch 3/4
# 391/391 [==============================] - 7s 18ms/step - loss: 2.3052 - accuracy: 0.1010 - val_loss: 2.3028 - val_accuracy: 0.1000
# Test loss: 2.3028080463409424
# Test accuracy: 0.10000000149011612
#  90% 27/30 [08:20<00:56, 18.68s/it]04/16/2021 06:43:43 PM - INFO - Getting Keras datasets
# 04/16/2021 06:43:44 PM - INFO - Compling Keras model
# 04/16/2021 06:43:44 PM - INFO - Architecture:[64, 16, 16, 16, 16, 128],elu,nadam,1
# Epoch 1/4
# 391/391 [==============================] - 4s 10ms/step - loss: 1.8741 - accuracy: 0.3644 - val_loss: 1.4238 - val_accuracy: 0.4985
# Epoch 2/4
# 391/391 [==============================] - 4s 9ms/step - loss: 1.4118 - accuracy: 0.5080 - val_loss: 1.3732 - val_accuracy: 0.5136
# Epoch 3/4
# 391/391 [==============================] - 4s 9ms/step - loss: 1.2901 - accuracy: 0.5516 - val_loss: 1.2399 - val_accuracy: 0.5650
# Epoch 4/4
# 391/391 [==============================] - 4s 9ms/step - loss: 1.2125 - accuracy: 0.5785 - val_loss: 1.1926 - val_accuracy: 0.5823
# Test loss: 1.1926161050796509
# Test accuracy: 0.5823000073432922
#  93% 28/30 [08:38<00:37, 18.52s/it]04/16/2021 06:44:01 PM - INFO - Getting Keras datasets
# 04/16/2021 06:44:02 PM - INFO - Compling Keras model
# 04/16/2021 06:44:02 PM - INFO - Architecture:[128, 32, 128, 128, 32, 32],linear,adamax,4
# Epoch 1/4
# 391/391 [==============================] - 6s 14ms/step - loss: 2.0159 - accuracy: 0.2645 - val_loss: 1.5240 - val_accuracy: 0.4786
# Epoch 2/4
# 391/391 [==============================] - 5s 13ms/step - loss: 1.6250 - accuracy: 0.4242 - val_loss: 1.3365 - val_accuracy: 0.5347
# Epoch 3/4
# 391/391 [==============================] - 5s 13ms/step - loss: 1.4866 - accuracy: 0.4798 - val_loss: 1.3484 - val_accuracy: 0.5106
# Epoch 4/4
# 391/391 [==============================] - 5s 13ms/step - loss: 1.4186 - accuracy: 0.5038 - val_loss: 1.1875 - val_accuracy: 0.5985
# Test loss: 1.187476634979248
# Test accuracy: 0.5985000133514404
#  97% 29/30 [09:02<00:20, 20.26s/it]04/16/2021 06:44:25 PM - INFO - Getting Keras datasets
# 04/16/2021 06:44:26 PM - INFO - Compling Keras model
# 04/16/2021 06:44:26 PM - INFO - Architecture:[64, 32, 16, 32, 64, 64],hard_sigmoid,adamax,1
# Epoch 1/4
# 391/391 [==============================] - 5s 11ms/step - loss: 2.4963 - accuracy: 0.1021 - val_loss: 2.3031 - val_accuracy: 0.1000
# Epoch 2/4
# 391/391 [==============================] - 4s 10ms/step - loss: 2.3708 - accuracy: 0.0985 - val_loss: 2.3029 - val_accuracy: 0.1000
# Epoch 3/4
# 391/391 [==============================] - 4s 10ms/step - loss: 2.3371 - accuracy: 0.0971 - val_loss: 2.3028 - val_accuracy: 0.1000
# Test loss: 2.3028366565704346
# Test accuracy: 0.10000000149011612
# 100% 30/30 [09:17<00:00, 18.57s/it]
# 04/16/2021 06:44:40 PM - INFO - Generation average: 26.15%
# 04/16/2021 06:44:40 PM - INFO - --------------------------------------------------------------------------------
# 04/16/2021 06:44:40 PM - INFO - ***Now in generation 2 of 8***
# 04/16/2021 06:44:40 PM - INFO - --------------------------------------------------------------------------------
# 04/16/2021 06:44:40 PM - INFO - {'nb_layers': 2, 'activation': 'linear', 'optimizer': 'adam', 'nb_neurons': [64, 64, 32, 32, 32, 64]}
# 04/16/2021 06:44:40 PM - INFO - Acc: 60.99%
# 04/16/2021 06:44:40 PM - INFO - UniID: 12
# 04/16/2021 06:44:40 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:44:40 PM - INFO - Gen: 1
# 04/16/2021 06:44:40 PM - INFO - Hash: 0f25f3e5e2ef5472784df5a4f36fbb84
# 04/16/2021 06:44:40 PM - INFO - {'nb_layers': 4, 'activation': 'linear', 'optimizer': 'adamax', 'nb_neurons': [128, 32, 128, 128, 32, 32]}
# 04/16/2021 06:44:40 PM - INFO - Acc: 59.85%
# 04/16/2021 06:44:40 PM - INFO - UniID: 29
# 04/16/2021 06:44:40 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:44:40 PM - INFO - Gen: 1
# 04/16/2021 06:44:40 PM - INFO - Hash: dd71fafdbfd2560ca3b4c0e2ebd8afc5
# 04/16/2021 06:44:40 PM - INFO - {'nb_layers': 1, 'activation': 'tanh', 'optimizer': 'nadam', 'nb_neurons': [64, 128, 128, 16, 16, 128]}
# 04/16/2021 06:44:40 PM - INFO - Acc: 59.44%
# 04/16/2021 06:44:40 PM - INFO - UniID: 19
# 04/16/2021 06:44:40 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:44:40 PM - INFO - Gen: 1
# 04/16/2021 06:44:40 PM - INFO - Hash: dd2f72ae9763c148ddcaef9a64e16fb5
# 04/16/2021 06:44:40 PM - INFO - {'nb_layers': 1, 'activation': 'elu', 'optimizer': 'nadam', 'nb_neurons': [64, 16, 16, 16, 16, 128]}
# 04/16/2021 06:44:40 PM - INFO - Acc: 58.23%
# 04/16/2021 06:44:40 PM - INFO - UniID: 28
# 04/16/2021 06:44:40 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:44:40 PM - INFO - Gen: 1
# 04/16/2021 06:44:40 PM - INFO - Hash: b482d28007fa6d20770decdd218886aa
# 04/16/2021 06:44:40 PM - INFO - {'nb_layers': 4, 'activation': 'hard_sigmoid', 'optimizer': 'adagrad', 'nb_neurons': [128, 128, 16, 32, 32, 64]}
# 04/16/2021 06:44:40 PM - INFO - Acc: 0.00%
# 04/16/2021 06:44:40 PM - INFO - UniID: 2
# 04/16/2021 06:44:40 PM - INFO - Mom and Dad: 0 0
# 04/16/2021 06:44:40 PM - INFO - Gen: 2
# 04/16/2021 06:44:40 PM - INFO - Hash: a896340f31613e385b6982b4e3bd7e55
# 04/16/2021 06:44:40 PM - INFO - {'activation': 'linear', 'nb_layers': 2, 'optimizer': 'adamax', 'nb_neurons': [128, 32, 128, 128, 32, 32]}
# 04/16/2021 06:44:40 PM - INFO - Acc: 0.00%
# 04/16/2021 06:44:40 PM - INFO - UniID: 31
# 04/16/2021 06:44:40 PM - INFO - Mom and Dad: 12 29
# 04/16/2021 06:44:40 PM - INFO - Gen: 2
# 04/16/2021 06:44:40 PM - INFO - Hash: 38a26d8ebdc39c87d04d23bd5c3c7d44
# 04/16/2021 06:44:40 PM - INFO - {'activation': 'linear', 'nb_layers': 4, 'optimizer': 'adam', 'nb_neurons': [64, 64, 32, 32, 32, 64]}
# 04/16/2021 06:44:40 PM - INFO - Acc: 0.00%
# 04/16/2021 06:44:40 PM - INFO - UniID: 32
# 04/16/2021 06:44:40 PM - INFO - Mom and Dad: 12 29
# 04/16/2021 06:44:40 PM - INFO - Gen: 2
# 04/16/2021 06:44:40 PM - INFO - Hash: b0bf113215393be99b04475dd67be136
# 04/16/2021 06:44:40 PM - INFO - {'activation': 'tanh', 'nb_layers': 1, 'optimizer': 'nadam', 'nb_neurons': [128, 128, 128, 16, 16, 128]}
# 04/16/2021 06:44:40 PM - INFO - Acc: 0.00%
# 04/16/2021 06:44:40 PM - INFO - UniID: 33
# 04/16/2021 06:44:40 PM - INFO - Mom and Dad: 19 28
# 04/16/2021 06:44:40 PM - INFO - Gen: 2
# 04/16/2021 06:44:40 PM - INFO - Hash: 35a3cbd7b12f91f2462b1a7c2a9544c6
# 04/16/2021 06:44:40 PM - INFO - {'activation': 'elu', 'nb_layers': 1, 'optimizer': 'adadelta', 'nb_neurons': [64, 16, 16, 16, 16, 128]}
# 04/16/2021 06:44:40 PM - INFO - Acc: 0.00%
# 04/16/2021 06:44:40 PM - INFO - UniID: 34
# 04/16/2021 06:44:40 PM - INFO - Mom and Dad: 19 28
# 04/16/2021 06:44:40 PM - INFO - Gen: 2
# 04/16/2021 06:44:40 PM - INFO - Hash: 2d98bd94c5620478963c01b1f337ecc5
# 04/16/2021 06:44:40 PM - INFO - {'activation': 'linear', 'nb_layers': 1, 'optimizer': 'nadam', 'nb_neurons': [64, 64, 16, 16, 16, 128]}
# 04/16/2021 06:44:40 PM - INFO - Acc: 0.00%
# 04/16/2021 06:44:40 PM - INFO - UniID: 35
# 04/16/2021 06:44:40 PM - INFO - Mom and Dad: 12 28
# 04/16/2021 06:44:40 PM - INFO - Gen: 2
# 04/16/2021 06:44:40 PM - INFO - Hash: 0561db26f7cea3e698ce04219b429bd1
# 04/16/2021 06:44:40 PM - INFO - {'activation': 'elu', 'nb_layers': 2, 'optimizer': 'adam', 'nb_neurons': [64, 64, 32, 32, 32, 64]}
# 04/16/2021 06:44:40 PM - INFO - Acc: 0.00%
# 04/16/2021 06:44:40 PM - INFO - UniID: 36
# 04/16/2021 06:44:40 PM - INFO - Mom and Dad: 12 28
# 04/16/2021 06:44:40 PM - INFO - Gen: 2
# 04/16/2021 06:44:40 PM - INFO - Hash: 12f6278869e0dc9a5a1bc12031a8855c
# 04/16/2021 06:44:40 PM - INFO - {'activation': 'elu', 'nb_layers': 1, 'optimizer': 'adamax', 'nb_neurons': [64, 128, 16, 16, 32, 32]}
# 04/16/2021 06:44:40 PM - INFO - Acc: 0.00%
# 04/16/2021 06:44:40 PM - INFO - UniID: 37
# 04/16/2021 06:44:40 PM - INFO - Mom and Dad: 28 29
# 04/16/2021 06:44:40 PM - INFO - Gen: 2
# 04/16/2021 06:44:40 PM - INFO - Hash: 5bd4c7332025b7632c4d33d20bad3ffe
# ...
# 04/16/2021 07:00:25 PM - INFO - Acc: 0.00%
# 04/16/2021 07:00:25 PM - INFO - UniID: 80
# 04/16/2021 07:00:25 PM - INFO - Mom and Dad: 40 36
# 04/16/2021 07:00:25 PM - INFO - Gen: 4
# 04/16/2021 07:00:25 PM - INFO - Hash: 1cc6afa3ff9d131c2965d9a95ad0fca2
# 04/16/2021 07:00:25 PM - INFO - {'activation': 'linear', 'nb_layers': 2, 'optimizer': 'adam', 'nb_neurons': [128, 64, 32, 32, 32, 64]}
# 04/16/2021 07:00:25 PM - INFO - Acc: 0.00%
# 04/16/2021 07:00:25 PM - INFO - UniID: 81
# 04/16/2021 07:00:25 PM - INFO - Mom and Dad: 40 71
# 04/16/2021 07:00:25 PM - INFO - Gen: 4
# 04/16/2021 07:00:25 PM - INFO - Hash: c8469353825605d939cc62f12c63ada5
# 04/16/2021 07:00:25 PM - INFO - {'activation': 'elu', 'nb_layers': 4, 'optimizer': 'nadam', 'nb_neurons': [64, 16, 32, 32, 16, 32]}
# 04/16/2021 07:00:25 PM - INFO - Acc: 0.00%
# 04/16/2021 07:00:25 PM - INFO - UniID: 82
# 04/16/2021 07:00:25 PM - INFO - Mom and Dad: 40 71
# 04/16/2021 07:00:25 PM - INFO - Gen: 4
# 04/16/2021 07:00:25 PM - INFO - Hash: 6891dedee1c7e8462c2463f9fca2722d
# 04/16/2021 07:00:25 PM - INFO - {'activation': 'elu', 'nb_layers': 2, 'optimizer': 'nadam', 'nb_neurons': [64, 64, 32, 32, 16, 128]}
# 04/16/2021 07:00:25 PM - INFO - Acc: 0.00%
# 04/16/2021 07:00:25 PM - INFO - UniID: 83
# 04/16/2021 07:00:25 PM - INFO - Mom and Dad: 58 69
# 04/16/2021 07:00:25 PM - INFO - Gen: 4
# 04/16/2021 07:00:25 PM - INFO - Hash: 6d05e6bb31389dffdbbf857b99428aba
# 04/16/2021 07:00:25 PM - INFO - {'activation': 'linear', 'nb_layers': 2, 'optimizer': 'rmsprop', 'nb_neurons': [128, 64, 16, 128, 32, 128]}
# 04/16/2021 07:00:25 PM - INFO - Acc: 0.00%
# 04/16/2021 07:00:25 PM - INFO - UniID: 84
# 04/16/2021 07:00:25 PM - INFO - Mom and Dad: 58 69
# 04/16/2021 07:00:25 PM - INFO - Gen: 4
# 04/16/2021 07:00:25 PM - INFO - Hash: c43cdce2c07fcf09c961a4737ee303f5
# 04/16/2021 07:00:25 PM - INFO - {'activation': 'linear', 'nb_layers': 2, 'optimizer': 'nadam', 'nb_neurons': [128, 16, 16, 16, 32, 128]}
# 04/16/2021 07:00:25 PM - INFO - Acc: 0.00%
# 04/16/2021 07:00:25 PM - INFO - UniID: 85
# 04/16/2021 07:00:25 PM - INFO - Mom and Dad: 69 41
# 04/16/2021 07:00:25 PM - INFO - Gen: 4
# 04/16/2021 07:00:25 PM - INFO - Hash: ba6b002bd710b667e2d527194e281de1
# 04/16/2021 07:00:25 PM - INFO - {'activation': 'elu', 'nb_layers': 1, 'optimizer': 'nadam', 'nb_neurons': [64, 32, 16, 128, 16, 128]}
# 04/16/2021 07:00:25 PM - INFO - Acc: 0.00%
# 04/16/2021 07:00:25 PM - INFO - UniID: 86
# 04/16/2021 07:00:25 PM - INFO - Mom and Dad: 69 41
# 04/16/2021 07:00:25 PM - INFO - Gen: 4
# 04/16/2021 07:00:25 PM - INFO - Hash: e0b2e06a2e860b5996dbbad852a6806d
# 04/16/2021 07:00:25 PM - INFO - {'activation': 'elu', 'nb_layers': 1, 'optimizer': 'adagrad', 'nb_neurons': [64, 64, 128, 32, 32, 64]}
# 04/16/2021 07:00:25 PM - INFO - Acc: 0.00%
# 04/16/2021 07:00:25 PM - INFO - UniID: 87
# 04/16/2021 07:00:25 PM - INFO - Mom and Dad: 41 62
# 04/16/2021 07:00:25 PM - INFO - Gen: 4
# 04/16/2021 07:00:25 PM - INFO - Hash: 64e4a9d06ace42b0cb16c333af1bff2e
# 04/16/2021 07:00:25 PM - INFO - {'activation': 'elu', 'nb_layers': 1, 'optimizer': 'nadam', 'nb_neurons': [64, 16, 32, 16, 32, 128]}
# 04/16/2021 07:00:25 PM - INFO - Acc: 0.00%
# 04/16/2021 07:00:25 PM - INFO - UniID: 88
# 04/16/2021 07:00:25 PM - INFO - Mom and Dad: 41 62
# 04/16/2021 07:00:25 PM - INFO - Gen: 4
# 04/16/2021 07:00:25 PM - INFO - Hash: b9714a7797cf4c53b7fbc58058d05903
# 04/16/2021 07:00:25 PM - INFO - {'activation': 'elu', 'nb_layers': 1, 'optimizer': 'nadam', 'nb_neurons': [64, 64, 128, 32, 32, 128]}
# 04/16/2021 07:00:25 PM - INFO - Acc: 0.00%
# 04/16/2021 07:00:25 PM - INFO - UniID: 89
# 04/16/2021 07:00:25 PM - INFO - Mom and Dad: 62 41
# 04/16/2021 07:00:25 PM - INFO - Gen: 4
# 04/16/2021 07:00:25 PM - INFO - Hash: c9262cfeb4762cc2d3d66c6f00e1468c
# 04/16/2021 07:00:25 PM - INFO - {'activation': 'elu', 'nb_layers': 1, 'optimizer': 'adam', 'nb_neurons': [64, 16, 16, 32, 32, 64]}
# 04/16/2021 07:00:25 PM - INFO - Acc: 0.00%
# 04/16/2021 07:00:25 PM - INFO - UniID: 90
# 04/16/2021 07:00:25 PM - INFO - Mom and Dad: 62 41
# 04/16/2021 07:00:25 PM - INFO - Gen: 4
# 04/16/2021 07:00:25 PM - INFO - Hash: ce4bfaabfacb75611b928c2c5e2f52fd
# 04/16/2021 07:00:25 PM - INFO - {'activation': 'linear', 'nb_layers': 2, 'optimizer': 'adam', 'nb_neurons': [64, 64, 128, 32, 32, 128]}
# 04/16/2021 07:00:25 PM - INFO - Acc: 0.00%
# 04/16/2021 07:00:25 PM - INFO - UniID: 91
# 04/16/2021 07:00:25 PM - INFO - Mom and Dad: 40 62
# 04/16/2021 07:00:25 PM - INFO - Gen: 4
# 04/16/2021 07:00:25 PM - INFO - Hash: 92a037460301fe1b007ee9a41b1cce6a
# 04/16/2021 07:00:25 PM - INFO - {'activation': 'elu', 'nb_layers': 1, 'optimizer': 'nadam', 'nb_neurons': [64, 16, 32, 32, 16, 32]}
# 04/16/2021 07:00:25 PM - INFO - Acc: 0.00%
# 04/16/2021 07:00:25 PM - INFO - UniID: 92
# 04/16/2021 07:00:25 PM - INFO - Mom and Dad: 40 62
# 04/16/2021 07:00:25 PM - INFO - Gen: 4
# 04/16/2021 07:00:25 PM - INFO - Hash: 9970843ec97a7f4dba4eec02ebac1762
# 04/16/2021 07:00:25 PM - INFO - {'activation': 'relu', 'nb_layers': 2, 'optimizer': 'nadam', 'nb_neurons': [64, 64, 32, 32, 16, 32]}
# 04/16/2021 07:00:25 PM - INFO - Acc: 0.00%
# 04/16/2021 07:00:25 PM - INFO - UniID: 93
# 04/16/2021 07:00:25 PM - INFO - Mom and Dad: 58 40
# 04/16/2021 07:00:25 PM - INFO - Gen: 4
# 04/16/2021 07:00:25 PM - INFO - Hash: dfa8dde5a5b2cb46041767878a0ab403
# 04/16/2021 07:00:25 PM - INFO - {'activation': 'linear', 'nb_layers': 2, 'optimizer': 'rmsprop', 'nb_neurons': [64, 16, 32, 32, 32, 128]}
# 04/16/2021 07:00:25 PM - INFO - Acc: 0.00%
# 04/16/2021 07:00:25 PM - INFO - UniID: 94
# 04/16/2021 07:00:25 PM - INFO - Mom and Dad: 58 40
# 04/16/2021 07:00:25 PM - INFO - Gen: 4
# 04/16/2021 07:00:25 PM - INFO - Hash: f9dd886ee31fa0a57310a7961f3345da
# 04/16/2021 07:00:25 PM - INFO - {'activation': 'linear', 'nb_layers': 4, 'optimizer': 'adam', 'nb_neurons': [128, 128, 32, 32, 32, 64]}
# 04/16/2021 07:00:25 PM - INFO - Acc: 0.00%
# 04/16/2021 07:00:25 PM - INFO - UniID: 95
# 04/16/2021 07:00:25 PM - INFO - Mom and Dad: 69 71
# 04/16/2021 07:00:25 PM - INFO - Gen: 4
# 04/16/2021 07:00:25 PM - INFO - Hash: 94577745c7e84bda07d6406f05c74c20
# 04/16/2021 07:00:25 PM - INFO - {'activation': 'elu', 'nb_layers': 2, 'optimizer': 'nadam', 'nb_neurons': [128, 32, 16, 128, 128, 128]}
# 04/16/2021 07:00:25 PM - INFO - Acc: 0.00%
# 04/16/2021 07:00:25 PM - INFO - UniID: 96
# 04/16/2021 07:00:25 PM - INFO - Mom and Dad: 69 71
# 04/16/2021 07:00:25 PM - INFO - Gen: 4
# 04/16/2021 07:00:25 PM - INFO - Hash: e38cb98992b2cb774e144fb2004854ba
# 04/16/2021 07:00:25 PM - INFO - {'activation': 'elu', 'nb_layers': 2, 'optimizer': 'nadam', 'nb_neurons': [64, 16, 16, 16, 32, 128]}
# 04/16/2021 07:00:25 PM - INFO - Acc: 0.00%
# 04/16/2021 07:00:25 PM - INFO - UniID: 97
# 04/16/2021 07:00:25 PM - INFO - Mom and Dad: 36 41
# 04/16/2021 07:00:25 PM - INFO - Gen: 4
# 04/16/2021 07:00:25 PM - INFO - Hash: 9fef47505a485ade8425a2965b6bbb7e
# 04/16/2021 07:00:25 PM - INFO - {'activation': 'elu', 'nb_layers': 1, 'optimizer': 'adam', 'nb_neurons': [64, 64, 32, 128, 32, 64]}
# 04/16/2021 07:00:25 PM - INFO - Acc: 0.00%
# 04/16/2021 07:00:25 PM - INFO - UniID: 98
# 04/16/2021 07:00:25 PM - INFO - Mom and Dad: 36 41
# 04/16/2021 07:00:25 PM - INFO - Gen: 4
# 04/16/2021 07:00:25 PM - INFO - Hash: 6026cfa389ad50a0d3bdbfbf5f828145
# 04/16/2021 07:00:25 PM - INFO - {'activation': 'elu', 'nb_layers': 2, 'optimizer': 'adam', 'nb_neurons': [64, 64, 16, 32, 32, 64]}
# 04/16/2021 07:00:25 PM - INFO - Acc: 0.00%
# 04/16/2021 07:00:25 PM - INFO - UniID: 99
# 04/16/2021 07:00:25 PM - INFO - Mom and Dad: 62 71
# 04/16/2021 07:00:25 PM - INFO - Gen: 4
# 04/16/2021 07:00:25 PM - INFO - Hash: c73896ec46b39c44cbb155cb8bd4d758
# 04/16/2021 07:00:25 PM - INFO - {'activation': 'elu', 'nb_layers': 4, 'optimizer': 'adam', 'nb_neurons': [128, 64, 128, 32, 32, 64]}
# 04/16/2021 07:00:25 PM - INFO - Acc: 0.00%
# 04/16/2021 07:00:25 PM - INFO - UniID: 100
# 04/16/2021 07:00:25 PM - INFO - Mom and Dad: 62 71
# 04/16/2021 07:00:25 PM - INFO - Gen: 4
# 04/16/2021 07:00:25 PM - INFO - Hash: 2bf806034511bcf3a43426f800d3a5c8
# 04/16/2021 07:00:25 PM - INFO - {'activation': 'elu', 'nb_layers': 5, 'optimizer': 'nadam', 'nb_neurons': [64, 64, 32, 16, 32, 128]}
# 04/16/2021 07:00:25 PM - INFO - Acc: 0.00%
# 04/16/2021 07:00:25 PM - INFO - UniID: 101
# 04/16/2021 07:00:25 PM - INFO - Mom and Dad: 58 41
# 04/16/2021 07:00:25 PM - INFO - Gen: 4
# 04/16/2021 07:00:25 PM - INFO - Hash: e37ab58969acc3b05d25b309a3cb40b7
# 04/16/2021 07:00:25 PM - INFO - {'activation': 'elu', 'nb_layers': 1, 'optimizer': 'rmsprop', 'nb_neurons': [64, 16, 16, 32, 32, 128]}
# 04/16/2021 07:00:25 PM - INFO - Acc: 0.00%
# 04/16/2021 07:00:25 PM - INFO - UniID: 102
# 04/16/2021 07:00:25 PM - INFO - Mom and Dad: 58 41
# 04/16/2021 07:00:25 PM - INFO - Gen: 4
# 04/16/2021 07:00:25 PM - INFO - Hash: 2ad0247ec191fb2a31113fc35248511e
# 04/16/2021 07:00:25 PM - INFO - ***train_networks(networks, dataset)***
#   0% 0/32 [00:00<?, ?it/s]04/16/2021 07:00:25 PM - INFO - Getting Keras datasets
# 04/16/2021 07:00:26 PM - INFO - Compling Keras model
# 04/16/2021 07:00:26 PM - INFO - Architecture:[64, 16, 32, 32, 16, 32],linear,nadam,2
# Epoch 1/4
# 391/391 [==============================] - 4s 9ms/step - loss: 2.0086 - accuracy: 0.2638 - val_loss: 1.5028 - val_accuracy: 0.4737
# Epoch 2/4
# 391/391 [==============================] - 3s 8ms/step - loss: 1.6102 - accuracy: 0.4334 - val_loss: 1.3751 - val_accuracy: 0.5114
# Epoch 3/4
# 391/391 [==============================] - 3s 8ms/step - loss: 1.4701 - accuracy: 0.4841 - val_loss: 1.2719 - val_accuracy: 0.5623
# Epoch 4/4
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3893 - accuracy: 0.5148 - val_loss: 1.2129 - val_accuracy: 0.5825
# Test loss: 1.2129459381103516
# Test accuracy: 0.5824999809265137
#  16% 5/32 [00:15<01:22,  3.05s/it]04/16/2021 07:00:40 PM - INFO - Getting Keras datasets
# 04/16/2021 07:00:41 PM - INFO - Compling Keras model
# 04/16/2021 07:00:41 PM - INFO - Architecture:[64, 64, 128, 32, 32, 64],elu,adam,1
# Epoch 1/4
# 391/391 [==============================] - 4s 9ms/step - loss: 1.9134 - accuracy: 0.3413 - val_loss: 1.4327 - val_accuracy: 0.4936
# Epoch 2/4
# 391/391 [==============================] - 3s 8ms/step - loss: 1.4683 - accuracy: 0.4830 - val_loss: 1.3279 - val_accuracy: 0.5346
# Epoch 3/4
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3496 - accuracy: 0.5254 - val_loss: 1.2242 - val_accuracy: 0.5756
# Epoch 4/4
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2815 - accuracy: 0.5506 - val_loss: 1.2344 - val_accuracy: 0.5669
# Test loss: 1.2343840599060059
# Test accuracy: 0.5669000148773193
#  19% 6/32 [00:30<02:51,  6.60s/it]04/16/2021 07:00:55 PM - INFO - Getting Keras datasets
# 04/16/2021 07:00:56 PM - INFO - Compling Keras model
# 04/16/2021 07:00:56 PM - INFO - Architecture:[64, 16, 16, 16, 32, 128],elu,nadam,1
# Epoch 1/4
# 391/391 [==============================] - 5s 10ms/step - loss: 1.9132 - accuracy: 0.3561 - val_loss: 1.4017 - val_accuracy: 0.5099
# Epoch 2/4
# 391/391 [==============================] - 4s 10ms/step - loss: 1.4126 - accuracy: 0.5077 - val_loss: 1.3021 - val_accuracy: 0.5466
# Epoch 3/4
# 391/391 [==============================] - 4s 10ms/step - loss: 1.2925 - accuracy: 0.5527 - val_loss: 1.2282 - val_accuracy: 0.5721
# Epoch 4/4
# 391/391 [==============================] - 4s 10ms/step - loss: 1.2156 - accuracy: 0.5758 - val_loss: 1.1518 - val_accuracy: 0.5956
# Test loss: 1.1517530679702759
# Test accuracy: 0.5956000089645386
#  22% 7/32 [00:47<04:08,  9.95s/it]04/16/2021 07:01:13 PM - INFO - Getting Keras datasets
# 04/16/2021 07:01:14 PM - INFO - Compling Keras model
# 04/16/2021 07:01:14 PM - INFO - Architecture:[16, 16, 32, 16, 16, 64],elu,adam,1
# Epoch 1/4
# 391/391 [==============================] - 3s 6ms/step - loss: 1.9272 - accuracy: 0.3272 - val_loss: 1.4916 - val_accuracy: 0.4768
# Epoch 2/4
# 391/391 [==============================] - 2s 5ms/step - loss: 1.5320 - accuracy: 0.4638 - val_loss: 1.3622 - val_accuracy: 0.5311
# Epoch 3/4
# 391/391 [==============================] - 2s 5ms/step - loss: 1.4360 - accuracy: 0.4999 - val_loss: 1.3037 - val_accuracy: 0.5517
# Epoch 4/4
# 391/391 [==============================] - 2s 5ms/step - loss: 1.3671 - accuracy: 0.5222 - val_loss: 1.2547 - val_accuracy: 0.5671
# Test loss: 1.2547383308410645
# Test accuracy: 0.5670999884605408
#  25% 8/32 [00:58<04:02, 10.09s/it]04/16/2021 07:01:23 PM - INFO - Getting Keras datasets
# 04/16/2021 07:01:24 PM - INFO - Compling Keras model
# 04/16/2021 07:01:24 PM - INFO - Architecture:[64, 16, 32, 32, 32, 64],linear,adam,2
# Epoch 1/4
# 391/391 [==============================] - 4s 8ms/step - loss: 1.9242 - accuracy: 0.2988 - val_loss: 1.4387 - val_accuracy: 0.5004
# Epoch 2/4
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4981 - accuracy: 0.4678 - val_loss: 1.3065 - val_accuracy: 0.5515
# Epoch 3/4
# 391/391 [==============================] - 3s 7ms/step - loss: 1.3801 - accuracy: 0.5168 - val_loss: 1.2254 - val_accuracy: 0.5786
# Epoch 4/4
# 391/391 [==============================] - 3s 7ms/step - loss: 1.3140 - accuracy: 0.5443 - val_loss: 1.2443 - val_accuracy: 0.5488
# Test loss: 1.2442551851272583
# Test accuracy: 0.548799991607666
#  28% 9/32 [01:12<04:19, 11.29s/it]04/16/2021 07:01:37 PM - INFO - Getting Keras datasets
# 04/16/2021 07:01:38 PM - INFO - Compling Keras model
# 04/16/2021 07:01:38 PM - INFO - Architecture:[64, 64, 32, 32, 16, 32],elu,nadam,2
# Epoch 1/4
# 391/391 [==============================] - 5s 11ms/step - loss: 1.8957 - accuracy: 0.3143 - val_loss: 1.3315 - val_accuracy: 0.5387
# Epoch 2/4
# 391/391 [==============================] - 4s 10ms/step - loss: 1.4333 - accuracy: 0.4907 - val_loss: 1.2483 - val_accuracy: 0.5574
# Epoch 3/4
# 391/391 [==============================] - 4s 10ms/step - loss: 1.3043 - accuracy: 0.5435 - val_loss: 1.0970 - val_accuracy: 0.6251
# Epoch 4/4
# 391/391 [==============================] - 4s 10ms/step - loss: 1.2484 - accuracy: 0.5633 - val_loss: 1.1136 - val_accuracy: 0.6194
# Test loss: 1.1136342287063599
# Test accuracy: 0.6194000244140625
#  31% 10/32 [01:31<04:56, 13.49s/it]04/16/2021 07:01:56 PM - INFO - Getting Keras datasets
# 04/16/2021 07:01:57 PM - INFO - Compling Keras model
# 04/16/2021 07:01:57 PM - INFO - Architecture:[128, 64, 32, 32, 32, 64],linear,adam,2
# Epoch 1/4
# 391/391 [==============================] - 6s 14ms/step - loss: 1.8232 - accuracy: 0.3490 - val_loss: 1.4050 - val_accuracy: 0.4949
# Epoch 2/4
# 391/391 [==============================] - 5s 13ms/step - loss: 1.3264 - accuracy: 0.5375 - val_loss: 1.1854 - val_accuracy: 0.5828
# Epoch 3/4
# 391/391 [==============================] - 5s 13ms/step - loss: 1.2356 - accuracy: 0.5722 - val_loss: 1.1079 - val_accuracy: 0.6200
# Epoch 4/4
# 391/391 [==============================] - 5s 13ms/step - loss: 1.1688 - accuracy: 0.5992 - val_loss: 1.0714 - val_accuracy: 0.6348
# Test loss: 1.0713666677474976
# Test accuracy: 0.6348000168800354
#  34% 11/32 [01:53<05:42, 16.33s/it]04/16/2021 07:02:19 PM - INFO - Getting Keras datasets
# 04/16/2021 07:02:20 PM - INFO - Compling Keras model
# 04/16/2021 07:02:20 PM - INFO - Architecture:[64, 16, 32, 32, 16, 32],elu,nadam,4
# Epoch 1/4
# 391/391 [==============================] - 5s 10ms/step - loss: 2.0346 - accuracy: 0.2463 - val_loss: 1.6009 - val_accuracy: 0.4076
# Epoch 2/4
# 391/391 [==============================] - 4s 10ms/step - loss: 1.6139 - accuracy: 0.4138 - val_loss: 1.4031 - val_accuracy: 0.4975
# Epoch 3/4
# 391/391 [==============================] - 4s 10ms/step - loss: 1.4908 - accuracy: 0.4656 - val_loss: 1.3154 - val_accuracy: 0.5227
# Epoch 4/4
# 391/391 [==============================] - 4s 10ms/step - loss: 1.4356 - accuracy: 0.4850 - val_loss: 1.2484 - val_accuracy: 0.5444
# Test loss: 1.2484350204467773
# Test accuracy: 0.5443999767303467
#  38% 12/32 [02:12<05:36, 16.85s/it]04/16/2021 07:02:37 PM - INFO - Getting Keras datasets
# 04/16/2021 07:02:38 PM - INFO - Compling Keras model
# 04/16/2021 07:02:38 PM - INFO - Architecture:[64, 64, 32, 32, 16, 128],elu,nadam,2
# Epoch 1/4
# 391/391 [==============================] - 5s 11ms/step - loss: 1.8036 - accuracy: 0.3517 - val_loss: 1.2586 - val_accuracy: 0.5544
# Epoch 2/4
# 312/391 [======================>.......] - ETA: 0s - loss: 1.2857 - accuracy: 0.5515

# %% [markdown]
# Y os recomiendo que le echéis un ojo a estos dos enlaces en los que evolucionan una red neuronal con un GA. Aquí no nos da tiempo, pero son muy interesantes:
#
# ### Ejemplo GA para evolucionar NN:
#
# * https://blog.coast.ai/lets-evolve-a-neural-network-with-a-genetic-algorithm-code-included-8809bece164
# * https://github.com/harvitronix/neural-network-genetic-algorithm
